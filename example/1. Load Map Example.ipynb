# %% [markdown]
# # 1. Load Library
# ## 1.1 Load Global Library
# Load global library here, because we will change the path to library when we load the local library

# %%
import sys
import os

# %% [markdown]
# ## 1.2 Load Local Library

# %%
# change the library read path
sys.path.append(os.path.join(os.getcwd() , ".."))

# load local library
import lib.Map.Map as map

# %% [markdown]
# # 2. How to use the documentation
#
# To keep it simple, you can read the documentation on the fly by calling printing \_\_doc\_\_ attribute
#
# ## 2.1 Class documentation

# %%
print(map.Map.__doc__)
# Out:
#     [Class] Map
#     A class to represent the map
#
#     Properties:
#         - origin        : [Coordinate] map's origin coordinate
#         - end           : [Coordinate] map's end coordinate
#         - num_nodes     : Number of Nodes.
#         - nodesDict     : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - nodes         : List of all nodes.
#
#         - num_ways      : Number of Ways.
#         - waysDict      : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - ways          : List of all ways.
#
#         - num_roads     : Number of Roads.
#         - roadNodesDict :
#         - roadNodes     :
#         - roadsDict     : List of all nodes that marked as road.
#         - roads         : List of all roads.
#
#         - num_buildings : Number of Buildings.
#         - buildings     : List of all buildings.
#         - naturals      : List of all naturals.
#         - leisures      : List of all leisures.
#         - amenities     : List of all amenities.
#
#         - grids         : [(int,int)] Two dimensional array of grids
#
#         - others        : List of other openstreetmap ways that yet to be categorized.
#         - distanceLat   : height of 1 grid in latitude
#         - distanceLon   : width of 1 grid in longitude
#         - gridsize      : tuple of 2 integer that shows how many grids we have

# %% [markdown]
# ## 2.2 Function Documentation

# %%
print(map.readFile.__doc__)
# Out:
#     [Function] readFile
#     Function to generate map fom osm File
#
#     parameter:
#         - filepath : [string] path to the OSM file
#         - grid     : [(int,int)] grid size, default value = (10,10)

# %% [markdown]
# ## 2.3 Method Documentation
# can be called from class also from objects

# %%
print(map.Map.setBounds.__doc__)
# Out:
#         [Method] __str__
#         Setup the bounds using the file path
#
#         Parameter:
#             - filepath : path to the OSM file

# %% [markdown]
# # 3. load the data
# ## 3.1 setup the path

# %%
dataDirectory = os.path.join("..","osmData")
#filename = "TX-To-TU.osm"
filename = "London.osm"
filepath = os.path.join(dataDirectory,filename)

# %% [markdown]
# ## 3.2 Load the osm file

# %%
osmMap = map.readFile(filepath)

# %% [markdown]
# ## 3.3 Print the data

# %%
print(osmMap)
# Out:
# Epidemicon Map
#  number of nodes = 49832
#  number of ways = 11252
#  number of roads = 8806
#  number of roads node = 7657
#  number of buildings = 4431

# %%
node = osmMap.nodes[0]
print(node)
# Out:
# id: 101998
# lat = 51.5193483 lon = -0.14714
# number of ways : 1
# number of connections : 1
# Tags :

# %%
way = osmMap.ways[0]
print(way)
# Out:
# id: 31039
# number of nodes : 8
# Tags :
# 	cycleway:right : opposite_share_busway
# 	highway : primary
# 	lanes : 2
# 	lit : yes
# 	maxspeed : 20 mph
# 	maxspeed:type : GB:zone20
# 	name : Tottenham Court Road
# 	name:ja : トッテナム・コート・ロード
# 	oneway : yes
# 	oneway:bicycle : no
# 	oneway:bus : no
# 	proposed:oneway : no
# 	ref : A400
# 	sidewalk : both
# 	surface : asphalt

# %%
road = osmMap.roads[0]
print(road)
# Out:
# staring = (lat = 51.5164132, lon = -0.1303768)
# destination = (lat = 51.5164763, lon = -0.1303836)
# distance = 0.007036239849447578km

# %%
building = osmMap.buildings[0]
print(building)
# Out:
# [Building]
# id: 4372002
# number of nodes : 72
# Tags :
# 	addr:city : London
# 	building : yes
# 	building:levels : 2
# 	fee : no
# 	name : National Gallery
# 	name:de : Nationalgalerie
# 	name:en : National Gallery
# 	name:es : Galería Nacional.
# 	name:gl : Galería Nacional
# 	name:ru : Национальная галерея
# 	name:uk : Національна галерея
# 	name:zh : 國家美術館
# 	opening_hours : Sa-Th 10:00-18:00; Fr 10:00-21:00
# 	postal_code : WC2N 5DN
# 	source : Bing
# 	toilets:wheelchair : yes
# 	tourism : gallery
# 	website : https://www.nationalgallery.org.uk/
# 	wheelchair : yes
# 	wikidata : Q180788
# 	wikipedia : en:National Gallery

# %%
temp = {}
yesBuilding = []
for x in osmMap.buildings:
    print (x)
    for y in x.tags.keys():
        if y == "building":
            if x.tags[y] not in temp.keys():
                temp[x.tags[y]] = 1
            else:
                temp[x.tags[y]] +=1
            if x.tags[y] == "yes":
                yesBuilding.append(x)
            break
# Out:
# [Building]
# id: 4372002
# number of nodes : 72
# Tags :
# 	addr:city : London
# 	building : yes
# 	building:levels : 2
# 	fee : no
# 	name : National Gallery
# 	name:de : Nationalgalerie
# 	name:en : National Gallery
# 	name:es : Galería Nacional.
# 	name:gl : Galería Nacional
# 	name:ru : Национальная галерея
# 	name:uk : Національна галерея
# 	name:zh : 國家美術館
# 	opening_hours : Sa-Th 10:00-18:00; Fr 10:00-21:00
# 	postal_code : WC2N 5DN
# 	source : Bing
# 	toilets:wheelchair : yes
# 	tourism : gallery
# 	website : https://www.nationalgallery.org.uk/
# 	wheelchair : yes
# 	wikidata : Q180788
# 	wikipedia : en:National Gallery
#
#
# [Building]
# id: 10811256
# number of nodes : 46
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housename : Broadcasting House
# 	addr:postcode : W1A 1AA
# 	addr:street : Portland Place
# 	building : office
# 	building:levels : 9
# 	name : BBC Broadcasting House
# 	short_name : NBH
# 	website : https://www.bbc.com/historyofthebbc/buildings/broadcasting-house
# 	wikipedia : en:Broadcasting House
#
#
# [Building]
# id: 23613977
# number of nodes : 33
# Tags :
# 	addr:city : London
# 	addr:housename : Old Building
# 	addr:postcode : WC2A 2AE
# 	addr:street : Houghton Street
# 	building : university
# 	building:levels : 6
# 	building:material : sandstone
# 	construction_date : 1920-1923
# 	name : Old Building
# 	operator : London School of Economics and Political Science (LSE)
# 	roof:colour : black
# 	roof:shape : hipped
# 	short_name : OLD
# 	wheelchair : yes
#
#
# [Building]
# id: 23613978
# number of nodes : 18
# Tags :
# 	addr:city : London
# 	addr:housename : Connaught House
# 	addr:housenumber : 63–65
# 	addr:postcode : WC2A 2AE
# 	addr:street : Aldwych
# 	building : university
# 	building:levels : 7
# 	building:material : sandstone
# 	contact:website : http://www.lse.ac.uk/intranet/LSEServices/estatesDivision/lseEstate/campusBuildings/connaughtHouse.aspx
# 	department : Department of International Development
# 	name : Connaught House
# 	operator : London School of Economics and Political Science (LSE)
# 	roof:colour : black
# 	roof:levels : 1
# 	roof:material : slate
# 	roof:shape : mansard
# 	short_name : CON
# 	source : survey
#
#
# [Building]
# id: 23613985
# number of nodes : 13
# Tags :
# 	addr:city : London
# 	addr:housenumber : 20
# 	addr:postcode : WC2B 6LH
# 	addr:street : Kingsway
# 	building : university
# 	building:colour : white
# 	building:levels : 5
# 	building:material : brick
# 	name : 20 Kingsway
# 	operator : London School of Economics and Political Science (LSE)
# 	ref : KSW
# 	short_name : KSW
# 	source : http://www.lse.ac.uk/intranet/LSEServices/estatesDivision/lseEstate/campusBuildings/kingsway.aspx
#
#
# [Building]
# id: 23613986
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:housename : Peacock Theatre
# 	addr:housenumber : 35
# 	addr:postcode : WC2A 2HT
# 	addr:street : Portugal Street
# 	amenity : theatre
# 	building : yes
# 	fhrs:confidence_management : 5
# 	fhrs:hygiene : 10
# 	fhrs:id : 411811
# 	fhrs:local_authority_id : 00570/4000/0/000
# 	fhrs:rating : 4
# 	fhrs:structural : 5
# 	name : Peacock Theatre
# 	short_name : PEA
# 	source:addr : FSA Food Hygiene Ratings Database
# 	start_date : 1960
# 	wikidata : Q748557
# 	wikipedia : en:Peacock Theatre
#
#
# [Building]
# id: 23613987
# number of nodes : 20
# Tags :
# 	addr:city : London
# 	addr:housename : New Academic Building
# 	addr:housenumber : 54
# 	addr:postcode : WC2A 3LJ
# 	addr:street : Lincoln's Inn Fields
# 	building : university
# 	building:colour : light_grey
# 	building:levels : 6
# 	building:material : stone
# 	department : Department of Law;Department of Management
# 	name : New Academic Building
# 	operator : London School of Economics and Political Science (LSE)
# 	photo : http://www.lse.ac.uk/intranet/LSEServices/estatesDivision/lseEstate/campusBuildings/newAcademicBuilding/images/newAcademicFacade_478x282.JPG
# 	roof:colour : grey
# 	roof:levels : 3
# 	roof:shape : quadruple_saltbox
# 	short_name : NAB
# 	wheelchair : yes
#
#
# [Building]
# id: 23613988
# number of nodes : 6
# Tags :
# 	addr:city : London
# 	addr:housename : Parish Hall
# 	addr:postcode : WC2A 2HA
# 	addr:street : Sheffield Street
# 	building : university
# 	building:colour : maroon
# 	building:levels : 2
# 	building:material : brick
# 	name : Parish Hall
# 	operator : London School of Economics and Political Science (LSE)
# 	roof:black : gabled
# 	short_name : PAR
# 	source : http://www.lse.ac.uk/intranet/LSEServices/estatesDivision/lseEstate/campusBuildings/parishHall.aspx
# 	start_date : 1897–1898
#
#
# [Building]
# id: 23613989
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:housename : Lincoln Chambers
# 	addr:housenumber : 2–4
# 	addr:postcode : WC2A 2ES
# 	addr:street : Portsmouth Street
# 	building : university
# 	building:colour : red
# 	building:levels : 3
# 	building:material : brick
# 	name : Lincoln Chambers
# 	operator : London School of Economics and Political Science (LSE)
# 	short_name : LCH
#
#
# [Building]
# id: 23613990
# number of nodes : 6
# Tags :
# 	addr:city : London
# 	addr:housename : King's Chambers
# 	building : university
# 	name : King's Chambers
# 	operator : London School of Economics and Political Science (LSE)
# 	short_name : KGS
# 	wikidata : Q27081449
#
#
# [Building]
# id: 23613991
# number of nodes : 12
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housename : 1 Portsmouth Street
# 	addr:housenumber : 1
# 	addr:postcode : WC2A 2ES
# 	addr:street : Portsmouth Street
# 	building : university
# 	name : 1 Portsmouth Street
# 	operator : London School of Economics and Political Science (LSE)
# 	short_name : POR
#
#
# [Building]
# id: 23613992
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:housename : Sheffield Street
# 	addr:housenumber : 9–10
# 	addr:postcode : WC2A 2EY
# 	addr:street : Sheffield Street
# 	building : university
# 	name : Sheffield Street
# 	operator : London School of Economics and Political Science (LSE)
# 	short_name : SHF
# 	source : http://www.lse.ac.uk/intranet/LSEServices/estatesDivision/lseEstate/campusBuildings/sheffieldStreet.aspx
#
#
# [Building]
# id: 25904238
# number of nodes : 10
# Tags :
# 	building : commercial
#
#
# [Building]
# id: 25904239
# number of nodes : 41
# Tags :
# 	addr:city : London
# 	addr:housenumber : 30
# 	addr:postcode : WC2B 4BG
# 	addr:street : Aldwych
# 	building : commercial
# 	building:colour : light_grey
# 	building:material : stone
# 	name : Bush House
# 	note : part of the Aldwych Quarter development leased to King's College London, 2015–2065, who will start to occupy the building from September 2016
# 	operator : King's College London
# 	source : http://www.kcl.ac.uk/aboutkings/orgstructure/ps/estates/Real-Estate-Development/current/aldwych-quarter/index.aspx
# 	website : http://aldwychquarter.com/files/Bush%20House%20Completion%20Brochure.pdf
# 	wikidata : Q852282
# 	wikipedia : en:Bush House
#
#
# [Building]
# id: 25904243
# number of nodes : 8
# Tags :
# 	addr:city : London
# 	addr:housename : India House
# 	addr:postcode : WC2B 4NA
# 	addr:street : Aldwych
# 	building : public
# 	building:material : sandstone
# 	country : IN
# 	diplomatic : embassy
# 	name : High Commission of India
# 	office : diplomatic
# 	target : GB
# 	wikidata : Q14996965
# 	wikipedia : en:India House, London
#
#
# [Building]
# id: 25904245
# number of nodes : 10
# Tags :
# 	addr:city : London
# 	addr:postcode : WC2R 1ES
# 	amenity : place_of_worship
# 	building : church
# 	contact:website : http://www.stmarylestrand.org/
# 	denomination : anglican
# 	name : Saint Mary le Strand
# 	religion : christian
# 	wikidata : Q536866
# 	wikipedia : en:St Mary le Strand
#
#
# [Building]
# id: 27038418
# number of nodes : 23
# Tags :
# 	building : train_station
# 	name : Charing Cross Railway Station
#
#
# [Building]
# id: 27163672
# number of nodes : 17
# Tags :
# 	addr:city : London
# 	addr:housenumber : 21
# 	addr:street : Wellington Street
# 	amenity : theatre
# 	building : yes
# 	contact:website : http://www.lyceum-theatre.co.uk
# 	name : Lyceum Theatre
# 	name:en : Lyceum Theatre
# 	name:ru : Лицеум
# 	postal_code : WC2E 7RQ
# 	roof:colour : grey
# 	roof:shape : flat
# 	toilets:wheelchair : yes
# 	wheelchair : yes
# 	wikidata : Q1661445
# 	wikimedia_commons : Category:Lyceum_Theatre,_London
# 	wikipedia : en:Lyceum Theatre, London
#
#
# [Building]
# id: 27922125
# number of nodes : 28
# Tags :
# 	amenity : place_of_worship
# 	building : church
# 	denomination : anglican
# 	name : All Souls Church
# 	name:en : All Souls Church
# 	name:es : Iglesia All Souls
# 	religion : christian
# 	tourism : attraction
# 	wikidata : Q4729656
#
#
# [Building]
# id: 28143024
# number of nodes : 24
# Tags :
# 	addr:housenumber : 50-60
# 	addr:postcode : WC1B 4AR
# 	addr:street : Southampton Row
# 	building : yes
# 	building:colour : light_grey
# 	building:levels : 10
# 	building:material : stone
# 	name : The Grange Holborn Hotel
# 	tourism : hotel
# 	wikidata : Q5595661
#
#
# [Building]
# id: 28416499
# number of nodes : 6
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housename : Freemasons' Hall
# 	addr:housenumber : 60
# 	addr:postcode : WC2B 5AZ
# 	addr:street : Great Queen Street
# 	alt_name : Freemasons' Hall
# 	building : yes
# 	building:material : sandstone
# 	club : freemasonry
# 	contact:phone : +44 (0) 20 7831 9811
# 	fixme : The name of the building is Freemason's Hall. The name of the club it houses is United Grand Lodge of England. Which should rather be used for the name tag?
# 	loc_name : Freemason's Hall
# 	name : Freemasons' Hall
# 	tourism : yes
# 	wikidata : Q1453586
# 	wikipedia : en:Freemasons' Hall, London
#
#
# [Building]
# id: 28416536
# number of nodes : 39
# Tags :
# 	building : yes
# 	building:colour : red-brown
# 	building:levels : 6
# 	building:material : brick
# 	name : Radisson Blu Edwardian Kenilworth
# 	operator : Radisson Blu Edwardian
# 	roof:levels : 1
# 	tourism : hotel
# 	website : https://www.radissonblu-edwardian.com/london-hotel-gb-wc1b-3lb/gbkenilw
#
#
# [Building]
# id: 28416571
# number of nodes : 40
# Tags :
# 	addr:city : London
# 	addr:housenumber : 9
# 	addr:postcode : WC1B 3QD
# 	addr:street : Bloomsbury Street
# 	building : yes
# 	building:colour : orange
# 	building:levels : 6
# 	building:material : brick
# 	fhrs:id : 425905
# 	name : Radisson Blu Edwardian Bloomsbury Street Hotel
# 	operator : Radisson Blu Edwardian
# 	source:addr : FSA Food Hygiene Ratings Scheme open data
# 	tourism : hotel
# 	website : https://www.radissonblu-edwardian.com/london-hotel-gb-wc1b-3qd/gbmarlbo
#
#
# [Building]
# id: 30613704
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 280
# 	addr:street : High Holborn
# 	building : yes
#
#
# [Building]
# id: 30734422
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:postcode : WC2N 4JH
# 	addr:street : Trafalgar Square
# 	amenity : place_of_worship
# 	building : church
# 	denomination : anglican
# 	is_in : London
# 	name : St Martin-in-the-Fields
# 	name:es : Iglesia St. Martin in the Fields
# 	name:ru : Сент-Мартин-ин-зе-Филдс
# 	religion : christian
# 	start_date : 1724
# 	toilets:wheelchair : yes
# 	tourism : attraction
# 	website : https://www.stmartin-in-the-fields.org/
# 	wheelchair : yes
# 	wheelchair:description : There is access to ticket office, crypt and restaurant via a spacious lift at street level on the north side of the church.
# 	wikidata : Q1335201
# 	wikimedia_commons : Category:St_Martin-in-the-Fields
# 	wikipedia : en:St Martin-in-the-Fields
#
#
# [Building]
# id: 30734455
# number of nodes : 9
# Tags :
# 	building : yes
# 	building:levels : 7
# 	source : Bing
#
#
# [Building]
# id: 30942443
# number of nodes : 35
# Tags :
# 	addr:city : London
# 	addr:housenumber : 1
# 	addr:postcode : WC2B 4AN
# 	addr:street : Kemble Street
# 	building : public
# 	building:architecture : brutalism
# 	building:colour : silver
# 	building:levels : 16
# 	building:material : concrete
# 	construction_date : 1966
# 	height : 52 m
# 	office : government
# 	old_name : Space House
# 	roof:colour : silver
# 	roof:shape : flat
# 	wikidata : Q27087667
# 	wikipedia : en:One Kemble Street
#
#
# [Building]
# id: 31327771
# number of nodes : 20
# Tags :
# 	addr:city : London
# 	addr:housenumber : 11a
# 	addr:postcode : WC2H 0EP
# 	addr:street : Charing Cross Road
# 	alt_name : London Pass Redemption Centre
# 	building : yes
# 	name : The London Pass
# 	name:fr : Kiosque London Pass
# 	opening_hours : Mo-Su 10:00-16:30
# 	shop : ticket
#
#
# [Building]
# id: 31467151
# number of nodes : 11
# Tags :
# 	building : yes
# 	building:material : glass
# 	building:name : Crypt
# 	name : London Brass Rubbing Centre
# 	shop : gift
# 	toilets:wheelchair : yes
# 	website : http://www.stmartin-in-the-fields.org/visiting/brass-rubbing/
# 	wheelchair : yes
#
#
# [Building]
# id: 31467228
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:levels : 5
#
#
# [Building]
# id: 31509552
# number of nodes : 9
# Tags :
# 	building : yes
# 	building:material : sandstone
# 	roof:colour : black
#
#
# [Building]
# id: 31509554
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 31694141
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	amenity : restaurant
# 	building : yes
# 	building:levels : 1
# 	cuisine : pizza
# 	name : Fields
# 	outdoor_seating : yes
#
#
# [Building]
# id: 32919209
# number of nodes : 10
# Tags :
# 	addr:city : London
# 	addr:housenumber : 45
# 	addr:postcode : WC2N 4HX
# 	addr:street : St. Martin's Lane
# 	building : yes
# 	internet_access : wlan
# 	internet_access:ssid : ST-MARTINS-LANE-GUEST
# 	name : St Martins Lane Hotel
# 	operator : sbe - Morgans Hotel Group
# 	source : yahoo+ground sketch;local knowledge
# 	tourism : hotel
#
#
# [Building]
# id: 32919259
# number of nodes : 11
# Tags :
# 	building : yes
# 	name : Royal Trafalgar Hotel
# 	operator : thistle
# 	source : Bing
# 	tourism : hotel
# 	website : https://www.thistle.com/hotels/united_kingdom/london/thistle_trafalgar_square/index.html
#
#
# [Building]
# id: 32919261
# number of nodes : 26
# Tags :
# 	building : yes
#
#
# [Building]
# id: 33632838
# number of nodes : 21
# Tags :
# 	addr:street : Oxford Street
# 	building : shop
# 	name : The Plaza
#
#
# [Building]
# id: 33719501
# number of nodes : 13
# Tags :
# 	building : yes
# 	name : London Trocadero
# 	shop : mall
# 	source:name : survey
# 	source:shop : survey
# 	wikidata : Q6670874
# 	wikipedia : en:London Trocadero
#
#
# [Building]
# id: 33721552
# number of nodes : 8
# Tags :
# 	building : yes
# 	fixme : Multiple buildings to split
#
#
# [Building]
# id: 33721672
# number of nodes : 52
# Tags :
# 	addr:city : London
# 	addr:housename : Royal Opera House
# 	addr:postcode : WC2E 9DD
# 	addr:street : Bow Street
# 	addr:suburb : Covent Garden
# 	amenity : theatre
# 	building : civic
# 	building:levels : 7
# 	building:material : sandstone
# 	capacity : 2256
# 	contact:website : http://www.roh.org.uk
# 	loc_name : Covent Garden
# 	name : Royal Opera House
# 	name:de : Königliches Opernhaus
# 	name:es : Real Opera House
# 	name:he : בית האופרה המלכותית, קובנט גארדן
# 	name:ru : Королевский театр Ковент-Гарден
# 	name:uk : Королівський театр Ковент-Гарден
# 	name:zh : 皇家歌剧院
# 	operator : The Royal Opera
# 	roof:colour : grey
# 	roof:levels : 1
# 	short_name : Royal Opera
# 	theatre:genre : opera
# 	tourism : attraction
# 	wheelchair : yes
# 	wikidata : Q55018
# 	wikipedia : en:Royal Opera House
#
#
# [Building]
# id: 34878209
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 1
# 	addr:street : Wimpole Street
# 	building : yes
# 	fhrs:confidence_management : 0
# 	fhrs:hygiene : 5
# 	fhrs:id : 411295
# 	fhrs:local_authority_id : 00289/0001/0/000
# 	fhrs:rating : 5
# 	fhrs:structural : 0
# 	name : Royal Society of Medicine
# 	postal_code : W1G 8GP
# 	source:postcode : FSA Food Hygiene Ratings Database
# 	wikidata : Q3446034
#
#
# [Building]
# id: 35904815
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 37458961
# number of nodes : 22
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housename : First Avenue House
# 	addr:housenumber : 42-49
# 	addr:street : High Holborn
# 	building : yes
#
#
# [Building]
# id: 38310265
# number of nodes : 15
# Tags :
# 	amenity : place_of_worship
# 	building : church
# 	name : Saint George's Hanover Square
# 	religion : christian
# 	wikidata : Q3495317
# 	wikipedia : en:St George's, Hanover Square
#
#
# [Building]
# id: 38319205
# number of nodes : 10
# Tags :
# 	building : retail
# 	building:levels : 5
# 	name : Fenwick
# 	shop : department_store
# 	wheelchair : yes
#
#
# [Building]
# id: 38325236
# number of nodes : 13
# Tags :
# 	addr:housenumber : 1;3;5;7;9;11
# 	addr:street : John Adam Street
# 	alt_name : New Adelphi
# 	building : yes
# 	layer : 1
# 	name : The Adelphi
#
#
# [Building]
# id: 38325241
# number of nodes : 19
# Tags :
# 	addr:housenumber : 11
# 	addr:street : Strand
# 	building : yes
# 	building:levels : 8
#
#
# [Building]
# id: 38325243
# number of nodes : 15
# Tags :
# 	addr:housenumber : 5
# 	addr:street : Strand
# 	building : yes
# 	building:colour : light_grey
# 	building:levels : 9
# 	note : building:levels is approximate and varies in different parts of the building
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 38425099
# number of nodes : 13
# Tags :
# 	addr:city : London
# 	addr:housenumber : 3
# 	addr:street : Berkeley Street
# 	brand : Holiday Inn
# 	brand:wikidata : Q2717882
# 	brand:wikipedia : en:Holiday Inn
# 	building : hotel
# 	fhrs:confidence_management : 5
# 	fhrs:hygiene : 5
# 	fhrs:id : 412324
# 	fhrs:local_authority_id : 00762/0003/0/000
# 	fhrs:rating : 4
# 	fhrs:structural : 10
# 	name : Holiday Inn Mayfair
# 	operator : LRG
# 	postal_code : W1J 8NE
# 	source:addr : FSA Food Hygiene Ratings Database
# 	source:postcode : FSA Food Hygiene Ratings Database
# 	tourism : hotel
#
#
# [Building]
# id: 38425102
# number of nodes : 25
# Tags :
# 	addr:city : London
# 	addr:postcode : W1J 8LT
# 	addr:street : Stratton Street
# 	building : hotel
# 	name : May Fair Hotel
# 	phone : +44 20 7629 7777
# 	stars : 5
# 	toilets:wheelchair : no
# 	tourism : hotel
# 	website : https://www.themayfairhotel.co.uk/
# 	wheelchair : yes
# 	wikidata : Q7750722
# 	wikipedia : en:The May Fair
#
#
# [Building]
# id: 38432589
# number of nodes : 14
# Tags :
# 	amenity : police
# 	building : yes
# 	name : West End Central Police Station
# 	wikidata : Q18163108
#
#
# [Building]
# id: 40412564
# number of nodes : 8
# Tags :
# 	addr:street : West Street
# 	amenity : theatre
# 	building : yes
# 	building:colour : white
# 	building:levels : 4
# 	building:material : plaster
# 	name : St Martin's
# 	postal_code : WC2H 9NZ
# 	roof:colour : dark_grey
# 	website : http://www.stmartins-theatre.co.uk
# 	wheelchair : limited
# 	wikidata : Q7594202
# 	wikipedia : en:St Martin's Theatre
#
#
# [Building]
# id: 40463226
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40463229
# number of nodes : 5
# Tags :
# 	amenity : cinema
# 	building : yes
# 	name : Odeon Shaftesbury Avenue
# 	wheelchair : no
#
#
# [Building]
# id: 40463230
# number of nodes : 10
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housename : The Glasshouse
# 	addr:street : Shaftesbury Avenue
# 	building : yes
# 	name : The Glasshouse
#
#
# [Building]
# id: 40463232
# number of nodes : 11
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40463233
# number of nodes : 12
# Tags :
# 	building : apartments
#
#
# [Building]
# id: 40463234
# number of nodes : 12
# Tags :
# 	amenity : place_of_worship
# 	building : church
# 	denomination : anglican
# 	name : St Giles-in-the-Fields
# 	religion : christian
# 	wikidata : Q3495322
# 	wikimedia_commons : Category:St_Giles_in_the_Fields
# 	wikipedia : en:St Giles in the Fields
#
#
# [Building]
# id: 40470534
# number of nodes : 12
# Tags :
# 	addr:city : London
# 	addr:housename : Langley House
# 	addr:street : Long Acre
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	source : yahoo
#
#
# [Building]
# id: 40470537
# number of nodes : 9
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40470543
# number of nodes : 39
# Tags :
# 	addr:city : London
# 	addr:housenumber : 10
# 	addr:postcode : WC2B 5RE
# 	addr:street : Drury Lane
# 	brand : Travelodge
# 	brand:wikidata : Q9361374
# 	brand:wikipedia : en:Travelodge UK
# 	building : yes
# 	fhrs:id : 423928
# 	name : Travelodge London Covent Garden
# 	source : Bing;survey;tags copied from node 438170555
# 	source:addr : FSA Food Hygiene Rating Scheme open data
# 	tourism : hotel
# 	wheelchair : no
#
#
# [Building]
# id: 40470552
# number of nodes : 8
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 8-10
# 	addr:street : Dryden Street
# 	building : yes
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
# 	source : Bing;survey
#
#
# [Building]
# id: 40599490
# number of nodes : 25
# Tags :
# 	building : yes
# 	fixme : Retrace from Bing, and find Winter Garden House, Macklin House and no doubt other named buildings.
# 	source : yahoo
#
#
# [Building]
# id: 40733987
# number of nodes : 14
# Tags :
# 	building : retail
# 	building:levels : 4
# 	building:material : brick
#
#
# [Building]
# id: 40733988
# number of nodes : 7
# Tags :
# 	addr:housenumber : 39
# 	addr:postcode : WC1B 3EG
# 	addr:street : Bedford Square
# 	building : house
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:levels : 1
# 	source:housenumber : OSGB 1:1250 OOC Maps via NLS
# 	source:postcode : FHRS Open Data
#
#
# [Building]
# id: 40734125
# number of nodes : 6
# Tags :
# 	building : office
# 	building:levels : 4
#
#
# [Building]
# id: 40734128
# number of nodes : 11
# Tags :
# 	addr:city : London
# 	addr:street : Tottenham Court Road
# 	building : commercial
# 	building:levels : 6
# 	building:material : brick
#
#
# [Building]
# id: 40734131
# number of nodes : 16
# Tags :
# 	building : retail
# 	building:levels : 4
# 	building:material : brick
#
#
# [Building]
# id: 40825874
# number of nodes : 11
# Tags :
# 	addr:city : London
# 	addr:housename : Wogan House
# 	addr:housenumber : 99
# 	addr:postcode : W1A 1AA
# 	addr:street : Great Portland Street
# 	alt_name : BBC
# 	building : office
# 	building:colour : grey
# 	building:levels : 7
# 	building:material : stone
# 	name : BBC Wogan House
# 	wikidata : Q16897636
# 	wikipedia : en:Wogan House
#
#
# [Building]
# id: 40825881
# number of nodes : 12
# Tags :
# 	addr:city : London
# 	addr:housenumber : 32-33
# 	addr:street : Gosfield Street
# 	building : commercial
# 	building:levels : 4
# 	name : Royal Air Maroc
#
#
# [Building]
# id: 40825882
# number of nodes : 11
# Tags :
# 	addr:housenumber : 35
# 	addr:street : Gosfield Street
# 	building : apartments
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
#
#
# [Building]
# id: 40825883
# number of nodes : 18
# Tags :
# 	addr:city : London
# 	addr:housename : Rembrandt House
# 	addr:housenumber : 100
# 	addr:street : Great Portland Street
# 	building : apartments
# 	building:levels : 5
# 	building:material : brick
# 	name : Rembrandt House
#
#
# [Building]
# id: 40835925
# number of nodes : 10
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Gosfield Street
# 	building : apartments
# 	building:levels : 4
# 	building:material : brick
#
#
# [Building]
# id: 40835926
# number of nodes : 12
# Tags :
# 	addr:housenumber : 29
# 	addr:street : Langham Street
# 	building : apartments
# 	building:levels : 5
# 	building:material : brick
# 	name : Hogarth Mansion
# 	source:addr:housenumber : photo
#
#
# [Building]
# id: 40835927
# number of nodes : 26
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 31-35
# 	addr:street : Langham Street
# 	building : hotel
# 	building:colour : white
# 	building:levels : 4
# 	building:material : brick
# 	name : The Langham Court Hotel
# 	old_name : Howard de Walden Nurses Home
# 	roof:levels : 1
# 	source : Bing;photograph;survey
# 	stars : 4
# 	survey:date : 2016-06-11
# 	tourism : hotel
# 	wheelchair : limited
# 	wikidata : Q27080763
#
#
# [Building]
# id: 40835928
# number of nodes : 15
# Tags :
# 	addr:housenumber : 71
# 	addr:street : Great Titchfield Street
# 	amenity : restaurant
# 	building : retail
# 	building:colour : light_brown
# 	building:levels : 4
# 	building:material : brick
# 	cuisine : italian
# 	description : "Restaurant & wine bar"
# 	name : Bellaria
# 	opening_hours : Mo,Tu 12:00-15:00,17:30-22:30; Th-Sa 12:00-22:30
# 	outdoor_seating : yes
# 	phone : +44 20 7580 8075
# 	website : https://www.bellariarestaurant.co.uk/
# 	wheelchair : yes
#
#
# [Building]
# id: 40835930
# number of nodes : 13
# Tags :
# 	addr:housenumber : 79
# 	addr:street : Great Titchfield Street
# 	building : residential
#
#
# [Building]
# id: 40836229
# number of nodes : 13
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Candover Street
# 	building : residential
# 	building:levels : 5
# 	building:material : brick
# 	name : Tower House
# 	source : Bing;photograph
# 	wikidata : Q26319306
#
#
# [Building]
# id: 40836230
# number of nodes : 13
# Tags :
# 	addr:housename : Oakley House
# 	addr:housenumber : 61
# 	addr:street : Riding House Street
# 	building : residential
# 	building:levels : 5
# 	building:material : brick
# 	name : Oakley House
# 	source : Bing;photograph
#
#
# [Building]
# id: 40836231
# number of nodes : 12
# Tags :
# 	addr:housename : Belmont House
# 	addr:housenumber : 6
# 	addr:street : Candover Street
# 	building : residential
# 	building:levels : 5
# 	name : Belmont House
# 	source : Bing;photograph
# 	wikidata : Q26319307
#
#
# [Building]
# id: 40836234
# number of nodes : 16
# Tags :
# 	addr:housenumber : 33
# 	addr:street : Foley Street
# 	building : commercial
# 	building:levels : 5
# 	building:material : brick
# 	source : Bing;photograph
#
#
# [Building]
# id: 40836293
# number of nodes : 11
# Tags :
# 	addr:housenumber : 52
# 	addr:street : Langham Street
# 	building : yes
# 	building:levels : 5
# 	name : Romney Mansions
#
#
# [Building]
# id: 40836294
# number of nodes : 10
# Tags :
# 	addr:housenumber : 67
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836295
# number of nodes : 5
# Tags :
# 	addr:housenumber : 65
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836296
# number of nodes : 5
# Tags :
# 	addr:housenumber : 63
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836297
# number of nodes : 5
# Tags :
# 	addr:housenumber : 61
# 	addr:street : Great Titchfield Street
# 	building : residential
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836298
# number of nodes : 5
# Tags :
# 	addr:housenumber : 59
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836299
# number of nodes : 5
# Tags :
# 	addr:housenumber : 57
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	craft : photographer
# 	name : Kube Studios
# 	roof:levels : 1
# 	website : http://kubestudios.co.uk/#/kube-studios-london/
#
#
# [Building]
# id: 40836300
# number of nodes : 5
# Tags :
# 	addr:housenumber : 55
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	name : Kall Kwik
# 	roof:levels : 1
# 	shop : copyshop
#
#
# [Building]
# id: 40836301
# number of nodes : 7
# Tags :
# 	building : retail
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836302
# number of nodes : 5
# Tags :
# 	addr:housenumber : 29
# 	addr:street : Riding House Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	shop : vacant
#
#
# [Building]
# id: 40836303
# number of nodes : 5
# Tags :
# 	addr:housenumber : 1
# 	addr:street : Middleton Place
# 	building : house
# 	building:colour : light_brown
# 	building:levels : 3
# 	building:material : brick
#
#
# [Building]
# id: 40836304
# number of nodes : 5
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Middleton Place
# 	building : house
# 	building:colour : light_brown
# 	building:levels : 3
# 	building:material : brick
#
#
# [Building]
# id: 40836305
# number of nodes : 5
# Tags :
# 	addr:housenumber : 4
# 	addr:street : Middleton Place
# 	building : house
# 	building:colour : light_brown
# 	building:levels : 3
# 	building:material : brick
#
#
# [Building]
# id: 40836306
# number of nodes : 12
# Tags :
# 	addr:housenumber : 6a
# 	addr:street : Middleton Place
# 	building : yes
# 	building:colour : white
# 	building:levels : 2
# 	building:material : plaster
#
#
# [Building]
# id: 40836307
# number of nodes : 5
# Tags :
# 	addr:housenumber : 3
# 	addr:street : Middleton Place
# 	building : house
# 	building:colour : light_brown
# 	building:levels : 3
# 	building:material : brick
#
#
# [Building]
# id: 40836499
# number of nodes : 21
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40836500
# number of nodes : 7
# Tags :
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	roof:levels : 1
# 	source : yahoo
#
#
# [Building]
# id: 40836501
# number of nodes : 15
# Tags :
# 	addr:housenumber : 78-80
# 	addr:street : Great Portland Street
# 	building : yes
# 	building:levels : 4
# 	source : yahoo
#
#
# [Building]
# id: 40836502
# number of nodes : 5
# Tags :
# 	addr:housenumber : 21-23
# 	addr:street : Riding House Street
# 	building : yes
# 	building:levels : 3
# 	source : yahoo
#
#
# [Building]
# id: 40836503
# number of nodes : 6
# Tags :
# 	addr:city : London
# 	addr:housenumber : 25-27
# 	addr:street : Riding House Street
# 	building : yes
# 	building:colour : light_brown
# 	building:levels : 3
# 	building:material : brick
# 	name : Cheerful Scout
# 	source : yahoo
#
#
# [Building]
# id: 40836505
# number of nodes : 7
# Tags :
# 	addr:housenumber : 11
# 	addr:street : Middleton Place
# 	building : house
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	source : Bing;photograph
#
#
# [Building]
# id: 40836506
# number of nodes : 8
# Tags :
# 	addr:housenumber : 9
# 	addr:street : Middleton Place
# 	building : house
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	source : Bing;photograph
#
#
# [Building]
# id: 40836507
# number of nodes : 8
# Tags :
# 	addr:housenumber : 8
# 	addr:street : Middleton Place
# 	building : house
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	source : Bing;photograph
#
#
# [Building]
# id: 40836508
# number of nodes : 9
# Tags :
# 	addr:housenumber : 6
# 	addr:street : Middleton Place
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	source : Bing;photograph
#
#
# [Building]
# id: 40836510
# number of nodes : 10
# Tags :
# 	addr:city : London
# 	addr:housenumber : 94
# 	addr:street : Great Portland Street
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	shop : yes
# 	source : Bing
#
#
# [Building]
# id: 40836512
# number of nodes : 7
# Tags :
# 	addr:housenumber : 44
# 	addr:street : Langham Street
# 	building : residential
# 	building:levels : 4
# 	building:material : brick
# 	source : Bing;photograph
#
#
# [Building]
# id: 40836837
# number of nodes : 10
# Tags :
# 	addr:housenumber : 60
# 	addr:street : Great Portland Street
# 	building : commercial
# 	building:levels : 6
#
#
# [Building]
# id: 40836839
# number of nodes : 14
# Tags :
# 	addr:housenumber : 42-44
# 	addr:postcode : W1W 7RJ
# 	addr:street : Mortimer Street
# 	building : retail
# 	building:levels : 5
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836843
# number of nodes : 16
# Tags :
# 	addr:housenumber : 3-4
# 	addr:street : Little Portland Street
# 	building : commercial
# 	source : yahoo
#
#
# [Building]
# id: 40836844
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 50
# 	addr:postcode : W1W 7ND
# 	addr:street : Great Portland Street
# 	building : yes
# 	building:levels : 5
# 	description : Shoe repairs, watch repairs, key cutting, engraving, dry cleaning, passport photos
# 	name : Mr Craftsman's Workshop
# 	phone : +44 207 636 7753
# 	roof:levels : 1
# 	shop : shoe_repair
# 	source : Bing;photographic_survey
# 	website : http://mrcraftsmanswork.com
#
#
# [Building]
# id: 40836845
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:housenumber : 54-56
# 	addr:postcode : W1W 7NE
# 	addr:street : Great Portland Street
# 	amenity : post_office
# 	brand : Post Office
# 	building : retail
# 	building:levels : 4
# 	building:material : brick
# 	name : Great Portland Street Post Office
# 	ref:pol_id : 19586
# 	roof:levels : 1
# 	source : Bing;photographic_survey
# 	wheelchair : limited
#
#
# [Building]
# id: 40836846
# number of nodes : 8
# Tags :
# 	addr:housenumber : 26-28
# 	addr:street : Great Portland Street
# 	building : commercial
# 	building:levels : 6
# 	source : yahoo
#
#
# [Building]
# id: 40836848
# number of nodes : 7
# Tags :
# 	addr:housenumber : 20
# 	addr:street : Margaret Street
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40836850
# number of nodes : 9
# Tags :
# 	addr:housenumber : 15-16
# 	addr:street : Margaret Street
# 	building : commercial
# 	building:levels : 5
# 	source : yahoo
#
#
# [Building]
# id: 40836851
# number of nodes : 10
# Tags :
# 	addr:housenumber : 26
# 	addr:street : Little Portland Street
# 	building : yes
# 	building:levels : 5
# 	name : Circus House
# 	source : yahoo
#
#
# [Building]
# id: 40836852
# number of nodes : 9
# Tags :
# 	addr:housenumber : 15-19
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	name : Golderbrock House
# 	roof:levels : 1
# 	roof:shape : quadruple_saltbox
# 	source : yahoo
#
#
# [Building]
# id: 40836853
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:levels : 6
# 	source : yahoo
#
#
# [Building]
# id: 40836854
# number of nodes : 7
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40836855
# number of nodes : 5
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40836856
# number of nodes : 5
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40837400
# number of nodes : 14
# Tags :
# 	addr:city : London
# 	addr:housename : The White House
# 	addr:housenumber : 26
# 	addr:street : Mortimer Street
# 	building : retail
# 	building:levels : 5
# 	roof:levels : 0
# 	source : Bing;photograph
#
#
# [Building]
# id: 40837404
# number of nodes : 12
# Tags :
# 	addr:city : London
# 	addr:housenumber : 56
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	name : Morplan
# 	source : Bing;photograph
#
#
# [Building]
# id: 40837407
# number of nodes : 14
# Tags :
# 	addr:city : London
# 	addr:housenumber : 60-62
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : light_brown
# 	building:levels : 4
# 	building:material : brick
# 	source : yahoo
#
#
# [Building]
# id: 40837408
# number of nodes : 25
# Tags :
# 	building : office
# 	building:levels : 5
# 	roof:levels : 1
# 	roof:shape : flat
# 	source : Bing;photograph
#
#
# [Building]
# id: 40837416
# number of nodes : 7
# Tags :
# 	addr:housenumber : 14-18
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	name : Great Titchfield House
# 	source : yahoo
#
#
# [Building]
# id: 40837417
# number of nodes : 24
# Tags :
# 	addr:housenumber : 20-30
# 	addr:street : Great Titchfield Street
# 	building : commercial
# 	building:levels : 5
# 	building:material : brick
# 	name : Elsley House and Elsley Court
# 	roof:levels : 1
# 	source : yahoo
#
#
# [Building]
# id: 40837421
# number of nodes : 12
# Tags :
# 	addr:housenumber : 7
# 	addr:postcode : W1D 2JB
# 	addr:street : Margaret Street
# 	alt_name : All Saints Margaret Street
# 	amenity : place_of_worship
# 	building : yes
# 	denomination : anglican
# 	name : All Saints
# 	religion : christian
# 	source : yahoo
# 	wikidata : Q4729371
# 	wikipedia : en:All Saints, Margaret Street
#
#
# [Building]
# id: 40837812
# number of nodes : 9
# Tags :
# 	addr:housenumber : 60-62
# 	addr:street : Margaret Street
# 	building : yes
#
#
# [Building]
# id: 40837814
# number of nodes : 8
# Tags :
# 	addr:housenumber : 5-7
# 	addr:street : Great Titchfield Street
# 	building : commercial
#
#
# [Building]
# id: 40837815
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:housename : Kent House
# 	addr:housenumber : 14-17
# 	addr:postcode : W1W 8AJ
# 	addr:street : Market place
# 	building : yes
# 	name : Kent House
#
#
# [Building]
# id: 40837816
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 11-13
# 	addr:street : Market Place
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 40837817
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 9/10
# 	addr:street : Market Place
# 	building : yes
#
#
# [Building]
# id: 40837818
# number of nodes : 7
# Tags :
# 	addr:housenumber : 7-8
# 	addr:street : Market Place
# 	building : commercial
#
#
# [Building]
# id: 40837820
# number of nodes : 9
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40837861
# number of nodes : 8
# Tags :
# 	building : commercial
# 	building:levels : 5
# 	building:material : stone
# 	name : Highlight House
#
#
# [Building]
# id: 40837862
# number of nodes : 6
# Tags :
# 	addr:housenumber : 58-59
# 	addr:street : Margaret Street
# 	building : yes
#
#
# [Building]
# id: 40837863
# number of nodes : 5
# Tags :
# 	addr:housenumber : 14-16
# 	addr:street : Great Portland Street
# 	building : retail
#
#
# [Building]
# id: 40837864
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40837865
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40840754
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40840755
# number of nodes : 16
# Tags :
# 	addr:street : Margaret Street
# 	building : commercial
#
#
# [Building]
# id: 40840756
# number of nodes : 15
# Tags :
# 	addr:housenumber : 75-77
# 	addr:street : Margaret Street
# 	building : commercial
#
#
# [Building]
# id: 40840758
# number of nodes : 10
# Tags :
# 	addr:housenumber : 41-42
# 	addr:street : Eastcastle Street
# 	building : commercial
# 	building:levels : 5
#
#
# [Building]
# id: 40840761
# number of nodes : 7
# Tags :
# 	addr:housenumber : 8-10
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 40840762
# number of nodes : 7
# Tags :
# 	addr:housenumber : 31-32
# 	addr:street : Eastcastle Street
# 	building : commercial
# 	building:levels : 4
# 	name : Shelana House
#
#
# [Building]
# id: 40840764
# number of nodes : 16
# Tags :
# 	addr:housenumber : 23-25
# 	addr:street : Eastcastle Street
# 	building : commercial
# 	building:levels : 7
#
#
# [Building]
# id: 40840766
# number of nodes : 6
# Tags :
# 	addr:housenumber : 16-19
# 	addr:street : Eastcastle Street
# 	building : commercial
# 	building:levels : 5
# 	name : Eastgate House
#
#
# [Building]
# id: 40858234
# number of nodes : 9
# Tags :
# 	building : yes
# 	building:levels : 8
# 	name : Wingate House
# 	note : Check exact building shape.
#
#
# [Building]
# id: 40858235
# number of nodes : 10
# Tags :
# 	building : residential
# 	building:levels : 16
# 	height : 52
# 	name : Kemp House
#
#
# [Building]
# id: 40858239
# number of nodes : 5
# Tags :
# 	building : yes
# 	fixme : Multiple buildings to split
#
#
# [Building]
# id: 40858241
# number of nodes : 6
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40858242
# number of nodes : 20
# Tags :
# 	addr:housenumber : 58
# 	addr:street : Dean Street
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	name : Kemble House
#
#
# [Building]
# id: 40863620
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40863621
# number of nodes : 7
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Bourdon Street
# 	building : apartments
# 	name : St George's Buildings
#
#
# [Building]
# id: 40863633
# number of nodes : 13
# Tags :
# 	building : retail
# 	building:levels : 5
# 	building:material : stone
# 	roof:colour : grey
# 	roof:levels : 1
#
#
# [Building]
# id: 40863662
# number of nodes : 11
# Tags :
# 	building : yes
# 	building:levels : 7
# 	roof:levels : 2
#
#
# [Building]
# id: 40863703
# number of nodes : 24
# Tags :
# 	addr:city : London
# 	addr:housename : Regent House
# 	addr:street : Regent Street
# 	building : yes
# 	building:colour : light_grey
# 	building:levels : 5
# 	building:material : stone
# 	name : Regent House
# 	roof:levels : 1
#
#
# [Building]
# id: 40863709
# number of nodes : 6
# Tags :
# 	addr:housenumber : 25
# 	addr:street : St George Street
# 	building : commercial
#
#
# [Building]
# id: 40863714
# number of nodes : 14
# Tags :
# 	addr:housenumber : 325-329
# 	addr:street : Oxford Street
# 	building : yes
# 	building:levels : 5
# 	name : Burlian House
#
#
# [Building]
# id: 40863715
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:housenumber : 74
# 	addr:street : New Bond Street
# 	building : yes
# 	building:levels : 5
# 	building:material : stone
# 	name : Watches Of Bond Street
# 	shop : watches
#
#
# [Building]
# id: 40863717
# number of nodes : 6
# Tags :
# 	addr:housenumber : 51-52
# 	addr:street : New Bond Street
# 	building : yes
# 	building:levels : 5
# 	building:material : stone
# 	name : Emporio Armani
# 	name:zh : 阿玛尼邦德街分店
# 	phone : +44 20 7491 8080
# 	shop : clothes
# 	website : https://www.armani.com/
#
#
# [Building]
# id: 40863718
# number of nodes : 10
# Tags :
# 	addr:housenumber : 23-29
# 	addr:street : Maddox Street
# 	building : yes
#
#
# [Building]
# id: 40863722
# number of nodes : 12
# Tags :
# 	addr:housenumber : 7-10
# 	addr:street : Hanover Square
# 	building : commercial
# 	building:architecture : brutalism
# 	building:levels : 7
# 	building:material : concrete
# 	name : 7-10 Hanover Square
#
#
# [Building]
# id: 40863723
# number of nodes : 13
# Tags :
# 	addr:housenumber : 89
# 	addr:street : New Bond Street
# 	building : yes
# 	name : Lumina House
#
#
# [Building]
# id: 40863728
# number of nodes : 9
# Tags :
# 	addr:housenumber : 15
# 	addr:street : Bourdon Street
# 	building : yes
# 	name : Grosvenor Hill Court
#
#
# [Building]
# id: 40916590
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housename : Victoria House
# 	addr:housenumber : 37-63
# 	addr:street : Southampton Row
# 	building : commercial
# 	building:colour : light_grey
# 	building:levels : 5
# 	building:material : stone
# 	note : Also including 1-12 Victoria Colonnade
# 	roof:levels : 2
# 	wikidata : Q18667468
#
#
# [Building]
# id: 40952618
# number of nodes : 6
# Tags :
# 	building : yes
# 	leisure : fitness_centre
# 	name : Soho Fitness Lab
#
#
# [Building]
# id: 40952627
# number of nodes : 18
# Tags :
# 	building : yes
# 	building:colour : grey
# 	building:levels : 4
# 	roof:colour : grey
# 	roof:levels : 1
#
#
# [Building]
# id: 40952629
# number of nodes : 5
# Tags :
# 	building : service
# 	note : access to electricity sub-station
# 	opened : 1925
#
#
# [Building]
# id: 41117897
# number of nodes : 11
# Tags :
# 	building : yes
# 	source : guestimation from ground observation
#
#
# [Building]
# id: 41117902
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 41117905
# number of nodes : 8
# Tags :
# 	building : yes
#
#
# [Building]
# id: 41117906
# number of nodes : 12
# Tags :
# 	building : yes
# 	layer : 1
# 	source : Bing
#
#
# [Building]
# id: 41117907
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:housenumber : 101-103
# 	addr:postcode : WC1A 1DB
# 	addr:street : New Oxford Street
# 	building : yes
# 	building:architecture : brutalism
# 	building:levels : 34
# 	building:material : concrete
# 	height : 117
# 	name : Centre Point Tower
# 	name:he : סנטר פוינט
# 	source : Bing
# 	source:height : http://www.urban75.org/london/centrepoint.html
# 	wikidata : Q2339039
# 	wikimedia_commons : Category:Centre_Point
# 	wikipedia : en:Centre Point
#
#
# [Building]
# id: 41118172
# number of nodes : 21
# Tags :
# 	building : yes
# 	building:colour : brown
# 	building:levels : 6
# 	building:material : brick
# 	note : space in the middle seen from yahoo, is private and not ground floor. raised level terrace with swimming pool
# 	roof:colour : dark_grey
# 	source : yahoo;Bing;photo
#
#
# [Building]
# id: 42155129
# number of nodes : 12
# Tags :
# 	addr:housenumber : 26
# 	addr:postcode : WC1E 7BT
# 	addr:street : Store Street
# 	building : office
# 	building:colour : grey
# 	building:levels : 4
# 	building:material : stone
# 	name : The Building Centre
# 	opening_hours : Mo-Fr 09:00-18:00; Sa 10:00-14:00
# 	wheelchair : yes
#
#
# [Building]
# id: 42785351
# number of nodes : 10
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 42785389
# number of nodes : 15
# Tags :
# 	addr:city : London
# 	addr:housenumber : 232-233
# 	addr:postcode : WC1V 7DA
# 	addr:street : High Holborn
# 	brand : Superdrug
# 	brand:wikidata : Q7643261
# 	brand:wikipedia : en:Superdrug
# 	building : retail
# 	building:levels : 7
# 	building:material : plaster
# 	fhrs:id : 423787
# 	fhrs:local_authority_id : 12531
# 	name : Superdrug
# 	operator : Superdrug Stores Plc
# 	shop : chemist
#
#
# [Building]
# id: 42785390
# number of nodes : 17
# Tags :
# 	building : train_station
# 	building:levels : 6
# 	building:material : sandstone
# 	name : Holborn
# 	wheelchair : no
#
#
# [Building]
# id: 42785391
# number of nodes : 11
# Tags :
# 	addr:city : London
# 	addr:housename : Africa House
# 	addr:housenumber : 64-68
# 	addr:postcode : WC2B 6BG
# 	addr:street : Kingsway
# 	building : yes
# 	building:colour : silver
# 	building:levels : 8
# 	building:material : sandstone
# 	roof:colour : black
# 	roof:levels : 1
# 	roof:shape : mansard
# 	wikidata : Q27086661
#
#
# [Building]
# id: 42786635
# number of nodes : 13
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 203
# 	addr:street : High Holborn
# 	building : yes
# 	note : Shops on ground floor, office on upper floors
# 	source : yahoo;Bing;survey
#
#
# [Building]
# id: 42786636
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	building : yes
# 	name : Reed.co.uk
# 	source : Bing;survey
#
#
# [Building]
# id: 42786637
# number of nodes : 5
# Tags :
# 	building : yes
# 	levels : 13
#
#
# [Building]
# id: 44426447
# number of nodes : 36
# Tags :
# 	addr:housename : Congress House
# 	addr:postcode : WC1B 3LS
# 	addr:street : Great Russell Street
# 	alt_name : TUC
# 	building : commercial
# 	building:levels : 7
# 	name : Trades Union Congress
# 	office : ngo
# 	wikidata : Q5160797
#
#
# [Building]
# id: 44521980
# number of nodes : 27
# Tags :
# 	addr:city : London
# 	addr:housenumber : 10
# 	addr:postcode : W1T 3NP
# 	addr:street : Berners Street
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	name : The London EDITION
# 	phone : +44 20 7781 0000
# 	ref : LONEB
# 	roof:levels : 2
# 	tourism : hotel
# 	website : https://www.editionhotels.com/london/
#
#
# [Building]
# id: 44599803
# number of nodes : 22
# Tags :
# 	addr:city : London
# 	addr:postcode : WC2E 7BB
# 	addr:street : Covent Garden Piazza
# 	building : yes
# 	building:levels : 2
# 	building:material : brick
# 	contact:phone : +44 20 73796344
# 	contact:website : http://www.ltmuseum.co.uk/
# 	fee : yes
# 	name : London Transport Museum
# 	name:fr : Musée du transport de Londres
# 	opening_hours : Mo-Su 10:00-17:15; Fr 11:00-17:15
# 	operator : Transport for London (TfL)
# 	roof:colour : dark_grey
# 	toilets:wheelchair : yes
# 	tourism : museum
# 	website : https://www.ltmuseum.co.uk/
# 	wheelchair : yes
# 	wikidata : Q1541098
# 	wikipedia : en:London Transport Museum
#
#
# [Building]
# id: 45405644
# number of nodes : 21
# Tags :
# 	addr:housenumber : 33
# 	addr:street : Cavendish Square
# 	building : yes
# 	building:levels : 3
# 	building:part : yes
# 	disused:shop : department_store
# 	height : 10
# 	name : BHS
# 	note:building:levels : this value and height for plinth, see building parts for taller areas
#
#
# [Building]
# id: 45405645
# number of nodes : 10
# Tags :
# 	addr:housenumber : 300
# 	addr:postcode : W1C 1DX
# 	addr:street : Oxford Street
# 	brand : John Lewis
# 	brand:wikidata : Q1918981
# 	brand:wikipedia : en:John Lewis & Partners
# 	building : yes
# 	building:levels : 8
# 	name : John Lewis
# 	official_name : John Lewis & Partners
# 	opening_hours : Mo-Sa 09:30-20:00; Su 11:30-18:00
# 	roof:colour : grey
# 	shop : department_store
# 	toilets:wheelchair : yes
# 	wheelchair : yes
#
#
# [Building]
# id: 45405646
# number of nodes : 6
# Tags :
# 	addr:housenumber : 318
# 	addr:street : Oxford Street
# 	brand : House of Fraser
# 	brand:wikidata : Q5928422
# 	brand:wikipedia : en:House of Fraser
# 	building : yes
# 	building:levels : 6
# 	name : House of Fraser
# 	old_name : D H Evans
# 	operator : John Lewis
# 	payment:cash : yes
# 	payment:mastercard : yes
# 	payment:visa : yes
# 	shop : department_store
# 	toilets : yes
# 	toilets:wheelchair : yes
# 	wheelchair : yes
# 	wikidata : Q27996008
#
#
# [Building]
# id: 45405648
# number of nodes : 6
# Tags :
# 	building : yes
# 	building:colour : grey
# 	building:levels : 5
# 	building:material : stone
# 	roof:colour : grey
#
#
# [Building]
# id: 46129307
# number of nodes : 14
# Tags :
# 	addr:street : Lincoln's Inn, Newman's Row
# 	building : yes
# 	name : The Great Hall
# 	photo : http://commons.wikimedia.org/wiki/File:The_Great_Hall,_Lincoln%27s_Inn,_Newman%27s_Row_WC2.jpeg
# 	source : Wikimedia Commons; Bing
#
#
# [Building]
# id: 48180830
# number of nodes : 24
# Tags :
# 	building : yes
#
#
# [Building]
# id: 48180833
# number of nodes : 15
# Tags :
# 	building : yes
# 	building:colour : light_grey
# 	building:levels : 5
# 	building:material : stone
# 	roof:levels : 1
# 	source : Bing;photograph
#
#
# [Building]
# id: 48180836
# number of nodes : 25
# Tags :
# 	addr:housenumber : 208-222
# 	addr:street : Regent Street
# 	building : yes
# 	building:colour : light_grey
# 	building:levels : 6
# 	building:material : stone
# 	name : Liberty House
# 	source : Bing;photograph
# 	wikidata : Q27081355
#
#
# [Building]
# id: 48180840
# number of nodes : 17
# Tags :
# 	building : yes
#
#
# [Building]
# id: 48180841
# number of nodes : 22
# Tags :
# 	addr:housenumber : 224-244
# 	addr:street : Regent Street
# 	building : yes
# 	building:levels : 5
# 	building:material : stone
# 	roof:levels : 1
# 	source : Bing;photograph
#
#
# [Building]
# id: 48545563
# number of nodes : 16
# Tags :
# 	building : yes
# 	fixme : Multiple buildings to split
# 	source : yahoo
#
#
# [Building]
# id: 48545564
# number of nodes : 20
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 48545565
# number of nodes : 11
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 48545566
# number of nodes : 44
# Tags :
# 	building : yes
# 	fixme : Multiple buildings to split
# 	source : yahoo
#
#
# [Building]
# id: 48545568
# number of nodes : 33
# Tags :
# 	addr:street : Newport Court
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 48545570
# number of nodes : 11
# Tags :
# 	addr:housenumber : 138-140
# 	addr:postcode : WC2H 8HB
# 	addr:street : Shaftesbury Avenue
# 	amenity : fast_food
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	name : Wingstop
# 	roof:levels : 1
# 	source : Bing
#
#
# [Building]
# id: 48545571
# number of nodes : 24
# Tags :
# ...
# 	building:levels : 5
#
#
# [Building]
# id: 661632243
# number of nodes : 5
# Tags :
# 	addr:housenumber : 12
# 	addr:street : John Prince's Street
# 	building : commercial
#
#
# [Building]
# id: 661632244
# number of nodes : 5
# Tags :
# 	addr:housenumber : 13
# 	addr:street : John Prince's Street
# 	building : commercial
#
#
# [Building]
# id: 661632245
# number of nodes : 5
# Tags :
# 	addr:housenumber : 39
# 	addr:street : Margaret Street
# 	amenity : cafe
# 	building : yes
# 	name : Sally White
# 	website : http://sallywhite.co.uk/
# [Building]
# id: 662261305
# number of nodes : 5
# Tags :
# 	addr:housenumber : 317
# 	addr:street : Regent Street
# 	building : yes
# 	name : Indialinks
# 	shop : clothes
#
#
# [Building]
# id: 662415975
# number of nodes : 6
# Tags :
# 	addr:housenumber : 1
# 	addr:street : Cavendish Square
# 	building : yes
# 	building:levels : 1
#
#
# [Building]
# id: 662571730
# number of nodes : 5
# Tags :
# 	addr:housenumber : 10
# 	addr:street : Dean's Mews
# 	building : residential
# 	building:levels : 2
#
#
# [Building]
# id: 662571731
# number of nodes : 6
# Tags :
# 	addr:housenumber : 9
# 	addr:street : Dean's Mews
# 	building : residential
# 	building:levels : 3
#
#
# [Building]
# id: 662571732
# number of nodes : 7
# Tags :
# 	addr:housenumber : 8
# 	addr:street : Dean's Mews
# 	building : residential
# 	building:levels : 3
#
#
# [Building]
# id: 662571733
# number of nodes : 6
# Tags :
# 	addr:housenumber : 7
# 	addr:street : Dean's Mews
# 	building : residential
# 	building:levels : 3
#
#
# [Building]
# id: 662571734
# number of nodes : 18
# Tags :
# 	addr:city : London
# 	addr:housenumber : 14
# 	addr:street : Cavendish Square
# 	building : yes
#
#
# [Building]
# id: 662571735
# number of nodes : 9
# Tags :
# 	addr:housenumber : 15
# 	addr:street : Cavendish Square
# 	building : residential
# 	building:levels : 4
#
#
# [Building]
# id: 662581894
# number of nodes : 6
# Tags :
# 	addr:housenumber : 16
# 	addr:street : Cavendish Square
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 662598158
# number of nodes : 7
# Tags :
# 	addr:housenumber : 17
# 	addr:street : Cavendish Square
# 	building : commercial
# 	building:levels : 4
# 	roof:levels : 1
# 	wikidata : Q15261567
#
#
# [Building]
# id: 662598159
# number of nodes : 13
# Tags :
# 	addr:housenumber : 18
# 	addr:street : Cavendish Square
# 	building : commercial
#
#
# [Building]
# id: 663375905
# number of nodes : 9
# Tags :
# 	addr:housenumber : 324
# 	addr:street : Oxford Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 664315342
# number of nodes : 7
# Tags :
# 	addr:housenumber : 3-9
# 	addr:street : Wigmore Street
# 	building : retail
#
#
# [Building]
# id: 664315343
# number of nodes : 11
# Tags :
# 	addr:housenumber : 11-15
# 	addr:street : Wigmore Street
# 	building : yes
# 	building:levels : 7
# 	name : Cavendish Court
#
#
# [Building]
# id: 666407252
# number of nodes : 5
# Tags :
# 	addr:housenumber : 4
# 	addr:street : Cavendish Place
# 	building : commercial
# 	building:levels : 5
#
#
# [Building]
# id: 666407253
# number of nodes : 5
# Tags :
# 	addr:housenumber : 6
# 	addr:street : Cavendish Place
# 	building : commercial
# 	building:levels : 5
#
#
# [Building]
# id: 666407254
# number of nodes : 5
# Tags :
# 	addr:housenumber : 8
# 	addr:street : Cavendish Place
# 	building : commercial
# 	building:levels : 5
#
#
# [Building]
# id: 666407255
# number of nodes : 5
# Tags :
# 	addr:housenumber : 10
# 	addr:street : Cavendish Place
# 	building : commercial
# 	building:levels : 5
#
#
# [Building]
# id: 666407256
# number of nodes : 6
# Tags :
# 	addr:housenumber : 12
# 	addr:street : Cavendish Place
# 	building : commercial
# 	building:levels : 3
# 	roof:levels : 1
# 	roof:shape : gambrel
#
#
# [Building]
# id: 666407257
# number of nodes : 7
# Tags :
# 	addr:housenumber : 14
# 	addr:street : Cavendish Place
# 	building : commercial
# 	building:levels : 4
#
#
# [Building]
# id: 666417782
# number of nodes : 5
# Tags :
# 	addr:housenumber : 1-5
# 	addr:street : Queen Anne Mews
# 	building : residential
# 	building:levels : 3
#
#
# [Building]
# id: 666417783
# number of nodes : 5
# Tags :
# 	addr:housenumber : 9
# 	addr:street : Queen Anne Street
# 	building : yes
#
#
# [Building]
# id: 666417784
# number of nodes : 5
# Tags :
# 	addr:housenumber : 11
# 	addr:street : Queen Anne Street
# 	building : yes
#
#
# [Building]
# id: 666417785
# number of nodes : 5
# Tags :
# 	addr:housenumber : 13
# 	addr:street : Queen Anne Street
# 	building : yes
#
#
# [Building]
# id: 666570082
# number of nodes : 50
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Mansfield Street
# 	building : residential
# 	building:levels : 6
# 	roof:levels : 1
#
#
# [Building]
# id: 666574224
# number of nodes : 8
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Queen Anne Street
# 	building : yes
# 	name : Chandos House
# 	wikidata : Q5071247
#
#
# [Building]
# id: 666574225
# number of nodes : 9
# Tags :
# 	addr:housenumber : 6
# 	addr:street : Chandos Street
# 	building : yes
# 	country : NA
# 	diplomatic : embassy
# 	embassy : high_commission
# 	name : High Commission of Namibia
# 	office : diplomatic
# 	target : GB
# 	wikidata : Q16843021
#
#
# [Building]
# id: 666574892
# number of nodes : 7
# Tags :
# 	addr:housenumber : 4
# 	addr:street : Chandos Street
# 	building : yes
#
#
# [Building]
# id: 666574893
# number of nodes : 7
# Tags :
# 	addr:housenumber : 3
# 	addr:street : Chandos Street
# 	building : yes
#
#
# [Building]
# id: 666574894
# number of nodes : 7
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Chandos Street
# 	building : yes
#
#
# [Building]
# id: 666812938
# number of nodes : 7
# Tags :
# 	addr:housenumber : 10
# 	addr:street : Duchess Street
# 	building : commercial
# 	wikidata : Q27084655
#
#
# [Building]
# id: 669874405
# number of nodes : 8
# Tags :
# 	addr:housenumber : 18
# 	addr:street : Mansfield Street
# 	building : residential
# 	building:levels : 4
#
#
# [Building]
# id: 669874406
# number of nodes : 8
# Tags :
# 	addr:housenumber : 20
# 	addr:street : Mansfield Street
# 	building : residential
#
#
# [Building]
# id: 669874407
# number of nodes : 7
# Tags :
# 	addr:housenumber : 18-20
# 	addr:street : Duchess Mews
# 	building : residential
# 	building:levels : 2
#
#
# [Building]
# id: 669875310
# number of nodes : 5
# Tags :
# 	addr:housenumber : 22
# 	addr:street : Mansfield Street
# 	building : residential
# 	building:levels : 4
#
#
# [Building]
# id: 669879249
# number of nodes : 9
# Tags :
# 	addr:housenumber : 10
# 	addr:street : Queen Anne Street
# 	building : residential
# 	building:levels : 4
#
#
# [Building]
# id: 669882378
# number of nodes : 6
# Tags :
# 	addr:housenumber : 12
# 	addr:street : Queen Anne Street
# 	building : residential
#
#
# [Building]
# id: 669882379
# number of nodes : 11
# Tags :
# 	addr:housenumber : 30
# 	addr:street : Harley Street
# 	building : residential
#
#
# [Building]
# id: 669882380
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 669882381
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 669882382
# number of nodes : 6
# Tags :
# 	addr:housenumber : 40
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : clinic
# 	name : Care Oncology Clinic
# 	website : https://careoncologyclinic.com/
#
#
# [Building]
# id: 669882383
# number of nodes : 9
# Tags :
# 	addr:housenumber : 42
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
# 	name : The Natural Screening Centre Ltd
# 	website : http://www.thenaturalscreeningcentre.co.uk/
#
#
# [Building]
# id: 669882384
# number of nodes : 6
# Tags :
# 	addr:housenumber : 1
# 	addr:street : Mansfield Mews
# 	building : yes
# 	building:levels : 2
#
#
# [Building]
# id: 669882385
# number of nodes : 6
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Mansfield Mews
# 	building : residential
# 	building:levels : 3
#
#
# [Building]
# id: 669890679
# number of nodes : 5
# Tags :
# 	addr:housenumber : 52
# 	addr:street : Harley Street
# 	building : yes
# 	building:levels : 4
# 	healthcare : dentist
# 	name : Harley Street Dental Group
# 	website : https://www.harleystreetdentalgroup.org/
#
#
# [Building]
# id: 669890680
# number of nodes : 5
# Tags :
# 	addr:housenumber : 50
# 	addr:street : Harley Street
# 	building : yes
# 	building:levels : 4
# 	healthcare : clinic
# 	name : Doctors Surgery
#
#
# [Building]
# id: 669890681
# number of nodes : 5
# Tags :
# 	addr:housenumber : 48
# 	addr:street : Harley Street
# 	building : yes
# 	building:levels : 4
# 	healthcare : clinic
# 	name : Harley Street Skin Clinic
# 	website : https://www.harleystreetskinclinic.com/en/
#
#
# [Building]
# id: 669890682
# number of nodes : 5
# Tags :
# 	addr:housenumber : 46
# 	addr:street : Harley Street
# 	building : yes
# 	building:levels : 4
# 	healthcare : yes
# 	name : 46 Harley Street Dental Centre
#
#
# [Building]
# id: 669890683
# number of nodes : 5
# Tags :
# 	addr:housenumber : 44
# 	addr:street : Harley Street
# 	building : yes
# 	building:levels : 4
# 	healthcare : yes
# 	name : Consulting Rooms
#
#
# [Building]
# id: 669899572
# number of nodes : 8
# Tags :
# 	addr:housenumber : 14
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669899573
# number of nodes : 8
# Tags :
# 	addr:housenumber : 12
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669899574
# number of nodes : 7
# Tags :
# 	addr:housenumber : 10
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669899575
# number of nodes : 5
# Tags :
# 	addr:housenumber : 8
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669899576
# number of nodes : 9
# Tags :
# 	addr:housenumber : 6
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669899577
# number of nodes : 5
# Tags :
# 	addr:housenumber : 4
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669902343
# number of nodes : 5
# Tags :
# 	addr:housenumber : 9
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : clinic
# 	name : 9 Harley Street
#
#
# [Building]
# id: 669902344
# number of nodes : 5
# Tags :
# 	addr:housenumber : 11
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : doctor
# 	name : Isokinetic
#
#
# [Building]
# id: 670141392
# number of nodes : 10
# Tags :
# 	addr:housenumber : 13
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : doctor
#
#
# [Building]
# id: 670141393
# number of nodes : 9
# Tags :
# 	addr:housenumber : 15
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : doctor
#
#
# [Building]
# id: 670141394
# number of nodes : 11
# Tags :
# 	addr:housenumber : 17
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
#
#
# [Building]
# id: 670141395
# number of nodes : 9
# Tags :
# 	addr:housenumber : 19
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : clinic
# 	name : London Prostate
#
#
# [Building]
# id: 670141396
# number of nodes : 7
# Tags :
# 	addr:housenumber : 21
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
#
#
# [Building]
# id: 670141397
# number of nodes : 8
# Tags :
# 	addr:housenumber : 23
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
#
#
# [Building]
# id: 670141398
# number of nodes : 6
# Tags :
# 	addr:housenumber : 25
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
# 	name : 25 Harley Street
# 	website : https://www.25harleystreet.co.uk/
#
#
# [Building]
# id: 670141399
# number of nodes : 7
# Tags :
# 	addr:housenumber : 27
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
# 	name : Harley Street Medical Centre
# 	website : https://harleystreet-medicalcentre.com/
#
#
# [Building]
# id: 670141400
# number of nodes : 7
# Tags :
# 	addr:housenumber : 29
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 670141402
# number of nodes : 5
# Tags :
# 	addr:housenumber : 31
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : clinic
# 	name : Westminster Clinic
# 	website : https://www.westminsterclinic.co.uk/
#
#
# [Building]
# id: 670141404
# number of nodes : 7
# Tags :
# 	addr:housenumber : 33
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
#
#
# [Building]
# id: 670146229
# number of nodes : 5
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Wigmore Place
# 	building : house
# 	building:levels : 2
#
#
# [Building]
# id: 670146230
# number of nodes : 5
# Tags :
# 	addr:housenumber : 3
# 	addr:street : Wigmore Place
# 	building : yes
# 	building:levels : 3
#
#
# [Building]
# id: 670350843
# number of nodes : 8
# Tags :
# 	addr:city : London
# 	addr:housenumber : 38A
# 	addr:street : Tavistock Street
# 	amenity : cafe
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	name : Double Shot Coffee Co.
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 670350853
# number of nodes : 9
# Tags :
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 670350854
# number of nodes : 10
# Tags :
# 	addr:city : London
# 	addr:housename : Harlequin Court
# 	addr:housenumber : 20
# 	addr:street : Tavistock Street
# 	building : yes
# 	building:colour : white
# 	building:levels : 4
# 	roof:colour : dark_grey
# 	roof:levels : 1
# 	wikidata : Q27080715
#
#
# [Building]
# id: 670350868
# number of nodes : 13
# Tags :
# 	building : commercial
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	roof:levels : 1
#
#
# [Building]
# id: 670350869
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:housenumber : 34
# 	addr:postcode : WC2E 8NL
# 	addr:street : Henrietta Street
# 	amenity : bank
# 	atm : yes
# 	brand : NatWest
# 	brand:wikidata : Q2740021
# 	brand:wikipedia : en:NatWest
# 	building : commercial
# 	drive_through : no
# 	name : NatWest
# 	opening_hours : Mo-Tu, Th-Fr 09:00-17:00; We 10:00-17:00
#
#
# [Building]
# id: 670350872
# number of nodes : 19
# Tags :
# 	building : commercial
# 	building:levels : 5
# 	building:material : brick
# 	old_name : St Peter's Hospital
# 	roof:colour : dark_grey
# 	wikidata : Q18392694
#
#
# [Building]
# id: 670350873
# number of nodes : 9
# Tags :
# 	building : commercial
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	roof:levels : 1
#
#
# [Building]
# id: 670350874
# number of nodes : 5
# Tags :
# 	building : commercial
# 	building:colour : white
# 	building:levels : 4
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 670920470
# number of nodes : 6
# Tags :
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	roof:levels : 1
#
#
# [Building]
# id: 670920485
# number of nodes : 10
# Tags :
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	roof:levels : 1
#
#
# [Building]
# id: 670986515
# number of nodes : 17
# Tags :
# 	addr:city : London
# 	building : apartments
# 	building:colour : brown
# 	building:levels : 6
# 	building:material : brick
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 670986547
# number of nodes : 15
# Tags :
# 	building : commercial
#
#
# [Building]
# id: 670990648
# number of nodes : 8
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 18
# 	addr:postcode : WC2B 6LH
# 	addr:street : Kingsway
# 	atm : no
# 	brand : The Co-operative Food
# 	brand:wikidata : Q3277439
# 	brand:wikipedia : en:Co-op Food
# 	building : yes
# 	contact:phone : +44 20 74040181
# 	contact:website : https://finder.coop.co.uk/food/store/WC2B-6LH/18-kingsway
# 	level : 0
# 	name : The Co-operative Food
# 	opening_hours : 07:00-22:00
# 	operator : The Co-operative Group
# 	shop : convenience
# 	wheelchair : yes
#
#
# [Building]
# id: 674172486
# number of nodes : 9
# Tags :
# 	building : yes
# 	fixme : Rough outline
#
#
# [Building]
# id: 674654402
# number of nodes : 20
# Tags :
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 723079665
# number of nodes : 9
# Tags :
# 	building : construction
# 	fixme : check depth, rear shape of new building from later imagery when available
#
#
# [Building]
# id: 724528893
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:levels : 3
# 	roof:levels : 2
#
#
# [Building]
# id: 724528894
# number of nodes : 14
# Tags :
# 	building : yes
# 	building:levels : 3
# 	roof:levels : 2
#
#
# [Building]
# id: 766878413
# number of nodes : 13
# Tags :
# 	building : university
# 	building:material : glass
# 	fixme : Shape approximate
# 	name : Centre Building
# 	operator : London School of Economics and Political Science (LSE)
# 	roof:colour : grey
# 	roof:shape : flat
#
#
# [Building]
# id: 771143799
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 771143800
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 802152472
# number of nodes : 5
# Tags :
# 	amenity : fast_food
# 	building : yes
# 	building:colour : grey
# 	building:levels : 1
# 	cuisine : pizza;crepe;ice_cream
# 	name : Italian Street Kitchen
# 	roof:colour : grey
#
#
# [Building]
# id: 802152475
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:colour : dark_green
# 	building:levels : 1
#
#
# [Building]
# id: 802152484
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:colour : dark_green
# 	building:levels : 1
#
#
# [Building]
# id: 807588030
# number of nodes : 10
# Tags :
# 	building : yes
# 	building:colour : white
# 	building:levels : 6
# 	building:material : stone
# 	roof:colour : grey
# 	roof:levels : 1

# %%
print(temp)
# Out:
# {'yes': 3150, 'office': 50, 'university': 45, 'commercial': 363, 'public': 7, 'church': 12, 'train_station': 5, 'shop': 1, 'civic': 1, 'retail': 456, 'hotel': 5, 'apartments': 92, 'house': 69, 'residential': 131, 'service': 1, 'school': 6, 'multiple': 2, 'gallery': 1, 'no': 8, 'college': 2, 'terrace': 4, 'construction': 4, 'tower': 1, 'garages': 1, 'offices': 1, 'dormitory': 1, 'boat': 2, 'air_shaft': 1, 'kiosk': 1, 'theatre': 2, 'roof': 3, 'bridge': 1, 'pub': 1, 'hospital': 1}

# %%
temp2 = {}
for x in yesBuilding:
    print (x)
    for y in x.tags.keys():
        if y == "amenity":
            if x.tags[y] not in temp2.keys():
                temp2[x.tags[y]] = 1
            else:
                temp2[x.tags[y]] +=1
            break
# Out:
# [Building]
# id: 4372002
# number of nodes : 72
# Tags :
# 	addr:city : London
# 	building : yes
# 	building:levels : 2
# 	fee : no
# 	name : National Gallery
# 	name:de : Nationalgalerie
# 	name:en : National Gallery
# 	name:es : Galería Nacional.
# 	name:gl : Galería Nacional
# 	name:ru : Национальная галерея
# 	name:uk : Національна галерея
# 	name:zh : 國家美術館
# 	opening_hours : Sa-Th 10:00-18:00; Fr 10:00-21:00
# 	postal_code : WC2N 5DN
# 	source : Bing
# 	toilets:wheelchair : yes
# 	tourism : gallery
# 	website : https://www.nationalgallery.org.uk/
# 	wheelchair : yes
# 	wikidata : Q180788
# 	wikipedia : en:National Gallery
#
#
# [Building]
# id: 23613986
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:housename : Peacock Theatre
# 	addr:housenumber : 35
# 	addr:postcode : WC2A 2HT
# 	addr:street : Portugal Street
# 	amenity : theatre
# 	building : yes
# 	fhrs:confidence_management : 5
# 	fhrs:hygiene : 10
# 	fhrs:id : 411811
# 	fhrs:local_authority_id : 00570/4000/0/000
# 	fhrs:rating : 4
# 	fhrs:structural : 5
# 	name : Peacock Theatre
# 	short_name : PEA
# 	source:addr : FSA Food Hygiene Ratings Database
# 	start_date : 1960
# 	wikidata : Q748557
# 	wikipedia : en:Peacock Theatre
#
#
# [Building]
# id: 27163672
# number of nodes : 17
# Tags :
# 	addr:city : London
# 	addr:housenumber : 21
# 	addr:street : Wellington Street
# 	amenity : theatre
# 	building : yes
# 	contact:website : http://www.lyceum-theatre.co.uk
# 	name : Lyceum Theatre
# 	name:en : Lyceum Theatre
# 	name:ru : Лицеум
# 	postal_code : WC2E 7RQ
# 	roof:colour : grey
# 	roof:shape : flat
# 	toilets:wheelchair : yes
# 	wheelchair : yes
# 	wikidata : Q1661445
# 	wikimedia_commons : Category:Lyceum_Theatre,_London
# 	wikipedia : en:Lyceum Theatre, London
#
#
# [Building]
# id: 28143024
# number of nodes : 24
# Tags :
# 	addr:housenumber : 50-60
# 	addr:postcode : WC1B 4AR
# 	addr:street : Southampton Row
# 	building : yes
# 	building:colour : light_grey
# 	building:levels : 10
# 	building:material : stone
# 	name : The Grange Holborn Hotel
# 	tourism : hotel
# 	wikidata : Q5595661
#
#
# [Building]
# id: 28416499
# number of nodes : 6
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housename : Freemasons' Hall
# 	addr:housenumber : 60
# 	addr:postcode : WC2B 5AZ
# 	addr:street : Great Queen Street
# 	alt_name : Freemasons' Hall
# 	building : yes
# 	building:material : sandstone
# 	club : freemasonry
# 	contact:phone : +44 (0) 20 7831 9811
# 	fixme : The name of the building is Freemason's Hall. The name of the club it houses is United Grand Lodge of England. Which should rather be used for the name tag?
# 	loc_name : Freemason's Hall
# 	name : Freemasons' Hall
# 	tourism : yes
# 	wikidata : Q1453586
# 	wikipedia : en:Freemasons' Hall, London
#
#
# [Building]
# id: 28416536
# number of nodes : 39
# Tags :
# 	building : yes
# 	building:colour : red-brown
# 	building:levels : 6
# 	building:material : brick
# 	name : Radisson Blu Edwardian Kenilworth
# 	operator : Radisson Blu Edwardian
# 	roof:levels : 1
# 	tourism : hotel
# 	website : https://www.radissonblu-edwardian.com/london-hotel-gb-wc1b-3lb/gbkenilw
#
#
# [Building]
# id: 28416571
# number of nodes : 40
# Tags :
# 	addr:city : London
# 	addr:housenumber : 9
# 	addr:postcode : WC1B 3QD
# 	addr:street : Bloomsbury Street
# 	building : yes
# 	building:colour : orange
# 	building:levels : 6
# 	building:material : brick
# 	fhrs:id : 425905
# 	name : Radisson Blu Edwardian Bloomsbury Street Hotel
# 	operator : Radisson Blu Edwardian
# 	source:addr : FSA Food Hygiene Ratings Scheme open data
# 	tourism : hotel
# 	website : https://www.radissonblu-edwardian.com/london-hotel-gb-wc1b-3qd/gbmarlbo
#
#
# [Building]
# id: 30613704
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 280
# 	addr:street : High Holborn
# 	building : yes
#
#
# [Building]
# id: 30734455
# number of nodes : 9
# Tags :
# 	building : yes
# 	building:levels : 7
# 	source : Bing
#
#
# [Building]
# id: 31327771
# number of nodes : 20
# Tags :
# 	addr:city : London
# 	addr:housenumber : 11a
# 	addr:postcode : WC2H 0EP
# 	addr:street : Charing Cross Road
# 	alt_name : London Pass Redemption Centre
# 	building : yes
# 	name : The London Pass
# 	name:fr : Kiosque London Pass
# 	opening_hours : Mo-Su 10:00-16:30
# 	shop : ticket
#
#
# [Building]
# id: 31467151
# number of nodes : 11
# Tags :
# 	building : yes
# 	building:material : glass
# 	building:name : Crypt
# 	name : London Brass Rubbing Centre
# 	shop : gift
# 	toilets:wheelchair : yes
# 	website : http://www.stmartin-in-the-fields.org/visiting/brass-rubbing/
# 	wheelchair : yes
#
#
# [Building]
# id: 31467228
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:levels : 5
#
#
# [Building]
# id: 31509552
# number of nodes : 9
# Tags :
# 	building : yes
# 	building:material : sandstone
# 	roof:colour : black
#
#
# [Building]
# id: 31509554
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 31694141
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	amenity : restaurant
# 	building : yes
# 	building:levels : 1
# 	cuisine : pizza
# 	name : Fields
# 	outdoor_seating : yes
#
#
# [Building]
# id: 32919209
# number of nodes : 10
# Tags :
# 	addr:city : London
# 	addr:housenumber : 45
# 	addr:postcode : WC2N 4HX
# 	addr:street : St. Martin's Lane
# 	building : yes
# 	internet_access : wlan
# 	internet_access:ssid : ST-MARTINS-LANE-GUEST
# 	name : St Martins Lane Hotel
# 	operator : sbe - Morgans Hotel Group
# 	source : yahoo+ground sketch;local knowledge
# 	tourism : hotel
#
#
# [Building]
# id: 32919259
# number of nodes : 11
# Tags :
# 	building : yes
# 	name : Royal Trafalgar Hotel
# 	operator : thistle
# 	source : Bing
# 	tourism : hotel
# 	website : https://www.thistle.com/hotels/united_kingdom/london/thistle_trafalgar_square/index.html
#
#
# [Building]
# id: 32919261
# number of nodes : 26
# Tags :
# 	building : yes
#
#
# [Building]
# id: 33719501
# number of nodes : 13
# Tags :
# 	building : yes
# 	name : London Trocadero
# 	shop : mall
# 	source:name : survey
# 	source:shop : survey
# 	wikidata : Q6670874
# 	wikipedia : en:London Trocadero
#
#
# [Building]
# id: 33721552
# number of nodes : 8
# Tags :
# 	building : yes
# 	fixme : Multiple buildings to split
#
#
# [Building]
# id: 34878209
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 1
# 	addr:street : Wimpole Street
# 	building : yes
# 	fhrs:confidence_management : 0
# 	fhrs:hygiene : 5
# 	fhrs:id : 411295
# 	fhrs:local_authority_id : 00289/0001/0/000
# 	fhrs:rating : 5
# 	fhrs:structural : 0
# 	name : Royal Society of Medicine
# 	postal_code : W1G 8GP
# 	source:postcode : FSA Food Hygiene Ratings Database
# 	wikidata : Q3446034
#
#
# [Building]
# id: 35904815
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 37458961
# number of nodes : 22
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housename : First Avenue House
# 	addr:housenumber : 42-49
# 	addr:street : High Holborn
# 	building : yes
#
#
# [Building]
# id: 38325236
# number of nodes : 13
# Tags :
# 	addr:housenumber : 1;3;5;7;9;11
# 	addr:street : John Adam Street
# 	alt_name : New Adelphi
# 	building : yes
# 	layer : 1
# 	name : The Adelphi
#
#
# [Building]
# id: 38325241
# number of nodes : 19
# Tags :
# 	addr:housenumber : 11
# 	addr:street : Strand
# 	building : yes
# 	building:levels : 8
#
#
# [Building]
# id: 38325243
# number of nodes : 15
# Tags :
# 	addr:housenumber : 5
# 	addr:street : Strand
# 	building : yes
# 	building:colour : light_grey
# 	building:levels : 9
# 	note : building:levels is approximate and varies in different parts of the building
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 38432589
# number of nodes : 14
# Tags :
# 	amenity : police
# 	building : yes
# 	name : West End Central Police Station
# 	wikidata : Q18163108
#
#
# [Building]
# id: 40412564
# number of nodes : 8
# Tags :
# 	addr:street : West Street
# 	amenity : theatre
# 	building : yes
# 	building:colour : white
# 	building:levels : 4
# 	building:material : plaster
# 	name : St Martin's
# 	postal_code : WC2H 9NZ
# 	roof:colour : dark_grey
# 	website : http://www.stmartins-theatre.co.uk
# 	wheelchair : limited
# 	wikidata : Q7594202
# 	wikipedia : en:St Martin's Theatre
#
#
# [Building]
# id: 40463226
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40463229
# number of nodes : 5
# Tags :
# 	amenity : cinema
# 	building : yes
# 	name : Odeon Shaftesbury Avenue
# 	wheelchair : no
#
#
# [Building]
# id: 40463230
# number of nodes : 10
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housename : The Glasshouse
# 	addr:street : Shaftesbury Avenue
# 	building : yes
# 	name : The Glasshouse
#
#
# [Building]
# id: 40463232
# number of nodes : 11
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40470534
# number of nodes : 12
# Tags :
# 	addr:city : London
# 	addr:housename : Langley House
# 	addr:street : Long Acre
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	source : yahoo
#
#
# [Building]
# id: 40470537
# number of nodes : 9
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40470543
# number of nodes : 39
# Tags :
# 	addr:city : London
# 	addr:housenumber : 10
# 	addr:postcode : WC2B 5RE
# 	addr:street : Drury Lane
# 	brand : Travelodge
# 	brand:wikidata : Q9361374
# 	brand:wikipedia : en:Travelodge UK
# 	building : yes
# 	fhrs:id : 423928
# 	name : Travelodge London Covent Garden
# 	source : Bing;survey;tags copied from node 438170555
# 	source:addr : FSA Food Hygiene Rating Scheme open data
# 	tourism : hotel
# 	wheelchair : no
#
#
# [Building]
# id: 40470552
# number of nodes : 8
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 8-10
# 	addr:street : Dryden Street
# 	building : yes
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
# 	source : Bing;survey
#
#
# [Building]
# id: 40599490
# number of nodes : 25
# Tags :
# 	building : yes
# 	fixme : Retrace from Bing, and find Winter Garden House, Macklin House and no doubt other named buildings.
# 	source : yahoo
#
#
# [Building]
# id: 40836293
# number of nodes : 11
# Tags :
# 	addr:housenumber : 52
# 	addr:street : Langham Street
# 	building : yes
# 	building:levels : 5
# 	name : Romney Mansions
#
#
# [Building]
# id: 40836294
# number of nodes : 10
# Tags :
# 	addr:housenumber : 67
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836295
# number of nodes : 5
# Tags :
# 	addr:housenumber : 65
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836296
# number of nodes : 5
# Tags :
# 	addr:housenumber : 63
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836298
# number of nodes : 5
# Tags :
# 	addr:housenumber : 59
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	roof:levels : 1
#
#
# [Building]
# id: 40836299
# number of nodes : 5
# Tags :
# 	addr:housenumber : 57
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	craft : photographer
# 	name : Kube Studios
# 	roof:levels : 1
# 	website : http://kubestudios.co.uk/#/kube-studios-london/
#
#
# [Building]
# id: 40836300
# number of nodes : 5
# Tags :
# 	addr:housenumber : 55
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	name : Kall Kwik
# 	roof:levels : 1
# 	shop : copyshop
#
#
# [Building]
# id: 40836302
# number of nodes : 5
# Tags :
# 	addr:housenumber : 29
# 	addr:street : Riding House Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	shop : vacant
#
#
# [Building]
# id: 40836306
# number of nodes : 12
# Tags :
# 	addr:housenumber : 6a
# 	addr:street : Middleton Place
# 	building : yes
# 	building:colour : white
# 	building:levels : 2
# 	building:material : plaster
#
#
# [Building]
# id: 40836499
# number of nodes : 21
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40836500
# number of nodes : 7
# Tags :
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	roof:levels : 1
# 	source : yahoo
#
#
# [Building]
# id: 40836501
# number of nodes : 15
# Tags :
# 	addr:housenumber : 78-80
# 	addr:street : Great Portland Street
# 	building : yes
# 	building:levels : 4
# 	source : yahoo
#
#
# [Building]
# id: 40836502
# number of nodes : 5
# Tags :
# 	addr:housenumber : 21-23
# 	addr:street : Riding House Street
# 	building : yes
# 	building:levels : 3
# 	source : yahoo
#
#
# [Building]
# id: 40836503
# number of nodes : 6
# Tags :
# 	addr:city : London
# 	addr:housenumber : 25-27
# 	addr:street : Riding House Street
# 	building : yes
# 	building:colour : light_brown
# 	building:levels : 3
# 	building:material : brick
# 	name : Cheerful Scout
# 	source : yahoo
#
#
# [Building]
# id: 40836508
# number of nodes : 9
# Tags :
# 	addr:housenumber : 6
# 	addr:street : Middleton Place
# 	building : yes
# 	building:colour : brown
# 	building:levels : 3
# 	building:material : brick
# 	source : Bing;photograph
#
#
# [Building]
# id: 40836510
# number of nodes : 10
# Tags :
# 	addr:city : London
# 	addr:housenumber : 94
# 	addr:street : Great Portland Street
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	shop : yes
# 	source : Bing
#
#
# [Building]
# id: 40836844
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 50
# 	addr:postcode : W1W 7ND
# 	addr:street : Great Portland Street
# 	building : yes
# 	building:levels : 5
# 	description : Shoe repairs, watch repairs, key cutting, engraving, dry cleaning, passport photos
# 	name : Mr Craftsman's Workshop
# 	phone : +44 207 636 7753
# 	roof:levels : 1
# 	shop : shoe_repair
# 	source : Bing;photographic_survey
# 	website : http://mrcraftsmanswork.com
#
#
# [Building]
# id: 40836848
# number of nodes : 7
# Tags :
# 	addr:housenumber : 20
# 	addr:street : Margaret Street
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40836851
# number of nodes : 10
# Tags :
# 	addr:housenumber : 26
# 	addr:street : Little Portland Street
# 	building : yes
# 	building:levels : 5
# 	name : Circus House
# 	source : yahoo
#
#
# [Building]
# id: 40836852
# number of nodes : 9
# Tags :
# 	addr:housenumber : 15-19
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	name : Golderbrock House
# 	roof:levels : 1
# 	roof:shape : quadruple_saltbox
# 	source : yahoo
#
#
# [Building]
# id: 40836853
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:levels : 6
# 	source : yahoo
#
#
# [Building]
# id: 40836854
# number of nodes : 7
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40836855
# number of nodes : 5
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40836856
# number of nodes : 5
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 40837404
# number of nodes : 12
# Tags :
# 	addr:city : London
# 	addr:housenumber : 56
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	name : Morplan
# 	source : Bing;photograph
#
#
# [Building]
# id: 40837407
# number of nodes : 14
# Tags :
# 	addr:city : London
# 	addr:housenumber : 60-62
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:colour : light_brown
# 	building:levels : 4
# 	building:material : brick
# 	source : yahoo
#
#
# [Building]
# id: 40837416
# number of nodes : 7
# Tags :
# 	addr:housenumber : 14-18
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	name : Great Titchfield House
# 	source : yahoo
#
#
# [Building]
# id: 40837421
# number of nodes : 12
# Tags :
# 	addr:housenumber : 7
# 	addr:postcode : W1D 2JB
# 	addr:street : Margaret Street
# 	alt_name : All Saints Margaret Street
# 	amenity : place_of_worship
# 	building : yes
# 	denomination : anglican
# 	name : All Saints
# 	religion : christian
# 	source : yahoo
# 	wikidata : Q4729371
# 	wikipedia : en:All Saints, Margaret Street
#
#
# [Building]
# id: 40837812
# number of nodes : 9
# Tags :
# 	addr:housenumber : 60-62
# 	addr:street : Margaret Street
# 	building : yes
#
#
# [Building]
# id: 40837815
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:housename : Kent House
# 	addr:housenumber : 14-17
# 	addr:postcode : W1W 8AJ
# 	addr:street : Market place
# 	building : yes
# 	name : Kent House
#
#
# [Building]
# id: 40837816
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 11-13
# 	addr:street : Market Place
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 40837817
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 9/10
# 	addr:street : Market Place
# 	building : yes
#
#
# [Building]
# id: 40837820
# number of nodes : 9
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40837862
# number of nodes : 6
# Tags :
# 	addr:housenumber : 58-59
# 	addr:street : Margaret Street
# 	building : yes
#
#
# [Building]
# id: 40837864
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40837865
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40840754
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40840761
# number of nodes : 7
# Tags :
# 	addr:housenumber : 8-10
# 	addr:street : Great Titchfield Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 40858234
# number of nodes : 9
# Tags :
# 	building : yes
# 	building:levels : 8
# 	name : Wingate House
# 	note : Check exact building shape.
#
#
# [Building]
# id: 40858239
# number of nodes : 5
# Tags :
# 	building : yes
# 	fixme : Multiple buildings to split
#
#
# [Building]
# id: 40858241
# number of nodes : 6
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40858242
# number of nodes : 20
# Tags :
# 	addr:housenumber : 58
# 	addr:street : Dean Street
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	name : Kemble House
#
#
# [Building]
# id: 40863620
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 40863662
# number of nodes : 11
# Tags :
# 	building : yes
# 	building:levels : 7
# 	roof:levels : 2
#
#
# [Building]
# id: 40863703
# number of nodes : 24
# Tags :
# 	addr:city : London
# 	addr:housename : Regent House
# 	addr:street : Regent Street
# 	building : yes
# 	building:colour : light_grey
# 	building:levels : 5
# 	building:material : stone
# 	name : Regent House
# 	roof:levels : 1
#
#
# [Building]
# id: 40863714
# number of nodes : 14
# Tags :
# 	addr:housenumber : 325-329
# 	addr:street : Oxford Street
# 	building : yes
# 	building:levels : 5
# 	name : Burlian House
#
#
# [Building]
# id: 40863715
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:housenumber : 74
# 	addr:street : New Bond Street
# 	building : yes
# 	building:levels : 5
# 	building:material : stone
# 	name : Watches Of Bond Street
# 	shop : watches
#
#
# [Building]
# id: 40863717
# number of nodes : 6
# Tags :
# 	addr:housenumber : 51-52
# 	addr:street : New Bond Street
# 	building : yes
# 	building:levels : 5
# 	building:material : stone
# 	name : Emporio Armani
# 	name:zh : 阿玛尼邦德街分店
# 	phone : +44 20 7491 8080
# 	shop : clothes
# 	website : https://www.armani.com/
#
#
# [Building]
# id: 40863718
# number of nodes : 10
# Tags :
# 	addr:housenumber : 23-29
# 	addr:street : Maddox Street
# 	building : yes
#
#
# [Building]
# id: 40863723
# number of nodes : 13
# Tags :
# 	addr:housenumber : 89
# 	addr:street : New Bond Street
# 	building : yes
# 	name : Lumina House
#
#
# [Building]
# id: 40863728
# number of nodes : 9
# Tags :
# 	addr:housenumber : 15
# 	addr:street : Bourdon Street
# 	building : yes
# 	name : Grosvenor Hill Court
#
#
# [Building]
# id: 40952618
# number of nodes : 6
# Tags :
# 	building : yes
# 	leisure : fitness_centre
# 	name : Soho Fitness Lab
#
#
# [Building]
# id: 40952627
# number of nodes : 18
# Tags :
# 	building : yes
# 	building:colour : grey
# 	building:levels : 4
# 	roof:colour : grey
# 	roof:levels : 1
#
#
# [Building]
# id: 41117897
# number of nodes : 11
# Tags :
# 	building : yes
# 	source : guestimation from ground observation
#
#
# [Building]
# id: 41117902
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 41117905
# number of nodes : 8
# Tags :
# 	building : yes
#
#
# [Building]
# id: 41117906
# number of nodes : 12
# Tags :
# 	building : yes
# 	layer : 1
# 	source : Bing
#
#
# [Building]
# id: 41117907
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:housenumber : 101-103
# 	addr:postcode : WC1A 1DB
# 	addr:street : New Oxford Street
# 	building : yes
# 	building:architecture : brutalism
# 	building:levels : 34
# 	building:material : concrete
# 	height : 117
# 	name : Centre Point Tower
# 	name:he : סנטר פוינט
# 	source : Bing
# 	source:height : http://www.urban75.org/london/centrepoint.html
# 	wikidata : Q2339039
# 	wikimedia_commons : Category:Centre_Point
# 	wikipedia : en:Centre Point
#
#
# [Building]
# id: 41118172
# number of nodes : 21
# Tags :
# 	building : yes
# 	building:colour : brown
# 	building:levels : 6
# 	building:material : brick
# 	note : space in the middle seen from yahoo, is private and not ground floor. raised level terrace with swimming pool
# 	roof:colour : dark_grey
# 	source : yahoo;Bing;photo
#
#
# [Building]
# id: 42785351
# number of nodes : 10
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 42785391
# number of nodes : 11
# Tags :
# 	addr:city : London
# 	addr:housename : Africa House
# 	addr:housenumber : 64-68
# 	addr:postcode : WC2B 6BG
# 	addr:street : Kingsway
# 	building : yes
# 	building:colour : silver
# 	building:levels : 8
# 	building:material : sandstone
# 	roof:colour : black
# 	roof:levels : 1
# 	roof:shape : mansard
# 	wikidata : Q27086661
#
#
# [Building]
# id: 42786635
# number of nodes : 13
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 203
# 	addr:street : High Holborn
# 	building : yes
# 	note : Shops on ground floor, office on upper floors
# 	source : yahoo;Bing;survey
#
#
# [Building]
# id: 42786636
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	building : yes
# 	name : Reed.co.uk
# 	source : Bing;survey
#
#
# [Building]
# id: 42786637
# number of nodes : 5
# Tags :
# 	building : yes
# 	levels : 13
#
#
# [Building]
# id: 44521980
# number of nodes : 27
# Tags :
# 	addr:city : London
# 	addr:housenumber : 10
# 	addr:postcode : W1T 3NP
# 	addr:street : Berners Street
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	name : The London EDITION
# 	phone : +44 20 7781 0000
# 	ref : LONEB
# 	roof:levels : 2
# 	tourism : hotel
# 	website : https://www.editionhotels.com/london/
#
#
# [Building]
# id: 44599803
# number of nodes : 22
# Tags :
# 	addr:city : London
# 	addr:postcode : WC2E 7BB
# 	addr:street : Covent Garden Piazza
# 	building : yes
# 	building:levels : 2
# 	building:material : brick
# 	contact:phone : +44 20 73796344
# 	contact:website : http://www.ltmuseum.co.uk/
# 	fee : yes
# 	name : London Transport Museum
# 	name:fr : Musée du transport de Londres
# 	opening_hours : Mo-Su 10:00-17:15; Fr 11:00-17:15
# 	operator : Transport for London (TfL)
# 	roof:colour : dark_grey
# 	toilets:wheelchair : yes
# 	tourism : museum
# 	website : https://www.ltmuseum.co.uk/
# 	wheelchair : yes
# 	wikidata : Q1541098
# 	wikipedia : en:London Transport Museum
#
#
# [Building]
# id: 45405644
# number of nodes : 21
# Tags :
# 	addr:housenumber : 33
# 	addr:street : Cavendish Square
# 	building : yes
# 	building:levels : 3
# 	building:part : yes
# 	disused:shop : department_store
# 	height : 10
# 	name : BHS
# 	note:building:levels : this value and height for plinth, see building parts for taller areas
#
#
# [Building]
# id: 45405645
# number of nodes : 10
# Tags :
# 	addr:housenumber : 300
# 	addr:postcode : W1C 1DX
# 	addr:street : Oxford Street
# 	brand : John Lewis
# 	brand:wikidata : Q1918981
# 	brand:wikipedia : en:John Lewis & Partners
# 	building : yes
# 	building:levels : 8
# 	name : John Lewis
# 	official_name : John Lewis & Partners
# 	opening_hours : Mo-Sa 09:30-20:00; Su 11:30-18:00
# 	roof:colour : grey
# 	shop : department_store
# 	toilets:wheelchair : yes
# 	wheelchair : yes
#
#
# [Building]
# id: 45405646
# number of nodes : 6
# Tags :
# 	addr:housenumber : 318
# 	addr:street : Oxford Street
# 	brand : House of Fraser
# 	brand:wikidata : Q5928422
# 	brand:wikipedia : en:House of Fraser
# 	building : yes
# 	building:levels : 6
# 	name : House of Fraser
# 	old_name : D H Evans
# 	operator : John Lewis
# 	payment:cash : yes
# 	payment:mastercard : yes
# 	payment:visa : yes
# 	shop : department_store
# 	toilets : yes
# 	toilets:wheelchair : yes
# 	wheelchair : yes
# 	wikidata : Q27996008
#
#
# [Building]
# id: 45405648
# number of nodes : 6
# Tags :
# 	building : yes
# 	building:colour : grey
# 	building:levels : 5
# 	building:material : stone
# 	roof:colour : grey
#
#
# [Building]
# id: 46129307
# number of nodes : 14
# Tags :
# 	addr:street : Lincoln's Inn, Newman's Row
# 	building : yes
# 	name : The Great Hall
# 	photo : http://commons.wikimedia.org/wiki/File:The_Great_Hall,_Lincoln%27s_Inn,_Newman%27s_Row_WC2.jpeg
# 	source : Wikimedia Commons; Bing
#
#
# [Building]
# id: 48180830
# number of nodes : 24
# Tags :
# 	building : yes
#
#
# [Building]
# id: 48180833
# number of nodes : 15
# Tags :
# 	building : yes
# 	building:colour : light_grey
# 	building:levels : 5
# 	building:material : stone
# 	roof:levels : 1
# 	source : Bing;photograph
#
#
# [Building]
# id: 48180836
# number of nodes : 25
# Tags :
# 	addr:housenumber : 208-222
# 	addr:street : Regent Street
# 	building : yes
# 	building:colour : light_grey
# 	building:levels : 6
# 	building:material : stone
# 	name : Liberty House
# 	source : Bing;photograph
# 	wikidata : Q27081355
#
#
# [Building]
# id: 48180840
# number of nodes : 17
# Tags :
# 	building : yes
#
#
# [Building]
# id: 48180841
# number of nodes : 22
# Tags :
# 	addr:housenumber : 224-244
# 	addr:street : Regent Street
# 	building : yes
# 	building:levels : 5
# 	building:material : stone
# 	roof:levels : 1
# 	source : Bing;photograph
#
#
# [Building]
# id: 48545563
# number of nodes : 16
# Tags :
# 	building : yes
# 	fixme : Multiple buildings to split
# 	source : yahoo
#
#
# [Building]
# id: 48545564
# number of nodes : 20
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 48545565
# number of nodes : 11
# Tags :
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 48545566
# number of nodes : 44
# Tags :
# 	building : yes
# 	fixme : Multiple buildings to split
# 	source : yahoo
#
#
# [Building]
# id: 48545568
# number of nodes : 33
# Tags :
# 	addr:street : Newport Court
# 	building : yes
# 	source : yahoo
#
#
# [Building]
# id: 48545570
# number of nodes : 11
# Tags :
# 	addr:housenumber : 138-140
# 	addr:postcode : WC2H 8HB
# 	addr:street : Shaftesbury Avenue
# 	amenity : fast_food
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	name : Wingstop
# 	roof:levels : 1
# 	source : Bing
#
#
# [Building]
# id: 48545571
# number of nodes : 24
# Tags :
# 	building : yes
# 	building:levels : 6
# 	name : One Thirty W1
# 	source : yahoo
#
#
# [Building]
# id: 48615822
# number of nodes : 9
# Tags :
# 	addr:city : London
# 	addr:housenumber : 12-14
# 	addr:postcode : WC2E 9LP
# 	addr:street : Long Acre
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	contact:phone : +44 20 78361321
# 	disused:shop : books
# 	name : Stanfords
# 	opening_hours : Mo-Sa 09:00-20:00; Su 11:30-18:00
# 	roof:colour : dark_grey
# 	roof:levels : 2
#
#
# [Building]
# id: 48615823
# number of nodes : 15
# Tags :
# 	addr:housename : The Carriage Hall
# 	building : yes
# 	building:colour : brown
# 	building:levels : 5
# 	building:material : brick
# 	roof:colour : dark_grey
# 	source:name : survey
#
#
# [Building]
# id: 50733646
# number of nodes : 11
# Tags :
# 	addr:housename : Wellington Partners
# 	addr:housenumber : 11
# 	addr:street : Berkeley Street
# 	building : yes
#
#
# [Building]
# id: 51755264
# number of nodes : 15
# Tags :
# 	amenity : place_of_worship
# 	building : yes
# 	denomination : anglican
# 	name : St George's Bloomsbury
# 	postal_code : WC1A 2HR
# 	religion : christian
# 	tourism : attraction
# 	website : http://www.stgeorgesbloomsbury.org.uk
# 	wikidata : Q7588083
#
#
# [Building]
# id: 54666911
# number of nodes : 12
# Tags :
# 	addr:city : London
# 	addr:housenumber : 37-38
# 	addr:postcode : W1F 7JB
# 	addr:street : Great Marlborough Street
# 	amenity : pub
# 	brand : O'Neills
# 	building : yes
# 	building:levels : 5
# 	fhrs:confidence_management : 0
# 	fhrs:hygiene : 0
# 	fhrs:id : 428086
# 	fhrs:local_authority_id : 01373/0037/0/000
# 	fhrs:rating : 5
# 	fhrs:structural : 5
# 	food : yes
# 	name : O'Neills
# 	operator : Mitchells & Butlers plc
# 	real_ale : yes
# 	source : yahoo;survey;photograph;Bing
# 	source:addr : FSA Food Hygiene Ratings Database
# 	source:postcode : FSA Food Hygiene Ratings Database
# 	website : https://www.oneills.co.uk/carnaby-street/
# 	wheelchair : limited
#
#
# [Building]
# id: 54666919
# number of nodes : 19
# Tags :
# 	building : yes
# 	building:levels : 6
# 	building:material : brick
# 	covered : yes
# 	leisure : sports_centre
# 	name : Marshall Street Leisure Centre
# 	operator : Greenwich Leisure Limited
# 	roof:levels : 1
# 	source : yahoo;survey;Bing
# 	sport : swimming
# 	website : https://better.org.uk/leisure/marshall-street-leisure-centre
# 	wikidata : Q6773793
# 	wikipedia : en:Marshall Street Baths
#
#
# [Building]
# id: 54666927
# number of nodes : 28
# Tags :
# 	building : yes
#
#
# [Building]
# id: 54666929
# number of nodes : 36
# Tags :
# 	building : yes
# 	building:levels : 6
# 	source : yahoo followed by survey
#
#
# [Building]
# id: 55873933
# number of nodes : 16
# Tags :
# 	addr:housenumber : 49-50
# 	addr:street : Poland Street
# 	building : yes
# 	name : St Giles House
# 	source : yahoo;survey;Bing
#
#
# [Building]
# id: 55873943
# number of nodes : 6
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 25-32
# 	addr:street : Marshall Street
# 	building : yes
# 	building:levels : 3
# 	building:material : brick
# 	name : Molinare
# 	roof:levels : 1
# 	studio : video
# 	website : https://www.molinare.co.uk/
#
#
# [Building]
# id: 55976267
# number of nodes : 10
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 55976271
# number of nodes : 15
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 55976281
# number of nodes : 6
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 55976523
# number of nodes : 15
# Tags :
# 	amenity : college
# 	building : yes
# 	name : Central Saint Martins College of Art & Design
# 	old_name : LCC Central School of Arts & Crafts
# 	source : Yahoo;Mapbox Satellite;Bing
# 	wikidata : Q15208489
#
#
# [Building]
# id: 58645388
# number of nodes : 8
# Tags :
# 	addr:street : Soho Square
# 	amenity : place_of_worship
# 	building : yes
# 	denomination : protestant
# 	name : French Protestant Church of London
# 	name:en : French Protestant Church of London
# 	name:fr : Église Protestante Française de Londres
# 	religion : christian
# 	wikidata : Q3586104
#
#
# [Building]
# id: 60368357
# number of nodes : 24
# Tags :
# 	building : yes
#
#
# [Building]
# id: 61453256
# number of nodes : 6
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 61453257
# number of nodes : 6
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 61453258
# number of nodes : 11
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 61453259
# number of nodes : 6
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 61453260
# number of nodes : 5
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 61453261
# number of nodes : 6
# Tags :
# 	addr:city : London
# 	addr:housenumber : 13
# 	addr:postcode : WC2A 3BP
# 	addr:street : Lincoln's Inn Fields
# 	building : yes
# 	name : Sir John Soane's Museum
# 	name:ja : ジョン・ソーン博物館
# 	opening_hours : Tu-Sa 10:00-16:30
# 	tourism : museum
# 	website : https://www.soane.org/
# 	wikidata : Q2060860
# 	wikipedia : en:Sir John Soane's Museum
#
#
# [Building]
# id: 61453263
# number of nodes : 11
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 61509992
# number of nodes : 14
# Tags :
# 	addr:city : London
# 	addr:housename : D'Arblay House
# 	addr:street : D'Arblay Street
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	roof:levels : 1
# 	source : Bing;photograph
#
#
# [Building]
# id: 61509999
# number of nodes : 17
# Tags :
# 	addr:city : London
# 	addr:housenumber : 15
# 	addr:street : Poland Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	source : Bing;photograph
# 	wikidata : Q27081266
#
#
# [Building]
# id: 61510012
# number of nodes : 13
# Tags :
# 	building : yes
# 	building:colour : white
# 	building:levels : 3
# 	building:material : plaster
# 	name : Smoke and Mirrors
# 	office : company
# 	roof:levels : 1
# 	source : Bing;photograph
# 	website : http://www.smoke-mirrors.com
#
#
# [Building]
# id: 61926915
# number of nodes : 9
# Tags :
# 	building : yes
# 	building:levels : 3
# 	shop : vacant
#
#
# [Building]
# id: 61936008
# number of nodes : 13
# Tags :
# 	addr:housenumber : 141
# 	addr:street : Wardour Street
# 	building : yes
# 	building:levels : 5
# 	roof:levels : 1
#
#
# [Building]
# id: 65489484
# number of nodes : 34
# Tags :
# 	addr:city : London
# 	addr:housenumber : 7-8
# 	addr:postcode : W1F 7TF
# 	addr:street : Argyll Street
# 	amenity : theatre
# 	building : yes
# 	fhrs:confidence_management : 0
# 	fhrs:hygiene : 0
# 	fhrs:id : 413207
# 	fhrs:local_authority_id : 01092/0007/0/000
# 	fhrs:rating : 5
# 	fhrs:structural : 5
# 	name : London Palladium
# 	operator : Really Useful Theatres
# 	postal_code : W1F 7TQ
# 	source:addr : FSA Food Hygiene Ratings Database
# 	source:postcode : FSA Food Hygiene Ratings Database
# 	website : http://www.london-palladium.co.uk
# 	wheelchair : no
# 	wikidata : Q676755
# 	wikipedia : en:London Palladium
#
#
# [Building]
# id: 65489485
# number of nodes : 20
# Tags :
# 	addr:housenumber : 187-195
# 	addr:street : Oxford Street
# 	building : yes
#
#
# [Building]
# id: 65489501
# number of nodes : 9
# Tags :
# 	addr:housenumber : 175-179
# 	addr:street : Oxford Street
# 	building : yes
# 	building:colour : white
# 	building:levels : 5
# 	roof:colour : grey
#
#
# [Building]
# id: 65489515
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 10
# 	addr:street : Argyll Street
# 	building : yes
#
#
# [Building]
# id: 65489516
# number of nodes : 11
# Tags :
# 	amenity : fast_food
# 	brand : McDonald's
# 	brand:wikidata : Q38076
# 	brand:wikipedia : en:McDonald's
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	cuisine : burger
# 	name : McDonald's
# 	roof:colour : grey
# 	takeaway : yes
#
#
# [Building]
# id: 65489521
# number of nodes : 9
# Tags :
# 	addr:housename : Sutherland House
# 	addr:housenumber : 5-6
# 	addr:postcode : W1F 7TE
# 	addr:street : Argyll Street
# 	amenity : fast_food
# 	brand : Five Guys
# 	brand:wikidata : Q1131810
# 	brand:wikipedia : en:Five Guys
# 	building : yes
# 	cuisine : burger
# 	name : Five Guys
# 	official_name : Five Guys Burgers and Fries
# 	phone : +44 20 7434 3407
# 	ref : FGUK719
# 	takeaway : yes
# 	website : https://www.fiveguys.co.uk/
#
#
# [Building]
# id: 65489526
# number of nodes : 16
# Tags :
# 	addr:housenumber : 15
# 	addr:street : Great Marlborough Street
# 	building : yes
# 	building:levels : 7
# 	building:material : brick
#
#
# [Building]
# id: 65489529
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 16-18
# 	addr:postcode : W1F 7LW
# 	addr:street : Ramillies Street
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	email : info@tpg.org.uk
# 	fee : no
# 	name : The Photographers' Gallery
# 	opening_hours : Mo-Sa 10:00-18:00; Su 11:00-18:00
# 	phone : +44 20 7087 9300
# 	shop : art
# 	website : https://thephotographersgallery.org.uk/
# 	wikidata : Q3522227
# 	wikipedia : en:The Photographers' Gallery
#
#
# [Building]
# id: 65489533
# number of nodes : 27
# Tags :
# 	addr:housename : Turner House
# 	addr:housenumber : 16
# 	addr:street : Great Marlborough Street
# 	building : yes
# 	building:colour : white
# 	building:levels : 6
# 	building:material : plaster
# 	description : It is an international chain of bakery-restaurants.
# 	name : Turner House
# 	phone : +44 20 3657 6948
# 	website : http://www.lepainquotidien.co.uk/
#
#
# [Building]
# id: 67255463
# number of nodes : 7
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 67255464
# number of nodes : 7
# Tags :
# 	building : yes
# 	source : Yahoo
#
#
# [Building]
# id: 67864972
# number of nodes : 18
# Tags :
# 	building : yes
#
#
# [Building]
# id: 67864973
# number of nodes : 9
# Tags :
# 	building : yes
#
#
# [Building]
# id: 68155984
# number of nodes : 14
# Tags :
# 	addr:city : London
# 	addr:housenumber : 17
# 	addr:street : Bedford Street
# 	amenity : restaurant
# 	brand : Wagamama
# 	brand:wikidata : Q503715
# 	brand:wikipedia : en:Wagamama
# 	building : yes
# 	cuisine : asian
# 	name : Wagamama
# 	name:ja : ワガママ
# 	website : https://www.wagamama.com/restaurants/covent-garden
# 	wheelchair : yes
#
#
# [Building]
# id: 68155987
# number of nodes : 11
# Tags :
# 	addr:city : London
# 	addr:housenumber : 23-24
# 	addr:postcode : WC2E 7NA
# 	addr:street : Maiden Lane
# 	amenity : restaurant
# 	building : yes
# 	fhrs:id : 904573
# 	name : Ping Pong
# 	source:addr : FSA Food Hygiene Rating Scheme open data
# 	toilets:wheelchair : yes
# 	wheelchair : yes
#
#
# [Building]
# id: 68155989
# number of nodes : 17
# Tags :
# 	building : yes
# 	source : yahoo+ground sketch
#
#
# [Building]
# id: 68155992
# number of nodes : 7
# Tags :
# 	building : yes
# 	source : yahoo+ground sketch
#
#
# [Building]
# id: 68807951
# number of nodes : 9
# Tags :
# 	addr:housenumber : 10;12;14
# 	addr:street : John Adam Street
# 	building : yes
# 	building:levels : 7
# 	name : The Little Adelphi
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 68807954
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:housenumber : 34-35
# 	addr:postcode : WC2N 5HZ
# 	addr:street : Strand
# 	amenity : fast_food
# 	brand : McDonald's
# 	brand:wikidata : Q38076
# 	brand:wikipedia : en:McDonald's
# 	building : yes
# 	cuisine : burger
# 	delivery : no
# 	drive_through : no
# 	name : McDonald's
# 	takeaway : yes
# 	toilets:wheelchair : yes
# 	wheelchair : yes
#
#
# [Building]
# id: 68807956
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:housenumber : 16
# 	addr:street : John Adam Street
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	name : Durham House
# 	roof:colour : dark_grey
# 	roof:levels : 1
# 	wikidata : Q5316524
#
#
# [Building]
# id: 68807957
# number of nodes : 6
# Tags :
# 	addr:housenumber : 7
# 	addr:street : York Buildings
# 	building : yes
# 	building:levels : 3
# 	building:material : brick
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 68807960
# number of nodes : 5
# Tags :
# 	addr:housenumber : 21
# 	addr:street : John Adam Street
# 	building : yes
# 	building:colour : white
# 	building:levels : 4
# 	building:material : plaster
# 	roof:colour : dark_grey
# 	wikidata : Q27080598
#
#
# [Building]
# id: 68807961
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:housenumber : 26-30
# 	addr:street : John Adam Street
# 	amenity : pub
# 	building : yes
# 	building:colour : dark_brown
# 	building:levels : 3
# 	building:material : brick
# 	fhrs:id : 411559
# 	fhrs:local_authority_id : 00482/0026/0/000
# 	name : The Theodore Bullfrog
# 	phone : +44 20 7839 2697
# 	postal_code : WC2N 6HL
# 	roof:colour : dark_grey
# 	website : https://www.theodore-bullfrog.co.uk/
# 	wheelchair : limited
#
#
# [Building]
# id: 68807964
# number of nodes : 7
# Tags :
# 	addr:housenumber : 4
# 	addr:street : York Buildings
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : grey
#
#
# [Building]
# id: 68807965
# number of nodes : 9
# Tags :
# 	addr:housenumber : 8
# 	addr:postcode : WC2N 6EZ
# 	addr:street : John Adam Street
# 	building : yes
# 	contact:phone : +44 207 9305115
# 	contact:website : http://www.thersa.org/
# 	name : The Royal Society of Arts
# 	official_name : The Royal Society for the Encouragement of Arts, Manufactures and Commerce
# 	short_name : The RSA
# 	wikidata : Q1460885
# 	wikipedia : en:Royal Society of Arts
#
#
# [Building]
# id: 68807968
# number of nodes : 5
# Tags :
# 	addr:housenumber : 49-50
# 	addr:postcode : WC2N 5LL
# 	addr:street : Strand
# 	amenity : pharmacy
# 	brand : Superdrug
# 	brand:wikidata : Q7643261
# 	brand:wikipedia : en:Superdrug
# 	building : yes
# 	dispensing : yes
# 	healthcare : pharmacy
# 	name : Superdrug
# 	opening_hours : Mo-Fr 07:30-20:00; Sa 11:00-20:00
# 	payment:cash : yes
# 	payment:mastercard : yes
# 	payment:visa : yes
# 	phone : +44 207 9300381
# 	website : https://www.superdrug.com/
# 	wheelchair : yes
#
#
# [Building]
# id: 68807969
# number of nodes : 7
# Tags :
# 	addr:housenumber : 8
# 	addr:street : York Buildings
# 	building : yes
#
#
# [Building]
# id: 68807972
# number of nodes : 13
# Tags :
# 	addr:housename : 9-11
# 	amenity : fast_food
# 	brand : Five Guys
# 	brand:wikidata : Q1131810
# 	brand:wikipedia : en:Five Guys
# 	building : yes
# 	building:levels : 7
# 	cuisine : burger
# 	internet_access : wlan
# 	name : Five Guys
# 	official_name : Five Guys Burgers and Fries
# 	old_name : Bell & Compass
# 	outdoor_seating : no
# 	real_ale : no
# 	takeaway : yes
# 	wheelchair : no
#
#
# [Building]
# id: 68807973
# number of nodes : 6
# Tags :
# 	addr:housenumber : 6
# 	addr:street : York Buildings
# 	building : yes
# 	building:colour : white
# 	building:levels : 3
# 	building:material : plaster
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 68807977
# number of nodes : 7
# Tags :
# 	addr:housenumber : 7
# 	addr:street : Villiers Street
# 	brand : Ladbrokes
# 	brand:wikidata : Q1799875
# 	brand:wikipedia : en:Ladbrokes Coral
# 	building : yes
# 	name : Ladbrokes
# 	shop : bookmaker
#
#
# [Building]
# id: 68807984
# number of nodes : 5
# Tags :
# 	addr:housenumber : 20
# 	addr:street : York Buildings
# 	building : yes
#
#
# [Building]
# id: 68807987
# number of nodes : 10
# Tags :
# 	addr:city : London
# 	addr:housename : John Adam House
# 	addr:housenumber : 17-19
# 	addr:street : John Adam Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 5
# 	building:material : brick
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 68807989
# number of nodes : 11
# Tags :
# 	building : yes
#
#
# [Building]
# id: 68807993
# number of nodes : 5
# Tags :
# 	addr:housenumber : 3
# 	addr:street : Robert Street
# 	building : yes
# 	name : previously CIPFA
# 	wikidata : Q17549918
#
#
# [Building]
# id: 68807996
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 68807999
# number of nodes : 5
# Tags :
# 	addr:housename : Watergate House
# 	addr:housenumber : 13-15
# 	addr:street : York Buildings
# 	building : yes
# 	fixme : Check house numbers again
#
#
# [Building]
# id: 68808002
# number of nodes : 7
# Tags :
# 	addr:housenumber : 1
# 	addr:street : Robert Street
# 	building : yes
#
#
# [Building]
# id: 68808004
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 68808006
# number of nodes : 5
# Tags :
# 	addr:housenumber : 60-64
# 	addr:province : WC2N 5LR
# 	addr:street : Strand
# 	brand : Topshop
# 	brand:wikidata : Q1893576
# 	brand:wikipedia : en:Topshop
# 	building : yes
# 	clothes : women
# 	name : Topshop
# 	payment:american_express : yes
# 	shop : clothes
# 	wheelchair : limited
#
#
# [Building]
# id: 68808008
# number of nodes : 5
# Tags :
# 	addr:housename : Carlton Mansions
# 	building : yes
#
#
# [Building]
# id: 68808013
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:housenumber : 15
# 	addr:street : John Adam Street
# 	building : yes
#
#
# [Building]
# id: 68808014
# number of nodes : 7
# Tags :
# 	addr:housenumber : 51-55
# 	addr:postcode : WC2N 5LS
# 	addr:street : Strand
# 	amenity : bank
# 	atm : yes
# 	brand : Halifax
# 	brand:wikidata : Q3310164
# 	brand:wikipedia : en:Halifax (bank)
# 	building : yes
# 	name : Halifax
# 	wheelchair : yes
#
#
# [Building]
# id: 68808016
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 71408528
# number of nodes : 5
# Tags :
# 	addr:housenumber : 47
# 	addr:postcode : WC2N 6NE
# 	addr:street : Villiers Street
# 	amenity : bar
# 	building : yes
# 	contact:phone : +44 20 79301408
# 	name : Gordon's Wine Bar
# 	opening_hours : Mo-Sa 11:00-23:00; Su 12:00-22:00
# 	outdoor_seating : yes
# 	website : https://www.gordonswinebar.com/
# 	wheelchair : no
#
#
# [Building]
# id: 71408529
# number of nodes : 6
# Tags :
# 	addr:housenumber : 29
# 	addr:postcode : WC2N 6ND
# 	addr:street : Villiers Street
# 	amenity : restaurant
# 	building : yes
# 	building:colour : white
# 	building:levels : 4
# 	building:material : plaster
# 	cuisine : chicken
# 	name : Thunderbird
# 	outdoor_seating : no
# 	roof:colour : dark_grey
# 	wheelchair : no
#
#
# [Building]
# id: 71408530
# number of nodes : 12
# Tags :
# 	addr:housenumber : 14
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : grey
# 	wikidata : Q17550548
#
#
# [Building]
# id: 71408532
# number of nodes : 6
# Tags :
# 	addr:housenumber : 35
# 	addr:postcode : WC2N 6ND
# 	addr:street : Villiers Street
# 	amenity : restaurant
# 	building : yes
# 	contact:phone : +44 872 1484144
# 	name : Fratelli La Bufala
#
#
# [Building]
# id: 71408533
# number of nodes : 5
# Tags :
# 	addr:housename : Kipling House
# 	addr:housenumber : 43
# 	addr:postcode : WC2N 6NE
# 	addr:street : Villiers Street
# 	building : yes
#
#
# [Building]
# id: 71408537
# number of nodes : 5
# Tags :
# 	building : yes
# 	name : Cravings Express
# 	shop : kiosk
# 	wheelchair : limited
#
#
# [Building]
# id: 71408538
# number of nodes : 5
# Tags :
# 	addr:housenumber : 31
# 	addr:postcode : WC2N 6ND
# 	addr:street : Villiers Street
# 	amenity : restaurant
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	cuisine : ramen
# 	name : Ippudo
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 71408539
# number of nodes : 6
# Tags :
# 	addr:city : London
# 	addr:housenumber : 25
# 	addr:postcode : WC2N 6ND
# 	addr:street : Villiers Street
# 	amenity : fast_food
# 	brand : Pret A Manger
# 	brand:wikidata : Q2109109
# 	brand:wikipedia : en:Pret a Manger
# 	building : yes
# 	building:colour : white
# 	building:levels : 4
# 	building:material : plaster
# 	cuisine : sandwich
# 	name : Pret A Manger
# 	opening_hours : Mo-Fr 07:00-19:00; Sa-Su 10:00-18:00
# 	outdoor_seating : no
# 	roof:colour : dark_grey
# 	short_name : Pret
# 	takeaway : yes
# 	wheelchair : no
#
#
# [Building]
# id: 71408540
# number of nodes : 6
# Tags :
# 	addr:housenumber : 39-41
# 	addr:postcode : WC2N 6NJ
# 	addr:street : Villiers Street
# 	amenity : cafe
# 	building : yes
# 	contact:phone : +44 20 72227200
# 	cuisine : sandwich
# 	name : Eat
# 	outdoor_seating : yes
# 	takeaway : yes
# 	wheelchair : no
#
#
# [Building]
# id: 71408541
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:housenumber : 45
# 	addr:postcode : WC2N 6NE
# 	addr:street : Villiers Street
# 	amenity : fast_food
# 	building : yes
# 	cuisine : sandwich
# 	fhrs:confidence_management : 10
# 	fhrs:hygiene : 5
# 	fhrs:id : 411257
# 	fhrs:local_authority_id : 00271/0045/0/000
# 	fhrs:rating : 4
# 	fhrs:structural : 5
# 	name : Wrap it Up!
# 	postal_code : WC2N 6NE
# 	source:postcode : FSA Food Hygiene Ratings Database
#
#
# [Building]
# id: 71408542
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:housenumber : 27
# 	addr:postcode : WC2N 6ND
# 	addr:street : Villiers Street
# 	amenity : pub
# 	brand : Nicholson's
# 	building : yes
# 	building:colour : white
# 	building:levels : 4
# 	building:material : plaster
# 	fhrs:id : 427764
# 	fhrs:local_authority_id : 00271/0027/0/000
# 	food : yes
# 	name : Princess of Wales
# 	operator : Mitchells & Butlers plc
# 	outdoor_seating : no
# 	postal_code : WC2N 6ND
# 	real_ale : yes
# 	roof:colour : dark_grey
# 	source:postcode : FSA Food Hygiene Ratings Database
# 	wheelchair : no
#
#
# [Building]
# id: 71408543
# number of nodes : 5
# Tags :
# 	addr:housenumber : 33
# 	addr:postcode : WC2N 6ND
# 	addr:street : Villiers Street
# 	building : yes
# 	name : Simit Sarayi
# 	shop : bakery
# 	wheelchair : yes
#
#
# [Building]
# id: 71507453
# number of nodes : 14
# Tags :
# 	addr:housenumber : 12
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:colour : white
# 	building:levels : 5
# 	building:material : plaster
# 	roof:colour : dark_grey
# 	roof:levels : 1
# 	wikidata : Q17527406
#
#
# [Building]
# id: 71507455
# number of nodes : 5
# Tags :
# 	addr:housenumber : 9
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:colour : white
# 	building:levels : 4
# 	building:material : plaster
# 	roof:colour : grey
# 	wikidata : Q17549339
#
#
# [Building]
# id: 71507457
# number of nodes : 7
# Tags :
# 	addr:city : London
# 	addr:housenumber : 20
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	wikidata : Q17549355
#
#
# [Building]
# id: 71507458
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 71507459
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:housenumber : 17
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	roof:levels : 1
# 	wikidata : Q17549349
#
#
# [Building]
# id: 71507460
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:housenumber : 19
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	wikidata : Q17550747
#
#
# [Building]
# id: 71507461
# number of nodes : 11
# Tags :
# 	addr:housenumber : 10
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:levels : 5
# 	roof:colour : dark_grey
# 	wikidata : Q17549688
#
#
# [Building]
# id: 71507462
# number of nodes : 5
# Tags :
# 	addr:housenumber : 13
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : grey
# 	roof:levels : 1
# 	wikidata : Q17549343
#
#
# [Building]
# id: 71507463
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	roof:levels : 1
#
#
# [Building]
# id: 71507465
# number of nodes : 8
# Tags :
# 	addr:housenumber : 8
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:levels : 4
# 	building:material : plaster
# 	roof:colour : grey
# 	wikidata : Q17549682
#
#
# [Building]
# id: 71507468
# number of nodes : 17
# Tags :
# 	addr:housenumber : 11
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:colour : white
# 	building:levels : 3
# 	building:material : plaster
# 	roof:colour : dark_grey
# 	roof:levels : 1
# 	wikidata : Q17550742
#
#
# [Building]
# id: 71507469
# number of nodes : 5
# Tags :
# 	addr:city : London
# 	addr:housenumber : 18
# 	addr:street : Buckingham Street
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	roof:levels : 1
# 	wikidata : Q17549691
#
#
# [Building]
# id: 71507470
# ...
# number of nodes : 10
# Tags :
# 	addr:housenumber : 3
# 	addr:street : Hanway Place
# 	building : yes
# 	building:levels : 3
#
#
# [Building]
# id: 648355402
# number of nodes : 6
# Tags :
# 	addr:housenumber : 14
# 	addr:street : Rathbone Place
# 	building : yes
#
#
# [Building]
# id: 648386428
# number of nodes : 9
# Tags :
# 	addr:housenumber : 51-52
# 	addr:street : Rathbone Place
# 	building : yes
#
#
# [Building]
# id: 648386429
# number of nodes : 8
# Tags :
# 	addr:housenumber : 66
# 	addr:street : Oxford Street
# 	building : yes
#
#
# [Building]
# id: 648671560
# number of nodes : 9
# Tags :
# 	addr:housenumber : 14a
# 	addr:street : Newman Passage
# 	building : yes
#
#
# [Building]
# id: 648689210
# number of nodes : 8
# Tags :
# 	addr:housenumber : 23
# 	addr:street : Rathbone Street
# 	amenity : pub
# 	building : yes
# 	name : Newman Arms
# 	phone : +44 207 636 1127
# 	website : https://www.thenewmanarms.co.uk/
#
#
# [Building]
# id: 649231661
# number of nodes : 5
# Tags :
# 	addr:housenumber : 7
# 	addr:street : Charlotte Place
# 	building : yes
# 	building:levels : 3
#
#
# [Building]
# id: 651644530
# number of nodes : 7
# Tags :
# 	addr:housenumber : 12-13
# 	addr:street : Wells Street
# 	amenity : pub
# 	building : yes
# 	name : The Champion
# 	phone : +44 207 323 1228
#
#
# [Building]
# id: 651644531
# number of nodes : 15
# Tags :
# 	addr:housenumber : 61-62
# 	addr:street : Berners Street
# 	building : yes
# 	building:levels : 5
# 	name : Woolverstone House
#
#
# [Building]
# id: 651645079
# number of nodes : 17
# Tags :
# 	addr:housenumber : 50
# 	addr:street : Berners Street
# 	brand : Morgans Hotel Group
# 	building : yes
# 	name : Sanderson Hotel
# 	stars : 5
# 	tourism : hotel
# 	website : https://www.morganshotelgroup.com/originals/originals-sanderson-london
# 	wikidata : Q17550231
#
#
# [Building]
# id: 651674992
# number of nodes : 5
# Tags :
# 	addr:housenumber : 20
# 	addr:street : Wells Mews
# 	building : yes
#
#
# [Building]
# id: 653682433
# number of nodes : 8
# Tags :
# 	addr:housenumber : 48-50
# 	addr:street : Margaret Street
# 	building : yes
#
#
# [Building]
# id: 653685742
# number of nodes : 6
# Tags :
# 	addr:housenumber : 52-53
# 	addr:street : Margaret Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 653685743
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 653707730
# number of nodes : 5
# Tags :
# 	addr:housenumber : 6
# 	addr:street : Market Place
# 	building : yes
# 	building:levels : 5
#
#
# [Building]
# id: 653707731
# number of nodes : 6
# Tags :
# 	addr:housenumber : 5
# 	addr:street : Market Place
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 653762969
# number of nodes : 10
# Tags :
# 	addr:housenumber : 22
# 	addr:street : Eastcastle Street
# 	building : yes
# 	building:levels : 5
#
#
# [Building]
# id: 653762970
# number of nodes : 9
# Tags :
# 	addr:housenumber : 21
# 	addr:street : Eastcastle Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 653768876
# number of nodes : 5
# Tags :
# 	addr:housenumber : 36
# 	addr:street : Eastcastle Street
# 	building : yes
# 	building:levels : 5
#
#
# [Building]
# id: 653768877
# number of nodes : 5
# Tags :
# 	addr:housenumber : 37
# 	addr:street : Eastcastle Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 653768878
# number of nodes : 10
# Tags :
# 	addr:housenumber : 38-39
# 	addr:street : Eastcastle Street
# 	building : yes
#
#
# [Building]
# id: 653781882
# number of nodes : 9
# Tags :
# 	addr:housenumber : 8
# 	addr:street : Marylebone Passage
# 	building : yes
# 	building:levels : 3
#
#
# [Building]
# id: 653781884
# number of nodes : 7
# Tags :
# 	addr:housenumber : 72-74
# 	addr:street : Wells Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 653781886
# number of nodes : 10
# Tags :
# 	addr:housenumber : 70-71
# 	addr:street : Wells Street
# 	building : yes
#
#
# [Building]
# id: 653782315
# number of nodes : 9
# Tags :
# 	addr:housenumber : 84
# 	addr:street : Margaret Street
# 	amenity : place_of_worship
# 	building : yes
# 	denomination : buddhist
# 	name : Fo Guang Shan
# 	religion : buddhist
# 	website : http://londonfgs.org.uk/
# 	wikidata : Q2685759
#
#
# [Building]
# id: 653851221
# number of nodes : 9
# Tags :
# 	addr:housenumber : 69
# 	addr:street : Wells Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 653851222
# number of nodes : 9
# Tags :
# 	addr:housenumber : 68
# 	addr:street : Wells Street
# 	building : yes
# 	building:levels : 3
#
#
# [Building]
# id: 654097033
# number of nodes : 5
# Tags :
# 	addr:housenumber : 1
# 	addr:street : Margaret Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 654097034
# number of nodes : 5
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Margaret Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 654097036
# number of nodes : 5
# Tags :
# 	addr:housenumber : 4
# 	addr:street : Margaret Street
# 	building : yes
#
#
# [Building]
# id: 654112048
# number of nodes : 7
# Tags :
# 	addr:housenumber : 7
# 	addr:street : Margaret Street
# 	building : yes
#
#
# [Building]
# id: 654112049
# number of nodes : 8
# Tags :
# 	addr:housenumber : 8
# 	addr:street : Margaret Street
# 	building : yes
#
#
# [Building]
# id: 654112052
# number of nodes : 9
# Tags :
# 	addr:housenumber : 9a
# 	addr:street : Margaret Street
# 	building : yes
# 	name : London House
#
#
# [Building]
# id: 654388242
# number of nodes : 8
# Tags :
# 	addr:housenumber : 33-35
# 	addr:street : Great Titchfield Street
# 	building : yes
#
#
# [Building]
# id: 655989246
# number of nodes : 7
# Tags :
# 	addr:housenumber : 51
# 	addr:street : Great Portland Street
# 	building : yes
#
#
# [Building]
# id: 657223555
# number of nodes : 7
# Tags :
# 	addr:housenumber : 28
# 	addr:street : Mortimer Street
# 	building : yes
#
#
# [Building]
# id: 658642655
# number of nodes : 5
# Tags :
# 	addr:housenumber : 5
# 	addr:street : All Souls' Place
# 	building : yes
#
#
# [Building]
# id: 659512499
# number of nodes : 7
# Tags :
# 	addr:housenumber : 80-82
# 	addr:street : Great Titchfield Street
# 	amenity : restaurant
# 	building : yes
# 	cuisine : greek
# 	name : Meraki
# 	website : https://meraki-restaurant.com/
#
#
# [Building]
# id: 660546800
# number of nodes : 5
# Tags :
# 	addr:housenumber : 93
# 	addr:street : Great Portland Street
# 	building : yes
# 	level : 0
# 	name : Knomo
# 	shop : bag
# 	website : http://www.urbanlivinginteriors.co.uk/
#
#
# [Building]
# id: 660681199
# number of nodes : 4
# Tags :
# 	addr:housenumber : 2
# 	addr:street : All Souls' Place
# 	building : yes
#
#
# [Building]
# id: 661632245
# number of nodes : 5
# Tags :
# 	addr:housenumber : 39
# 	addr:street : Margaret Street
# 	amenity : cafe
# 	building : yes
# 	name : Sally White
# 	website : http://sallywhite.co.uk/
#
#
# [Building]
# id: 662261305
# number of nodes : 5
# Tags :
# 	addr:housenumber : 317
# 	addr:street : Regent Street
# 	building : yes
# 	name : Indialinks
# 	shop : clothes
#
#
# [Building]
# id: 662415975
# number of nodes : 6
# Tags :
# 	addr:housenumber : 1
# 	addr:street : Cavendish Square
# 	building : yes
# 	building:levels : 1
#
#
# [Building]
# id: 662571734
# number of nodes : 18
# Tags :
# 	addr:city : London
# 	addr:housenumber : 14
# 	addr:street : Cavendish Square
# 	building : yes
#
#
# [Building]
# id: 662581894
# number of nodes : 6
# Tags :
# 	addr:housenumber : 16
# 	addr:street : Cavendish Square
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 663375905
# number of nodes : 9
# Tags :
# 	addr:housenumber : 324
# 	addr:street : Oxford Street
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 664315343
# number of nodes : 11
# Tags :
# 	addr:housenumber : 11-15
# 	addr:street : Wigmore Street
# 	building : yes
# 	building:levels : 7
# 	name : Cavendish Court
#
#
# [Building]
# id: 666417783
# number of nodes : 5
# Tags :
# 	addr:housenumber : 9
# 	addr:street : Queen Anne Street
# 	building : yes
#
#
# [Building]
# id: 666417784
# number of nodes : 5
# Tags :
# 	addr:housenumber : 11
# 	addr:street : Queen Anne Street
# 	building : yes
#
#
# [Building]
# id: 666417785
# number of nodes : 5
# Tags :
# 	addr:housenumber : 13
# 	addr:street : Queen Anne Street
# 	building : yes
#
#
# [Building]
# id: 666574224
# number of nodes : 8
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Queen Anne Street
# 	building : yes
# 	name : Chandos House
# 	wikidata : Q5071247
#
#
# [Building]
# id: 666574225
# number of nodes : 9
# Tags :
# 	addr:housenumber : 6
# 	addr:street : Chandos Street
# 	building : yes
# 	country : NA
# 	diplomatic : embassy
# 	embassy : high_commission
# 	name : High Commission of Namibia
# 	office : diplomatic
# 	target : GB
# 	wikidata : Q16843021
#
#
# [Building]
# id: 666574892
# number of nodes : 7
# Tags :
# 	addr:housenumber : 4
# 	addr:street : Chandos Street
# 	building : yes
#
#
# [Building]
# id: 666574893
# number of nodes : 7
# Tags :
# 	addr:housenumber : 3
# 	addr:street : Chandos Street
# 	building : yes
#
#
# [Building]
# id: 666574894
# number of nodes : 7
# Tags :
# 	addr:housenumber : 2
# 	addr:street : Chandos Street
# 	building : yes
#
#
# [Building]
# id: 669882380
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 669882381
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 669882382
# number of nodes : 6
# Tags :
# 	addr:housenumber : 40
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : clinic
# 	name : Care Oncology Clinic
# 	website : https://careoncologyclinic.com/
#
#
# [Building]
# id: 669882383
# number of nodes : 9
# Tags :
# 	addr:housenumber : 42
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
# 	name : The Natural Screening Centre Ltd
# 	website : http://www.thenaturalscreeningcentre.co.uk/
#
#
# [Building]
# id: 669882384
# number of nodes : 6
# Tags :
# 	addr:housenumber : 1
# 	addr:street : Mansfield Mews
# 	building : yes
# 	building:levels : 2
#
#
# [Building]
# id: 669890679
# number of nodes : 5
# Tags :
# 	addr:housenumber : 52
# 	addr:street : Harley Street
# 	building : yes
# 	building:levels : 4
# 	healthcare : dentist
# 	name : Harley Street Dental Group
# 	website : https://www.harleystreetdentalgroup.org/
#
#
# [Building]
# id: 669890680
# number of nodes : 5
# Tags :
# 	addr:housenumber : 50
# 	addr:street : Harley Street
# 	building : yes
# 	building:levels : 4
# 	healthcare : clinic
# 	name : Doctors Surgery
#
#
# [Building]
# id: 669890681
# number of nodes : 5
# Tags :
# 	addr:housenumber : 48
# 	addr:street : Harley Street
# 	building : yes
# 	building:levels : 4
# 	healthcare : clinic
# 	name : Harley Street Skin Clinic
# 	website : https://www.harleystreetskinclinic.com/en/
#
#
# [Building]
# id: 669890682
# number of nodes : 5
# Tags :
# 	addr:housenumber : 46
# 	addr:street : Harley Street
# 	building : yes
# 	building:levels : 4
# 	healthcare : yes
# 	name : 46 Harley Street Dental Centre
#
#
# [Building]
# id: 669890683
# number of nodes : 5
# Tags :
# 	addr:housenumber : 44
# 	addr:street : Harley Street
# 	building : yes
# 	building:levels : 4
# 	healthcare : yes
# 	name : Consulting Rooms
#
#
# [Building]
# id: 669899572
# number of nodes : 8
# Tags :
# 	addr:housenumber : 14
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669899573
# number of nodes : 8
# Tags :
# 	addr:housenumber : 12
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669899574
# number of nodes : 7
# Tags :
# 	addr:housenumber : 10
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669899575
# number of nodes : 5
# Tags :
# 	addr:housenumber : 8
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669899576
# number of nodes : 9
# Tags :
# 	addr:housenumber : 6
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669899577
# number of nodes : 5
# Tags :
# 	addr:housenumber : 4
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 669902343
# number of nodes : 5
# Tags :
# 	addr:housenumber : 9
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : clinic
# 	name : 9 Harley Street
#
#
# [Building]
# id: 669902344
# number of nodes : 5
# Tags :
# 	addr:housenumber : 11
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : doctor
# 	name : Isokinetic
#
#
# [Building]
# id: 670141392
# number of nodes : 10
# Tags :
# 	addr:housenumber : 13
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : doctor
#
#
# [Building]
# id: 670141393
# number of nodes : 9
# Tags :
# 	addr:housenumber : 15
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : doctor
#
#
# [Building]
# id: 670141394
# number of nodes : 11
# Tags :
# 	addr:housenumber : 17
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
#
#
# [Building]
# id: 670141395
# number of nodes : 9
# Tags :
# 	addr:housenumber : 19
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : clinic
# 	name : London Prostate
#
#
# [Building]
# id: 670141396
# number of nodes : 7
# Tags :
# 	addr:housenumber : 21
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
#
#
# [Building]
# id: 670141397
# number of nodes : 8
# Tags :
# 	addr:housenumber : 23
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
#
#
# [Building]
# id: 670141398
# number of nodes : 6
# Tags :
# 	addr:housenumber : 25
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
# 	name : 25 Harley Street
# 	website : https://www.25harleystreet.co.uk/
#
#
# [Building]
# id: 670141399
# number of nodes : 7
# Tags :
# 	addr:housenumber : 27
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
# 	name : Harley Street Medical Centre
# 	website : https://harleystreet-medicalcentre.com/
#
#
# [Building]
# id: 670141400
# number of nodes : 7
# Tags :
# 	addr:housenumber : 29
# 	addr:street : Harley Street
# 	building : yes
#
#
# [Building]
# id: 670141402
# number of nodes : 5
# Tags :
# 	addr:housenumber : 31
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : clinic
# 	name : Westminster Clinic
# 	website : https://www.westminsterclinic.co.uk/
#
#
# [Building]
# id: 670141404
# number of nodes : 7
# Tags :
# 	addr:housenumber : 33
# 	addr:street : Harley Street
# 	building : yes
# 	healthcare : yes
#
#
# [Building]
# id: 670146230
# number of nodes : 5
# Tags :
# 	addr:housenumber : 3
# 	addr:street : Wigmore Place
# 	building : yes
# 	building:levels : 3
#
#
# [Building]
# id: 670350843
# number of nodes : 8
# Tags :
# 	addr:city : London
# 	addr:housenumber : 38A
# 	addr:street : Tavistock Street
# 	amenity : cafe
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	name : Double Shot Coffee Co.
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 670350853
# number of nodes : 9
# Tags :
# 	building : yes
# 	building:levels : 5
# 	building:material : brick
# 	roof:colour : dark_grey
#
#
# [Building]
# id: 670350854
# number of nodes : 10
# Tags :
# 	addr:city : London
# 	addr:housename : Harlequin Court
# 	addr:housenumber : 20
# 	addr:street : Tavistock Street
# 	building : yes
# 	building:colour : white
# 	building:levels : 4
# 	roof:colour : dark_grey
# 	roof:levels : 1
# 	wikidata : Q27080715
#
#
# [Building]
# id: 670920470
# number of nodes : 6
# Tags :
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	roof:levels : 1
#
#
# [Building]
# id: 670920485
# number of nodes : 10
# Tags :
# 	building : yes
# 	building:colour : brown
# 	building:levels : 4
# 	building:material : brick
# 	roof:colour : dark_grey
# 	roof:levels : 1
#
#
# [Building]
# id: 670990648
# number of nodes : 8
# Tags :
# 	addr:city : London
# 	addr:country : GB
# 	addr:housenumber : 18
# 	addr:postcode : WC2B 6LH
# 	addr:street : Kingsway
# 	atm : no
# 	brand : The Co-operative Food
# 	brand:wikidata : Q3277439
# 	brand:wikipedia : en:Co-op Food
# 	building : yes
# 	contact:phone : +44 20 74040181
# 	contact:website : https://finder.coop.co.uk/food/store/WC2B-6LH/18-kingsway
# 	level : 0
# 	name : The Co-operative Food
# 	opening_hours : 07:00-22:00
# 	operator : The Co-operative Group
# 	shop : convenience
# 	wheelchair : yes
#
#
# [Building]
# id: 674172486
# number of nodes : 9
# Tags :
# 	building : yes
# 	fixme : Rough outline
#
#
# [Building]
# id: 674654402
# number of nodes : 20
# Tags :
# 	building : yes
# 	building:levels : 4
#
#
# [Building]
# id: 724528893
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:levels : 3
# 	roof:levels : 2
#
#
# [Building]
# id: 724528894
# number of nodes : 14
# Tags :
# 	building : yes
# 	building:levels : 3
# 	roof:levels : 2
#
#
# [Building]
# id: 771143799
# number of nodes : 5
# Tags :
# 	building : yes
#
#
# [Building]
# id: 771143800
# number of nodes : 7
# Tags :
# 	building : yes
#
#
# [Building]
# id: 802152472
# number of nodes : 5
# Tags :
# 	amenity : fast_food
# 	building : yes
# 	building:colour : grey
# 	building:levels : 1
# 	cuisine : pizza;crepe;ice_cream
# 	name : Italian Street Kitchen
# 	roof:colour : grey
#
#
# [Building]
# id: 802152475
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:colour : dark_green
# 	building:levels : 1
#
#
# [Building]
# id: 802152484
# number of nodes : 5
# Tags :
# 	building : yes
# 	building:colour : dark_green
# 	building:levels : 1
#
#
# [Building]
# id: 807588030
# number of nodes : 10
# Tags :
# 	building : yes
# 	building:colour : white
# 	building:levels : 6
# 	building:material : stone
# 	roof:colour : grey
# 	roof:levels : 1

# %%
print(temp2)
# Out:
# {'theatre': 38, 'restaurant': 175, 'police': 1, 'cinema': 3, 'place_of_worship': 15, 'fast_food': 25, 'pub': 97, 'college': 5, 'pharmacy': 4, 'bank': 20, 'bar': 25, 'cafe': 53, 'marketplace': 1, 'library': 1, 'toilets': 1, 'society': 1, 'community_centre': 1, 'post_office': 1, 'adult_education': 1, 'kindergarten': 1, 'dentist': 4, 'clinic': 2, 'university': 3, 'social_facility': 1, 'studio': 7, 'nightclub': 5, 'ice_cream': 5, 'lifeboat_station': 1, 'stripclub': 3, 'casino': 1, 'arts_centre': 1, 'language_school': 2, 'bureau_de_change': 1, 'fountain': 1}
