# %% [markdown]
# # Load Library
# load global library

# %% [markdown]
# import matplotlib
# matplotlib.use("TkAgg")
# import matplotlib.pyplot as plt
# from time import time
# from random import random
#
# plt.ion()
# # set up the figure
# fig = plt.figure()
# plt.xlabel('Time')
# plt.ylabel('Value')
#
# plt.show(block=False)
#
# def mypause(interval):
#     backend = plt.rcParams['backend']
#     if backend in matplotlib.rcsetup.interactive_bk:
#         figManager = matplotlib._pylab_helpers.Gcf.get_active()
#         if figManager is not None:
#             canvas = figManager.canvas
#             if canvas.figure.stale:
#                 canvas.draw()
#             canvas.start_event_loop(interval)
#             return
#
#
# t0 = time()
# t = []
# y = []
# while True:
#     t.append( time()-t0 )
#     y.append( random() )
#     plt.gca().clear()
#     plt.plot( t , y )
#     mypause(1)

# %%
import random

a =[]
for i in range(0,10000):
    a.append(random.randint(0,1000))
i =int(0) 
chunks = [a[100*i:100*(i+1)] for i in range(int(len(a)/100) + 1)]
print (chunks)
# Out:
# [[476, 334, 515, 433, 880, 885, 557, 496, 630, 106, 858, 187, 325, 3, 231, 225, 888, 970, 588, 992, 842, 193, 67, 347, 90, 763, 943, 95, 604, 902, 566, 258, 576, 693, 655, 552, 270, 218, 504, 905, 617, 600, 887, 980, 502, 493, 108, 391, 17, 114, 691, 957, 129, 339, 929, 764, 65, 148, 529, 865, 400, 201, 593, 475, 887, 178, 458, 256, 504, 161, 948, 464, 259, 149, 978, 352, 863, 995, 669, 668, 975, 307, 272, 421, 47, 759, 361, 993, 364, 442, 836, 89, 721, 954, 981, 210, 903, 215, 369, 553], [972, 424, 34, 994, 789, 172, 434, 953, 106, 484, 756, 513, 568, 409, 837, 118, 682, 637, 394, 733, 42, 165, 945, 906, 711, 529, 395, 376, 663, 317, 272, 713, 169, 812, 461, 718, 113, 295, 772, 528, 712, 473, 622, 604, 320, 892, 794, 18, 124, 585, 554, 136, 617, 452, 784, 479, 94, 660, 254, 480, 401, 387, 442, 149, 475, 83, 13, 540, 372, 527, 8, 344, 727, 826, 900, 416, 361, 946, 501, 953, 747, 423, 447, 518, 112, 685, 410, 621, 739, 482, 818, 128, 566, 847, 22, 878, 991, 443, 789, 197], [520, 433, 999, 540, 686, 89, 468, 383, 903, 545, 77, 181, 615, 376, 671, 62, 957, 50, 418, 978, 30, 390, 263, 286, 504, 521, 775, 839, 410, 834, 648, 580, 595, 910, 716, 388, 629, 935, 1000, 507, 148, 154, 192, 30, 87, 789, 202, 288, 409, 845, 532, 764, 238, 58, 25, 570, 158, 101, 951, 384, 864, 782, 935, 396, 62, 857, 54, 587, 445, 851, 856, 221, 445, 810, 270, 21, 711, 62, 203, 501, 872, 387, 20, 801, 164, 413, 962, 54, 485, 785, 770, 140, 498, 673, 636, 161, 682, 96, 158, 301], [294, 583, 580, 575, 368, 748, 395, 146, 86, 206, 188, 200, 87, 450, 252, 963, 518, 860, 687, 229, 91, 909, 134, 709, 439, 167, 72, 509, 692, 424, 167, 542, 282, 344, 182, 875, 749, 11, 68, 545, 765, 657, 573, 605, 479, 950, 463, 429, 646, 191, 456, 405, 50, 68, 405, 606, 171, 878, 938, 673, 966, 758, 487, 644, 745, 907, 629, 301, 15, 145, 489, 417, 457, 2, 400, 406, 867, 82, 247, 88, 312, 598, 728, 707, 330, 28, 617, 423, 499, 354, 674, 359, 783, 631, 309, 690, 843, 797, 287, 996], [171, 407, 760, 416, 418, 197, 120, 108, 807, 191, 54, 666, 524, 128, 194, 621, 855, 754, 295, 699, 850, 703, 407, 193, 319, 992, 631, 978, 338, 40, 110, 928, 238, 454, 346, 328, 378, 899, 998, 166, 91, 409, 631, 337, 782, 808, 1, 310, 166, 116, 210, 574, 418, 489, 213, 422, 493, 348, 327, 593, 252, 927, 774, 285, 763, 621, 985, 384, 401, 504, 652, 461, 695, 692, 936, 317, 243, 785, 550, 332, 806, 591, 897, 828, 217, 446, 45, 692, 803, 585, 186, 6, 498, 16, 82, 62, 216, 131, 441, 747], [358, 656, 54, 112, 757, 215, 718, 620, 464, 466, 415, 644, 755, 753, 18, 899, 299, 210, 27, 174, 475, 924, 272, 123, 885, 953, 635, 638, 587, 867, 240, 641, 681, 777, 349, 82, 342, 532, 348, 70, 632, 501, 696, 427, 974, 849, 989, 3, 960, 334, 858, 177, 860, 941, 175, 386, 943, 145, 504, 72, 503, 774, 634, 563, 133, 83, 132, 104, 594, 32, 423, 816, 977, 187, 328, 431, 607, 939, 213, 154, 510, 963, 384, 731, 305, 855, 285, 803, 46, 578, 946, 210, 252, 208, 703, 819, 2, 399, 255, 526], [67, 585, 820, 15, 588, 113, 571, 224, 442, 1, 488, 623, 818, 696, 398, 233, 566, 580, 100, 146, 372, 340, 844, 485, 736, 544, 330, 617, 807, 22, 692, 510, 294, 187, 477, 616, 991, 378, 495, 98, 475, 533, 493, 693, 822, 469, 892, 614, 688, 521, 606, 338, 761, 206, 316, 325, 289, 971, 500, 211, 622, 295, 37, 502, 153, 246, 594, 627, 626, 156, 524, 488, 59, 702, 471, 224, 13, 568, 820, 206, 135, 368, 272, 384, 698, 103, 746, 216, 109, 411, 328, 623, 623, 745, 322, 152, 212, 447, 132, 673], [190, 223, 699, 178, 632, 522, 203, 649, 774, 824, 610, 66, 725, 564, 902, 80, 263, 577, 598, 587, 734, 941, 634, 958, 175, 319, 262, 541, 131, 140, 903, 340, 713, 519, 692, 905, 597, 596, 259, 978, 876, 48, 467, 721, 443, 355, 683, 206, 988, 544, 910, 448, 687, 788, 261, 449, 32, 55, 593, 371, 144, 239, 598, 190, 721, 920, 431, 511, 439, 873, 907, 593, 616, 284, 730, 204, 766, 570, 472, 222, 469, 30, 367, 21, 789, 131, 637, 716, 843, 147, 40, 480, 587, 44, 594, 432, 616, 842, 694, 173], [731, 430, 591, 354, 130, 147, 860, 123, 676, 170, 468, 111, 583, 515, 7 ...

# %%
len(a)/100
# Out:
# 100.0

# %%
import sys
import os

# %% [markdown]
# import random
# infectionPercentage = (-23.28 * 0) + 10.0
# print(infectionPercentage)
# test = random.randint(0,int(100*100))
# print(f"{test} vs {int(infectionPercentage*100)}")

# %% [markdown]
# import matplotlib.pyplot

# %% [markdown]
# load local library

# %%
sys.path.append(os.path.join(os.getcwd() , ".."))
import lib.Map.Map as map
import lib.Renderer.Renderer as renderer
from lib.Renderer.GraphViewer import showData
import threading
import lib.Simulation.Simulator as Simulator

# %%
print(map.Map.__doc__)
# Out:
#     [Class] Map
#     A class to represent the map
#
#     Properties:
#         - origin        : [Coordinate] map's origin coordinate
#         - end           : [Coordinate] map's end coordinate
#         - num_nodes     : Number of Nodes.
#         - nodesDict     : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - nodes         : List of all nodes.
#
#         - num_ways      : Number of Ways.
#         - waysDict      : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - ways          : List of all ways.
#
#         - num_roads     : Number of Roads.
#         - roadNodesDict :
#         - roadNodes     :
#         - roadsDict     : List of all nodes that marked as road.
#         - roads         : List of all roads.
#
#         - num_buildings : Number of Buildings.
#         - buildings     : List of all buildings.
#         - naturals      : List of all naturals.
#         - leisures      : List of all leisures.
#         - amenities     : List of all amenities.
#
#         - grids         : [(int,int)] Two dimensional array of grids
#
#         - others        : List of other openstreetmap ways that yet to be categorized.
#         - distanceLat   : height of 1 grid in latitude
#         - distanceLon   : width of 1 grid in longitude
#         - gridsize      : tuple of 2 integer that shows how many grids we have

# %%
print(map.readFile.__doc__)
# Out:
#     [Function] readFile
#     Function to generate map fom osm File
#
#     parameter:
#         - filepath : [string] path to the OSM file
#         - grid     : [(int,int)] grid size, default value = (10,10)

# %%
dataDirectory = os.path.join("..","osmData")
filename = "TX-To-TU.osm"
filepath = os.path.join(dataDirectory,filename)

buildingConfigPath = os.path.join("..","config","tsukuba-tu-building-data.csv")

# %%
osmMap = map.readFile(filepath,buildingCSV = buildingConfigPath)
# Out:
# 0.002800000000002001,0.004399999999999693
# error, Heron's formula is not working due to very small angle
# ['9', '0', '0', 'All', 'laboratory']
# ['9', '0', '1', 'All', 'residential']
# ['9', '0', '2', '1', 'barbershop']
# ['9', '0', '2', '1', 'retail']
# ['9', '0', '2', 'All', 'residential']
# ['8', '1', '0', '5', 'office']
# ['8', '1', '0', 'All', 'residential']
# ['8', '1', '1', '2', 'laboratory']
# ['8', '1', '1', 'All', 'laboratory']
# ['8', '1', '2', 'All', 'residential']
# ['8', '1', '3', 'All', 'laboratory']
# ['8', '1', '4', 'All', 'university']
# ['8', '1', '7', '3', 'retail']
# ['8', '1', '7', 'All', 'office']
# ['8', '1', '8', '1', 'clinic']
# ['8', '1', '8', '1', 'residential']
# ['8', '1', '8', '1', 'skill school']
# ['8', '1', '8', 'All', 'retail']
# ['7', '2', '1', 'All', 'laboratory']
# ['7', '2', '2', 'All', 'university']
# ['7', '2', '3', '1', 'retail']
# ['6', '3', '3', '3', 'residential']
# ['7', '2', '3', 'All', 'university']
# ['7', '2', '4', 'All', 'laboratory']
# ['7', '2', '5', '4', 'house']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', 'All', 'apartments']
# ['7', '2', '6', '1', 'house']
# ['7', '2', '6', '1', 'office']
# ['7', '2', '6', '1', 'university']
# ['7', '2', '6', '3', 'retail']
# ['7', '2', '6', '4', 'residential']
# ['7', '2', '6', 'All', 'apartments']
# ['7', '2', '7', '1', 'office']
# ['7', '2', '7', '2', 'retail']
# ['7', '2', '7', 'All', 'apartments']
# ['7', '2', '7', 'All', 'apartments']
# ['7', '2', '8', '1', 'office']
# ['7', '2', '8', 'All', 'retail']
# ['6', '3', '0', '2', 'apartments']
# ['6', '3', '0', 'All', 'house']
# ['6', '3', '1', '1', 'pachinko']
# ['6', '3', '1', 'All', 'house']
# ['6', '3', '2', '13', 'laboratory']
# ['6', '3', '3', '1', 'barbershop']
# ['6', '3', '3', 'All', 'University']
# ['6', '3', '4', '1', 'church']
# ['6', '3', '4', '1', 'office']
# ['6', '3', '4', '1', 'residential']
# ['6', '3', '4', '1', 'retail']
# ['6', '3', '4', 'All', 'apartments']
# ['6', '3', '5', '1', 'retail']
# ['6', '3', '5', '3', 'residential']
# ['6', '3', '5', 'All', 'apartments']
# ['6', '3', '6', '4', 'retail']
# ['6', '3', '6', '15', 'residential']
# ['6', '3', '6', 'All', 'apartments']
# ['6', '3', '7', '1', 'clinic']
# ['6', '3', '7', '1', 'office']
# ['6', '3', '7', '3', 'barbershop']
# ['6', '3', '7', '4', 'retail']
# ['6', '3', '7', 'All', 'apartments']
# ['6', '3', '8', '2', 'residential']
# ['6', '3', '8', 'All', 'apartments']
# ['5', '4', '0', '1', 'house']
# ['5', '4', '0', 'All', 'apartments']
# ['5', '4', '1', 'All', 'house']
# ['5', '4', '2', '2', 'barbershop']
# ['5', '4', '2', '4', 'house']
# ['5', '4', '2', '4', 'residential']
# ['5', '4', '2', 'All', 'apartments']
# ['5', '4', '3', '2', 'residential']
# ['5', '4', '3', '4', 'hall']
# ['5', '4', '3', '8', 'apartments']
# ['5', '4', '3', 'All', 'university']
# ['5', '4', '4', 'All', 'university']
# ['5', '4', '5', 'All', 'university']
# ['5', '4', '6', 'All', 'museum']
# ['5', '4', '7', 'All', 'museum']
# ['4', '5', '0', '1', 'nursery']
# ['4', '5', '0', 'All', 'miscellaneous']
# ['4', '5', '1', '1', 'clinic']
# ['4', '5', '1', '1', 'karaoke_box']
# ['4', '5', '1', '1', 'skill school']
# ['4', '5', '1', '2', 'residential']
# ['4', '5', '1', '2', 'retail']
# ['4', '5', '1', 'All', 'apartments']
# ['4', '5', '2', '1', 'barbershop']
# ['4', '5', '2', '1', 'university']
# ['4', '5', '2', '2', 'retail']
# ['4', '5', '2', '3', 'restaurant']
# ['4', '5', '2', 'All', 'apartments']
# ['4', '5', '3', '1', 'retail']
# ['4', '5', '3', '3', 'restaurant']
# ['4', '5', '3', '3', 'university']
# ['4', '5', '3', '4', 'residential']
# ['4', '5', '3', 'All', 'apartments']
# ['4', '5', '4', '1', 'office']
# ['4', '5', '4', '1', 'retail']
# ['4', '5', '4', '2', 'restaurant']
# ['4', '5', '4', 'All', 'residential']
# ['4', '5', '5', '4', 'restaurant']
# ['4', '5', '5', 'All', 'apartments']
# ['4', '5', '6', 'All', 'museum']
# ['4', '5', '8', 'All', 'hall']
# ['3', '6', '0', '1', 'office']
# ['3', '6', '0', '2', 'apartments']
# ['3', '6', '0', 'All', 'house']
# ['3', '6', '1', '1', 'laboratory']
# ['3', '6', '1', '1', 'restaurant']
# ['3', '6', '1', 'All', 'house']
# ['3', '6', '2', '3', 'laboratory']
# ['3', '6', '2', 'All', 'apartments']
# ['3', '6', '3', '1', 'hospital']
# ['3', '6', '3', 'All', 'laboratory']
# ['3', '6', '4', '1', 'hospital']
# ['3', '6', '4', '2', 'laboratory']
# ['3', '6', '4', 'All', 'residential']
# ['3', '6', '5', '1', 'barbershop']
# ['3', '6', '5', '1', 'school']
# ['3', '6', '5', '4', 'retail']
# ['3', '6', '5', '6', 'restaurant']
# ['3', '6', '5', 'All', 'apartments']
# ['3', '6', '6', '1', 'karaoke_box']
# ['3', '6', '6', '1', 'retail']
# ['3', '6', '6', 'All', 'apartments']
# ['3', '6', '7', 'All', 'apartments']
# ['2', '7', '1', 'All', 'apartments']
# ['2', '7', '2', '1', 'laboratory']
# ['2', '7', '2', '2', 'restaurant']
# ['2', '7', '2', '2', 'retail']
# ['2', '7', '2', 'All', 'apartments']
# ['2', '7', '3', '3', 'office']
# ['2', '7', '3', 'All', 'apartments']
# ['2', '7', '4', '1', 'hospital']
# ['2', '7', '4', '1', 'university']
# ['2', '7', '4', 'All', 'apartments']
# ['2', '7', '5', '2', 'hall']
# ['2', '7', '5', '3', 'university']
# ['2', '7', '5', 'All', 'laboratory']
# ['2', '7', '6', '1', 'restaurant']
# ['2', '7', '6', '1', 'retail']
# ['2', '7', '6', 'All', 'apartments']
# ['2', '7', '7', '1', 'clinic']
# ['2', '7', '7', '2', 'hospital']
# ['2', '7', '7', '3', 'restaurant']
# ['2', '7', '7', '3', 'retail']
# ['2', '7', '7', 'All', 'apartments']
# ['2', '7', '8', '1', 'laboratory']
# ['2', '7', '8', '1', 'skill school']
# ['2', '7', '8', 'All', 'apartments']
# ['1', '8', '0', '3', 'retail']
# ['1', '8', '0', 'All', 'house']
# ['1', '8', '1', '1', 'apartments']
# ['1', '8', '1', '1', 'clinic']
# ['1', '8', '1', '1', 'restaurant']
# ['1', '8', '1', '1', 'retail']
# ['1', '8', '1', '1', 'skill school']
# ['1', '8', '1', 'All', 'house']
# ['1', '8', '2', '1', 'restaurant']
# ['1', '8', '2', '1', 'retail']
# ['1', '8', '2', '2', 'office']
# ['1', '8', '2', 'All', 'apartments']
# ['1', '8', '3', '1', 'office']
# ['1', '8', '3', '1', 'restaurant']
# ['1', '8', '3', '1', 'retail']
# ['1', '8', '3', '1', 'skill school']
# ['1', '8', '3', '2', 'barbershop']
# ['1', '8', '3', 'All', 'apartments']
# ['1', '8', '4', '1', 'restaurant']
# ['1', '8', '4', 'All', 'office']
# ['1', '8', '5', '1', 'restaurant']
# ['1', '8', '5', '1', 'university']
# ['1', '8', '5', 'All', 'residential']
# ['1', '8', '6', '4', 'museum']
# ['1', '8', '6', 'All', 'school']
# ['1', '8', '7', '1', 'hotel']
# ['1', '8', '7', '1', 'skill school']
# ['1', '8', '7', 'All', 'apartments']
# ['1', '8', '8', '1', 'school']
# ['1', '8', '8', '3', 'office']
# ['1', '8', '8', 'All', 'apartments']
# ['1', '8', '9', 'All', 'apartments']
# ['0', '9', '1', '1', 'nursery']
# ['0', '9', '1', 'All', 'school']
# ['0', '9', '5', '1', 'hall']
# ['0', '9', '5', '1', 'restaurant']
# ['0', '9', '5', '2', 'hotel']
# ['0', '9', '5', 'All', 'apartments']
# ['0', '9', '6', '1', 'hotel']
# ['0', '9', '6', '1', 'mall']
# ['0', '9', '6', 'All', 'office']
# ['0', '9', '7', '1', 'apartments']
# ['0', '9', '7', '2', 'office']
# ['0', '9', '7', 'All', 'mall']
# ['0', '9', '8', '1', 'hall']
# ['0', '9', '8', '2', 'mall']
# ['0', '9', '8', '3', 'apartments']
# ['0', '9', '8', 'All', 'office']
# ['0', '9', '9', '1', 'mall']
# ['0', '9', '9', '1', 'office']
# ['0', '9', '9', 'All', 'apartments']

# %%
print(osmMap)
# Out:
# Epidemicon Map
#  number of nodes = 22469
#  number of ways = 3681
#  number of roads = 8134
#  number of roads node = 10760
#  number of buildings = 1752

# %%
sim = Simulator.Simulator("../config/jobs.csv",osmMap,agentNum = 10000,threadNumber = 8)
# Out:
# ['student', '9', '9', 'school', '4', '18', '5', '8', '9', 'weekday', '5', '5', 'no', '0']
# ['university_student', '4', '9', 'university', '18', '60', '5', '8', '14', 'weekday', '1', '5', 'no', '0']
# ['medical_doctor', '8', '24', 'public', '25', '70', '1', '0', '23', 'everyday', '5', '7', 'no', '0']
# ['teacher', '9', '9', 'school', '23', '70', '1', '8', '9', 'weekday', '5', '5', 'no', '0']
# ['university_professor ', '5', '9', 'school', '28', '70', '1', '8', '9', 'weekday', '3', '5', 'no', '0']
# ['salaryman_tsuchiura', '9', '9', 'train_station', '19', '70', '3', '8', '9', 'weekday', '5', '5', 'yes', '0.001']
# ['salaryman_tokyo', '9', '9', 'train_station', '19', '70', '3', '8', '9', 'weekday', '5', '5', 'yes', '0.001']
# ['convenience_store_employee', '8', '8', 'retail', '19', '70', '1', '0', '23', 'everyday', '3', '5', 'no', '0']
# ['test_job', '4', '5', 'school', '19', '70', '1', '0', '23', 'mon,tue', '2', '2', 'no', '0']
# Processed 0 lines.
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# ...
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays

# %%
len(sim.agents)
# Out:
# 9996

# %%
x = threading.Thread(target=showData, args=(sim,))
x.start()
sim.stepCount = 3600*8

# %%
renderer.render(osmMap,sim,stepLength = 300)
# Out:
# moving agents in renderer
# double click
# Activity Checking
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# double click
# double click
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# double click
# double click
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Activity Checking
# VBox()
#      Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Activity Checking
# VBox()
#      Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# moving agents in rendererfinish stepping
#
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Activity Checking
# VBox()
#      Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Finished checking activity, proceeding to move agents
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# moving agents in renderer
# Activity Checking
# VBox()

# %%
sim.history

# %% [markdown]
# showData(sim)

# %% [markdown]
# sim.stepCount = 3600*8

# %% [markdown]
# x = threading.Thread(target=renderer.render, args=(osmMap,sim,))
# x.start()

# %% [markdown]
# showData(sim)

# %% [markdown]
# a = [(45,'for', 24), (3,'Geeks', 8), (20,'Geeks', 30)]
# a.sort(key=lambda x:x[1])
# a

# %% [markdown]
# result

# %% [markdown]
# print(osmMap.buildingsMap["b586"])
# print(osmMap.buildingsMap["b586"].node)
# print(osmMap.buildingsMap["b586"].entryPoint)

# %% [markdown]
# for x in sim.agents:
#     print(x.mainJob.isWorking(0,8))

# %% [markdown]
# agent = sim.agents[1]

# %% [markdown]
# agent.step(0,8,steps=15)

# %% [markdown]
# sim.currentHour()

# %% [markdown]
# print(agent.activeSequence)

# %% [markdown]
# osmMap.findPath(agent,agent.mainJob.building)

# %% [markdown]
# x = agent.currentNode.getMovementSequence(agent.mainJob.building.node)
# print (x)

# %% [markdown]
# print(agent.currentNode)
# print(agent.home.node())

# %% [markdown]
# agent.mainJob.isWorking(0,8)

# %% [markdown]
# agent.mainJob.workdays

# %% [markdown]
# b = agent.currentNode.getMovementSequence(agent.mainJob.building.node)
# print(b)

# %% [markdown]
# from lib.Map.PathFinder import searchPath
# distance, sequence = searchPath(osmMap,agent.currentNode,agent.mainJob.building.node)

# %% [markdown]
# sequence

# %% [markdown]
# distance

# %% [markdown]
# agent.setMovementSequence(activeSequence)

# %% [markdown]
# agent.currentNode.addMovementSequence(sequence.clone())
