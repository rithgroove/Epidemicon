# %% [markdown]
# # Load Library
# load global library

# %%
import sys
import os

# %% [markdown]
# import random
# infectionPercentage = (-23.28 * 0) + 10.0
# print(infectionPercentage)
# test = random.randint(0,int(100*100))
# print(f"{test} vs {int(infectionPercentage*100)}")

# %% [markdown]
# import matplotlib.pyplot

# %% [markdown]
# load local library

# %%
sys.path.append(os.path.join(os.getcwd() , ".."))
import lib.Map.Map as map
import lib.Renderer.Renderer as renderer
from lib.Renderer.GraphViewer import showData
from lib.Renderer.LocationStatistic import showPieChart
import threading
import lib.Simulation.Simulator as Simulator

# %%
print(map.Map.__doc__)
# Out:
#     [Class] Map
#     A class to represent the map
#
#     Properties:
#         - origin        : [Coordinate] map's origin coordinate
#         - end           : [Coordinate] map's end coordinate
#         - num_nodes     : Number of Nodes.
#         - nodesDict     : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - nodes         : List of all nodes.
#
#         - num_ways      : Number of Ways.
#         - waysDict      : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - ways          : List of all ways.
#
#         - num_roads     : Number of Roads.
#         - roadNodesDict :
#         - roadNodes     :
#         - roadsDict     : List of all nodes that marked as road.
#         - roads         : List of all roads.
#
#         - num_buildings : Number of Buildings.
#         - buildings     : List of all buildings.
#         - naturals      : List of all naturals.
#         - leisures      : List of all leisures.
#         - amenities     : List of all amenities.
#
#         - grids         : [(int,int)] Two dimensional array of grids
#
#         - others        : List of other openstreetmap ways that yet to be categorized.
#         - distanceLat   : height of 1 grid in latitude
#         - distanceLon   : width of 1 grid in longitude
#         - gridsize      : tuple of 2 integer that shows how many grids we have

# %%
print(map.readFile.__doc__)
# Out:
#     [Function] readFile
#     Function to generate map fom osm File
#
#     parameter:
#         - filepath : [string] path to the OSM file
#         - grid     : [(int,int)] grid size, default value = (10,10)

# %%
dataDirectory = os.path.join("..","osmData")
filename = "TX-To-TU.osm"
filepath = os.path.join(dataDirectory,filename)

buildingConfigPath = os.path.join("..","config","tsukuba-tu-building-data.csv")

# %%
osmMap = map.readFile(filepath,buildingCSV = buildingConfigPath)
# Out:
# 0.002800000000002001,0.004399999999999693
# error, Heron's formula is not working due to very small angle
# ['9', '0', '0', 'All', 'laboratory']
# ['9', '0', '1', 'All', 'residential']
# ['9', '0', '2', '1', 'barbershop']
# ['9', '0', '2', '1', 'retail']
# ['9', '0', '2', 'All', 'residential']
# ['8', '1', '0', '5', 'office']
# ['8', '1', '0', 'All', 'residential']
# ['8', '1', '1', '2', 'laboratory']
# ['8', '1', '1', 'All', 'laboratory']
# ['8', '1', '2', 'All', 'residential']
# ['8', '1', '3', 'All', 'laboratory']
# ['8', '1', '4', 'All', 'university']
# ['8', '1', '7', '3', 'retail']
# ['8', '1', '7', 'All', 'office']
# ['8', '1', '8', '1', 'clinic']
# ['8', '1', '8', '1', 'residential']
# ['8', '1', '8', '1', 'skill school']
# ['8', '1', '8', 'All', 'retail']
# ['7', '2', '1', 'All', 'laboratory']
# ['7', '2', '2', 'All', 'university']
# ['7', '2', '3', '1', 'retail']
# ['6', '3', '3', '3', 'residential']
# ['7', '2', '3', 'All', 'university']
# ['7', '2', '4', 'All', 'laboratory']
# ['7', '2', '5', '4', 'house']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', 'All', 'apartments']
# ['7', '2', '6', '1', 'house']
# ['7', '2', '6', '1', 'office']
# ['7', '2', '6', '1', 'university']
# ['7', '2', '6', '3', 'retail']
# ['7', '2', '6', '4', 'residential']
# ['7', '2', '6', 'All', 'apartments']
# ['7', '2', '7', '1', 'office']
# ['7', '2', '7', '2', 'retail']
# ['7', '2', '7', 'All', 'apartments']
# ['7', '2', '7', 'All', 'apartments']
# ['7', '2', '8', '1', 'office']
# ['7', '2', '8', 'All', 'retail']
# ['6', '3', '0', '2', 'apartments']
# ['6', '3', '0', 'All', 'house']
# ['6', '3', '1', '1', 'pachinko']
# ['6', '3', '1', 'All', 'house']
# ['6', '3', '2', '13', 'laboratory']
# ['6', '3', '3', '1', 'barbershop']
# ['6', '3', '3', 'All', 'University']
# ['6', '3', '4', '1', 'church']
# ['6', '3', '4', '1', 'office']
# ['6', '3', '4', '1', 'residential']
# ['6', '3', '4', '1', 'retail']
# ['6', '3', '4', 'All', 'apartments']
# ['6', '3', '5', '1', 'retail']
# ['6', '3', '5', '3', 'residential']
# ['6', '3', '5', 'All', 'apartments']
# ['6', '3', '6', '4', 'retail']
# ['6', '3', '6', '15', 'residential']
# ['6', '3', '6', 'All', 'apartments']
# ['6', '3', '7', '1', 'clinic']
# ['6', '3', '7', '1', 'office']
# ['6', '3', '7', '3', 'barbershop']
# ['6', '3', '7', '4', 'retail']
# ['6', '3', '7', 'All', 'apartments']
# ['6', '3', '8', '2', 'residential']
# ['6', '3', '8', 'All', 'apartments']
# ['5', '4', '0', '1', 'house']
# ['5', '4', '0', 'All', 'apartments']
# ['5', '4', '1', 'All', 'house']
# ['5', '4', '2', '2', 'barbershop']
# ['5', '4', '2', '4', 'house']
# ['5', '4', '2', '4', 'residential']
# ['5', '4', '2', 'All', 'apartments']
# ['5', '4', '3', '2', 'residential']
# ['5', '4', '3', '4', 'hall']
# ['5', '4', '3', '8', 'apartments']
# ['5', '4', '3', 'All', 'university']
# ['5', '4', '4', 'All', 'university']
# ['5', '4', '5', 'All', 'university']
# ['5', '4', '6', 'All', 'museum']
# ['5', '4', '7', 'All', 'museum']
# ['4', '5', '0', '1', 'nursery']
# ['4', '5', '0', 'All', 'miscellaneous']
# ['4', '5', '1', '1', 'clinic']
# ['4', '5', '1', '1', 'karaoke_box']
# ['4', '5', '1', '1', 'skill school']
# ['4', '5', '1', '2', 'residential']
# ['4', '5', '1', '2', 'retail']
# ['4', '5', '1', 'All', 'apartments']
# ['4', '5', '2', '1', 'barbershop']
# ['4', '5', '2', '1', 'university']
# ['4', '5', '2', '2', 'retail']
# ['4', '5', '2', '3', 'restaurant']
# ['4', '5', '2', 'All', 'apartments']
# ['4', '5', '3', '1', 'retail']
# ['4', '5', '3', '3', 'restaurant']
# ['4', '5', '3', '3', 'university']
# ['4', '5', '3', '4', 'residential']
# ['4', '5', '3', 'All', 'apartments']
# ['4', '5', '4', '1', 'office']
# ['4', '5', '4', '1', 'retail']
# ['4', '5', '4', '2', 'restaurant']
# ['4', '5', '4', 'All', 'residential']
# ['4', '5', '5', '4', 'restaurant']
# ['4', '5', '5', 'All', 'apartments']
# ['4', '5', '6', 'All', 'museum']
# ['4', '5', '8', 'All', 'hall']
# ['3', '6', '0', '1', 'office']
# ['3', '6', '0', '2', 'apartments']
# ['3', '6', '0', 'All', 'house']
# ['3', '6', '1', '1', 'laboratory']
# ['3', '6', '1', '1', 'restaurant']
# ['3', '6', '1', 'All', 'house']
# ['3', '6', '2', '3', 'laboratory']
# ['3', '6', '2', 'All', 'apartments']
# ['3', '6', '3', '1', 'hospital']
# ['3', '6', '3', 'All', 'laboratory']
# ['3', '6', '4', '1', 'hospital']
# ['3', '6', '4', '2', 'laboratory']
# ['3', '6', '4', 'All', 'residential']
# ['3', '6', '5', '1', 'barbershop']
# ['3', '6', '5', '1', 'school']
# ['3', '6', '5', '4', 'retail']
# ['3', '6', '5', '6', 'restaurant']
# ['3', '6', '5', 'All', 'apartments']
# ['3', '6', '6', '1', 'karaoke_box']
# ['3', '6', '6', '1', 'retail']
# ['3', '6', '6', 'All', 'apartments']
# ['3', '6', '7', 'All', 'apartments']
# ['2', '7', '1', 'All', 'apartments']
# ['2', '7', '2', '1', 'laboratory']
# ['2', '7', '2', '2', 'restaurant']
# ['2', '7', '2', '2', 'retail']
# ['2', '7', '2', 'All', 'apartments']
# ['2', '7', '3', '3', 'office']
# ['2', '7', '3', 'All', 'apartments']
# ['2', '7', '4', '1', 'hospital']
# ['2', '7', '4', '1', 'university']
# ['2', '7', '4', 'All', 'apartments']
# ['2', '7', '5', '2', 'hall']
# ['2', '7', '5', '3', 'university']
# ['2', '7', '5', 'All', 'laboratory']
# ['2', '7', '6', '1', 'restaurant']
# ['2', '7', '6', '1', 'retail']
# ['2', '7', '6', 'All', 'apartments']
# ['2', '7', '7', '1', 'clinic']
# ['2', '7', '7', '2', 'hospital']
# ['2', '7', '7', '3', 'restaurant']
# ['2', '7', '7', '3', 'retail']
# ['2', '7', '7', 'All', 'apartments']
# ['2', '7', '8', '1', 'laboratory']
# ['2', '7', '8', '1', 'skill school']
# ['2', '7', '8', 'All', 'apartments']
# ['1', '8', '0', '3', 'retail']
# ['1', '8', '0', 'All', 'house']
# ['1', '8', '1', '1', 'apartments']
# ['1', '8', '1', '1', 'clinic']
# ['1', '8', '1', '1', 'restaurant']
# ['1', '8', '1', '1', 'retail']
# ['1', '8', '1', '1', 'skill school']
# ['1', '8', '1', 'All', 'house']
# ['1', '8', '2', '1', 'restaurant']
# ['1', '8', '2', '1', 'retail']
# ['1', '8', '2', '2', 'office']
# ['1', '8', '2', 'All', 'apartments']
# ['1', '8', '3', '1', 'office']
# ['1', '8', '3', '1', 'restaurant']
# ['1', '8', '3', '1', 'retail']
# ['1', '8', '3', '1', 'skill school']
# ['1', '8', '3', '2', 'barbershop']
# ['1', '8', '3', 'All', 'apartments']
# ['1', '8', '4', '1', 'restaurant']
# ['1', '8', '4', 'All', 'office']
# ['1', '8', '5', '1', 'restaurant']
# ['1', '8', '5', '1', 'university']
# ['1', '8', '5', 'All', 'residential']
# ['1', '8', '6', '4', 'museum']
# ['1', '8', '6', 'All', 'school']
# ['1', '8', '7', '1', 'hotel']
# ['1', '8', '7', '1', 'skill school']
# ['1', '8', '7', 'All', 'apartments']
# ['1', '8', '8', '1', 'school']
# ['1', '8', '8', '3', 'office']
# ['1', '8', '8', 'All', 'apartments']
# ['1', '8', '9', 'All', 'apartments']
# ['0', '9', '1', '1', 'nursery']
# ['0', '9', '1', 'All', 'school']
# ['0', '9', '5', '1', 'hall']
# ['0', '9', '5', '1', 'restaurant']
# ['0', '9', '5', '2', 'hotel']
# ['0', '9', '5', 'All', 'apartments']
# ['0', '9', '6', '1', 'hotel']
# ['0', '9', '6', '1', 'mall']
# ['0', '9', '6', 'All', 'office']
# ['0', '9', '7', '1', 'apartments']
# ['0', '9', '7', '2', 'office']
# ['0', '9', '7', 'All', 'mall']
# ['0', '9', '8', '1', 'hall']
# ['0', '9', '8', '2', 'mall']
# ['0', '9', '8', '3', 'apartments']
# ['0', '9', '8', 'All', 'office']
# ['0', '9', '9', '1', 'mall']
# ['0', '9', '9', '1', 'office']
# ['0', '9', '9', 'All', 'apartments']

# %%
print(osmMap)
# Out:
# Epidemicon Map
#  number of nodes = 22469
#  number of ways = 3681
#  number of roads = 8134
#  number of roads node = 10760
#  number of buildings = 1752

# %%
sim = Simulator.Simulator("../config/jobs.csv",osmMap,agentNum = 2000,threadNumber = 8)
# Out:
# ['student', '9', '9', 'school', '4', '18', '5', '8', '9', 'weekday', '5', '5', 'no', '0']
# ['university_student', '4', '9', 'university', '18', '60', '5', '8', '14', 'weekday', '1', '5', 'no', '0']
# ['medical_doctor', '8', '24', 'public', '25', '70', '1', '0', '23', 'everyday', '5', '7', 'no', '0']
# ['teacher', '9', '9', 'school', '23', '70', '1', '8', '9', 'weekday', '5', '5', 'no', '0']
# ['university_professor ', '5', '9', 'school', '28', '70', '1', '8', '9', 'weekday', '3', '5', 'no', '0']
# ['salaryman_tsuchiura', '9', '9', 'train_station', '19', '70', '3', '8', '9', 'weekday', '5', '5', 'yes', '0.001']
# ['salaryman_tokyo', '9', '9', 'train_station', '19', '70', '3', '8', '9', 'weekday', '5', '5', 'yes', '0.001']
# ['convenience_store_employee', '8', '8', 'retail', '19', '70', '1', '0', '23', 'everyday', '3', '5', 'no', '0']
# ['test_job', '4', '5', 'school', '19', '70', '1', '0', '23', 'mon,tue', '2', '2', 'no', '0']
# Processed 0 lines.
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# ...
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays

# %%
len(sim.agents)
# Out:
# 1997

# %%
x = threading.Thread(target=showData, args=(sim,))
x.start()
sim.stepCount = 3600*8

# %%
#y = threading.Thread(target=showPieChart, args=(sim,))
#y.start()

# %%
renderer.render(osmMap,sim,stepLength = 300)
# Out:
# moving agents in renderer
# double click
# Current Time = 8:0.0
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:0.0
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:0.0
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 2
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 3
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# On The Road = 1
# school = 4
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 5
# On The Road = 1
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 5
# On The Road = 1
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 5
# On The Road = 1
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 6
# On The Road = 1
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 6
# On The Road = 1
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 6
# On The Road = 1
# Going out of city = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 6
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 6
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 6
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 6
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 6
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 6
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 6
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 7
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 7
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 7
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 8
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 9
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 9
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 10
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 11
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 12
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 12
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:0.0
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 13:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:0.0
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 13
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 14
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 15
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 15
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 15
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 15
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 15
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 15
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 15
# On The Road = 1
# Going out of city = 2
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 15
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 15
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 14:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 16
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:0.0
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 16
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 17
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 17
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 18
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 18
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 18
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 18
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 18
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 18
# On The Road = 1
# Going out of city = 3
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 4
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 4
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 15:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 4
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 4
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 4
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 4
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 4
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 4
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 4
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 16:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 17:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 5
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:0.0
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 18:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# Going out of city = 6
# public = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 19:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:0.0
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 20:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:0.0
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# On The Road = 1
# public = 2
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 21:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 22:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 3
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 23:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:0.0
# VBox()
# VBox()
# VBox()
# VBox()
#  Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:0.0
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:0.0
# VBox()
# VBox()
#    Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:0.0
# VBox()
# VBox()
#    Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# school = 19
# public = 4
# On The Road = 1
# Going out of city = 6
#
#
# ...
# moving agents in renderer
# Current Time = 6:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:0.0
# VBox()
# VBox()
#   Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 63
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 64
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 64
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 64
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 64
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 64
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 64
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 64
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 7:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 226
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 227
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 227
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 227
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 8:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 227
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:0.0
# VBox()
#      double click
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 227
# public = 52
# On The Road = 20
#
#
# finish stepping
# moving agents in renderer
# double click
# Current Time = 9:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 227
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 228
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 228
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 228
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 228
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 229
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 229
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 230
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 230
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 230
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 9:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 230
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 230
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 230
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 31
# Home = 65
# school = 230
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 230
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 231
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 231
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 231
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 231
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 231
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 231
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 231
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 10:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 231
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 231
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 231
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 232
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 232
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 232
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 232
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 232
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 232
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 232
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 232
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 234
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 11:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 235
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:0.0
# VBox()
#     Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 236
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 236
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# Current Time = 12:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 80
# Going out of city = 32
# Home = 65
# school = 236
# public = 52
# On The Road = 21
#
#
# finish stepping
# moving agents in renderer
# double click

# %%
sim.history

# %%
sim.history

# %% [markdown]
# showData(sim)

# %% [markdown]
# sim.stepCount = 3600*8

# %% [markdown]
# x = threading.Thread(target=renderer.render, args=(osmMap,sim,))
# x.start()

# %% [markdown]
# showData(sim)

# %% [markdown]
# a = [(45,'for', 24), (3,'Geeks', 8), (20,'Geeks', 30)]
# a.sort(key=lambda x:x[1])
# a

# %% [markdown]
# result

# %% [markdown]
# print(osmMap.buildingsMap["b586"])
# print(osmMap.buildingsMap["b586"].node)
# print(osmMap.buildingsMap["b586"].entryPoint)

# %% [markdown]
# for x in sim.agents:
#     print(x.mainJob.isWorking(0,8))

# %% [markdown]
# agent = sim.agents[1]

# %% [markdown]
# agent.step(0,8,steps=15)

# %% [markdown]
# sim.currentHour()

# %% [markdown]
# print(agent.activeSequence)

# %% [markdown]
# osmMap.findPath(agent,agent.mainJob.building)

# %% [markdown]
# x = agent.currentNode.getMovementSequence(agent.mainJob.building.node)
# print (x)

# %% [markdown]
# print(agent.currentNode)
# print(agent.home.node())

# %% [markdown]
# agent.mainJob.isWorking(0,8)

# %% [markdown]
# agent.mainJob.workdays

# %% [markdown]
# b = agent.currentNode.getMovementSequence(agent.mainJob.building.node)
# print(b)

# %% [markdown]
# from lib.Map.PathFinder import searchPath
# distance, sequence = searchPath(osmMap,agent.currentNode,agent.mainJob.building.node)

# %% [markdown]
# sequence

# %% [markdown]
# distance

# %% [markdown]
# agent.setMovementSequence(activeSequence)

# %% [markdown]
# agent.currentNode.addMovementSequence(sequence.clone())
