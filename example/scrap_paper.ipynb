# %% [markdown]
# # Load Library
# load global library

# %% [markdown]
# import matplotlib
# matplotlib.use("TkAgg")
# import matplotlib.pyplot as plt
# from time import time
# from random import random
#
# plt.ion()
# # set up the figure
# fig = plt.figure()
# plt.xlabel('Time')
# plt.ylabel('Value')
#
# plt.show(block=False)
#
# def mypause(interval):
#     backend = plt.rcParams['backend']
#     if backend in matplotlib.rcsetup.interactive_bk:
#         figManager = matplotlib._pylab_helpers.Gcf.get_active()
#         if figManager is not None:
#             canvas = figManager.canvas
#             if canvas.figure.stale:
#                 canvas.draw()
#             canvas.start_event_loop(interval)
#             return
#
#
# t0 = time()
# t = []
# y = []
# while True:
#     t.append( time()-t0 )
#     y.append( random() )
#     plt.gca().clear()
#     plt.plot( t , y )
#     mypause(1)

# %%
import random

a =[]
for i in range(0,10000):
    a.append(random.randint(0,1000))
i =int(0) 
chunks = [a[100*i:100*(i+1)] for i in range(int(len(a)/100) + 1)]
print (chunks)
# Out:
# [[43, 564, 174, 208, 384, 159, 973, 468, 774, 761, 387, 308, 569, 378, 825, 231, 873, 932, 238, 351, 582, 198, 986, 76, 89, 286, 324, 209, 254, 928, 338, 956, 452, 415, 868, 14, 47, 448, 72, 92, 273, 690, 640, 184, 692, 56, 566, 650, 851, 830, 398, 865, 328, 529, 76, 730, 319, 169, 520, 465, 114, 157, 877, 420, 344, 531, 619, 574, 211, 142, 81, 623, 192, 818, 643, 966, 848, 355, 86, 268, 21, 247, 389, 84, 349, 643, 10, 67, 511, 393, 30, 890, 613, 604, 150, 756, 902, 571, 742, 744], [872, 695, 463, 387, 570, 633, 545, 12, 346, 6, 763, 521, 637, 982, 464, 633, 632, 914, 254, 857, 985, 542, 611, 892, 651, 565, 226, 239, 61, 516, 434, 598, 256, 518, 476, 467, 173, 423, 392, 788, 918, 748, 627, 252, 448, 495, 719, 930, 8, 388, 876, 108, 54, 66, 98, 84, 184, 921, 369, 950, 993, 74, 568, 956, 626, 754, 7, 11, 303, 553, 725, 904, 239, 225, 25, 496, 892, 578, 660, 219, 687, 165, 146, 937, 604, 677, 280, 252, 938, 27, 551, 536, 395, 285, 502, 783, 243, 18, 318, 864], [893, 619, 162, 812, 915, 55, 764, 796, 624, 986, 455, 843, 765, 642, 31, 328, 369, 251, 49, 412, 495, 199, 624, 838, 940, 75, 895, 510, 569, 168, 824, 576, 197, 499, 421, 816, 684, 531, 820, 636, 744, 563, 390, 572, 683, 346, 173, 570, 96, 55, 682, 102, 974, 732, 434, 75, 929, 630, 175, 171, 772, 72, 196, 875, 302, 208, 20, 165, 742, 899, 141, 639, 727, 588, 39, 191, 452, 790, 496, 294, 358, 179, 643, 952, 998, 40, 238, 10, 305, 576, 551, 786, 552, 346, 885, 434, 353, 889, 191, 567], [562, 855, 133, 244, 876, 247, 997, 599, 763, 991, 892, 1, 847, 751, 309, 587, 175, 566, 708, 800, 265, 518, 835, 153, 202, 740, 780, 146, 941, 857, 305, 634, 244, 812, 891, 74, 181, 365, 549, 305, 359, 699, 161, 931, 766, 166, 496, 1, 551, 293, 629, 316, 85, 265, 934, 935, 507, 748, 524, 887, 965, 583, 165, 682, 616, 321, 189, 849, 787, 179, 792, 461, 581, 966, 937, 807, 715, 769, 803, 43, 429, 469, 897, 96, 135, 927, 840, 404, 584, 885, 997, 823, 146, 598, 374, 995, 320, 653, 127, 787], [434, 140, 164, 466, 879, 254, 17, 276, 783, 609, 866, 339, 815, 9, 71, 859, 176, 893, 823, 607, 183, 520, 126, 773, 578, 322, 669, 554, 194, 428, 347, 585, 8, 263, 871, 392, 903, 126, 369, 496, 947, 811, 738, 952, 304, 745, 181, 59, 6, 677, 777, 316, 909, 304, 579, 799, 50, 833, 608, 997, 88, 766, 728, 627, 679, 853, 893, 385, 809, 73, 251, 554, 709, 461, 624, 90, 586, 890, 616, 502, 363, 211, 749, 439, 195, 471, 206, 126, 768, 834, 485, 155, 99, 785, 310, 990, 220, 188, 890, 956], [176, 366, 700, 210, 805, 103, 835, 110, 320, 506, 344, 287, 916, 215, 43, 769, 717, 381, 489, 242, 441, 327, 20, 6, 793, 442, 750, 343, 919, 543, 808, 935, 303, 283, 226, 475, 459, 740, 274, 935, 790, 894, 947, 453, 726, 418, 588, 650, 994, 375, 177, 597, 446, 458, 650, 971, 635, 534, 528, 696, 722, 503, 143, 88, 363, 452, 330, 256, 15, 791, 82, 842, 761, 425, 771, 622, 162, 58, 573, 630, 552, 57, 658, 787, 505, 839, 486, 521, 913, 535, 114, 871, 14, 776, 233, 98, 873, 985, 815, 457], [701, 384, 152, 164, 687, 977, 411, 494, 730, 572, 234, 225, 496, 982, 275, 547, 260, 716, 900, 453, 810, 405, 774, 678, 64, 39, 887, 835, 35, 204, 367, 730, 872, 843, 338, 509, 284, 495, 228, 168, 275, 170, 114, 970, 597, 474, 133, 704, 462, 87, 334, 318, 622, 840, 428, 906, 182, 27, 735, 45, 576, 368, 781, 814, 542, 995, 610, 495, 95, 363, 749, 121, 936, 103, 416, 469, 870, 665, 707, 63, 161, 237, 257, 836, 845, 686, 445, 86, 402, 632, 93, 456, 265, 429, 499, 389, 596, 806, 61, 437], [537, 249, 506, 736, 280, 675, 140, 578, 970, 803, 910, 499, 606, 71, 166, 906, 467, 405, 971, 509, 773, 196, 736, 416, 203, 827, 906, 777, 25, 501, 32, 441, 810, 245, 812, 304, 243, 949, 642, 120, 960, 351, 231, 517, 565, 668, 856, 432, 659, 161, 545, 808, 2, 459, 255, 340, 679, 597, 372, 327, 641, 291, 960, 13, 408, 434, 628, 655, 0, 424, 817, 269, 103, 253, 377, 945, 509, 628, 394, 569, 53, 126, 880, 598, 503, 84, 656, 287, 334, 683, 587, 685, 12, 938, 45, 137, 841, 758, 166, 607], [33, 809, 504, 760, 581, 874, 687, 940, 454, 719, 890, 713, 717, 158, 531, 853, 485, ...

# %%
len(a)/100
# Out:
# 100.0

# %%
import sys
import os

# %% [markdown]
# import random
# infectionPercentage = (-23.28 * 0) + 10.0
# print(infectionPercentage)
# test = random.randint(0,int(100*100))
# print(f"{test} vs {int(infectionPercentage*100)}")

# %% [markdown]
# import matplotlib.pyplot

# %% [markdown]
# load local library

# %%
sys.path.append(os.path.join(os.getcwd() , ".."))
import lib.Map.Map as map
import lib.Renderer.Renderer as renderer
from lib.Renderer.GraphViewer import showData
import threading
import lib.Simulation.Simulator as Simulator

# %%
print(map.Map.__doc__)
# Out:
#     [Class] Map
#     A class to represent the map
#
#     Properties:
#         - origin        : [Coordinate] map's origin coordinate
#         - end           : [Coordinate] map's end coordinate
#         - num_nodes     : Number of Nodes.
#         - nodesDict     : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - nodes         : List of all nodes.
#
#         - num_ways      : Number of Ways.
#         - waysDict      : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - ways          : List of all ways.
#
#         - num_roads     : Number of Roads.
#         - roadNodesDict :
#         - roadNodes     :
#         - roadsDict     : List of all nodes that marked as road.
#         - roads         : List of all roads.
#
#         - num_buildings : Number of Buildings.
#         - buildings     : List of all buildings.
#         - naturals      : List of all naturals.
#         - leisures      : List of all leisures.
#         - amenities     : List of all amenities.
#
#         - grids         : [(int,int)] Two dimensional array of grids
#
#         - others        : List of other openstreetmap ways that yet to be categorized.
#         - distanceLat   : height of 1 grid in latitude
#         - distanceLon   : width of 1 grid in longitude
#         - gridsize      : tuple of 2 integer that shows how many grids we have

# %%
print(map.readFile.__doc__)
# Out:
#     [Function] readFile
#     Function to generate map fom osm File
#
#     parameter:
#         - filepath : [string] path to the OSM file
#         - grid     : [(int,int)] grid size, default value = (10,10)

# %%
dataDirectory = os.path.join("..","osmData")
filename = "TX-To-TU.osm"
filepath = os.path.join(dataDirectory,filename)

buildingConfigPath = os.path.join("..","config","tsukuba-tu-building-data.csv")

# %%
osmMap = map.readFile(filepath,buildingCSV = buildingConfigPath)
# Out:
# 0.002800000000002001,0.004399999999999693
# error, Heron's formula is not working due to very small angle
# ['9', '0', '0', 'All', 'laboratory']
# ['9', '0', '1', 'All', 'residential']
# ['9', '0', '2', '1', 'barbershop']
# ['9', '0', '2', '1', 'retail']
# ['9', '0', '2', 'All', 'residential']
# ['8', '1', '0', '5', 'office']
# ['8', '1', '0', 'All', 'residential']
# ['8', '1', '1', 'All', 'laboratory']
# ['8', '1', '2', 'All', 'residential']
# ['8', '1', '3', 'All', 'laboratory']
# ['8', '1', '4', 'All', 'university']
# ['8', '1', '7', '3', 'retail']
# ['8', '1', '7', 'All', 'office']
# ['8', '1', '8', '1', 'clinic']
# ['8', '1', '8', '1', 'residential']
# ['8', '1', '8', '1', 'skill school']
# ['8', '1', '8', 'All', 'retail']
# ['7', '2', '1', 'All', 'laboratory']
# ['7', '2', '2', 'All', 'university']
# ['7', '2', '3', '1', 'retail']
# ['7', '2', '3', '3', 'residential']
# ['7', '2', '3', 'All', 'university']
# ['7', '2', '4', 'All', 'laboratory']
# ['7', '2', '5', '4', 'house']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', 'All', 'apartments']
# ['7', '2', '6', '1', 'house']
# ['7', '2', '6', '1', 'office']
# ['7', '2', '6', '1', 'university']
# ['7', '2', '6', '3', 'retail']
# ['7', '2', '6', '4', 'residential']
# ['7', '2', '6', 'All', 'apartments']
# ['7', '2', '7', '1', 'office']
# ['7', '2', '7', '2', 'retail']
# ['7', '2', '7', 'All', 'apartments']
# ['7', '2', '7', 'All', 'apartments']
# ['7', '2', '8', '1', 'office']
# ['7', '2', '8', 'All', 'retail']
# ['6', '3', '0', '2', 'apartments']
# ['6', '3', '0', 'All', 'house']
# ['6', '3', '1', '1', 'pachinko']
# ['6', '3', '1', 'All', 'house']
# ['6', '3', '2', '13', 'laboratory']
# ['6', '3', '3', '1', 'barbershop']
# ['6', '3', '4', '1', 'church']
# ['6', '3', '4', '1', 'office']
# ['6', '3', '4', '1', 'residential']
# ['6', '3', '4', '1', 'retail']
# ['6', '3', '4', 'All', 'apartments']
# ['6', '3', '5', '1', 'retail']
# ['6', '3', '5', '3', 'residential']
# ['6', '3', '5', '5', 'apartments']
# ['6', '3', '5', 'All', 'university']
# ['6', '3', '6', '4', 'retail']
# ['6', '3', '6', '15', 'residential']
# ['6', '3', '6', 'All', 'apartments']
# ['6', '3', '7', '1', 'clinic']
# ['6', '3', '7', '1', 'office']
# ['6', '3', '7', '3', 'barbershop']
# ['6', '3', '7', '4', 'retail']
# ['6', '3', '7', 'All', 'apartments']
# ['6', '3', '8', '2', 'residential']
# ['6', '3', '8', 'All', 'apartments']
# ['5', '4', '0', '1', 'house']
# ['5', '4', '0', 'All', 'apartments']
# ['5', '4', '1', 'All', 'house']
# ['5', '4', '2', '2', 'barbershop']
# ['5', '4', '2', '4', 'house']
# ['5', '4', '2', '4', 'residential']
# ['5', '4', '2', 'All', 'apartments']
# ['5', '4', '3', '2', 'residential']
# ['5', '4', '3', '4', 'hall']
# ['5', '4', '3', '8', 'apartments']
# ['5', '4', '3', 'All', 'university']
# ['5', '4', '4', 'All', 'university']
# ['5', '4', '5', 'All', 'university']
# ['5', '4', '6', 'All', 'museum']
# ['5', '4', '7', 'All', 'museum']
# ['4', '5', '0', '1', 'nursery']
# ['4', '5', '0', 'All', 'miscellaneous']
# ['4', '5', '1', '1', 'clinic']
# ['4', '5', '1', '1', 'karaoke_box']
# ['4', '5', '1', '1', 'skill school']
# ['4', '5', '1', '2', 'residential']
# ['4', '5', '1', '2', 'retail']
# ['4', '5', '1', 'All', 'apartments']
# ['4', '5', '2', '1', 'barbershop']
# ['4', '5', '2', '1', 'university']
# ['4', '5', '2', '2', 'retail']
# ['4', '5', '2', '3', 'restaurant']
# ['4', '5', '2', 'All', 'apartments']
# ['4', '5', '3', '1', 'retail']
# ['4', '5', '3', '3', 'restaurant']
# ['4', '5', '3', '3', 'university']
# ['4', '5', '3', '4', 'residential']
# ['4', '5', '3', 'All', 'apartments']
# ['4', '5', '4', '1', 'office']
# ['4', '5', '4', '1', 'retail']
# ['4', '5', '4', '2', 'restaurant']
# ['4', '5', '4', 'All', 'residential']
# ['4', '5', '5', '4', 'restaurant']
# ['4', '5', '5', 'All', 'apartments']
# ['4', '5', '6', 'All', 'museum']
# ['4', '5', '8', 'All', 'hall']
# ['3', '6', '0', '1', 'office']
# ['3', '6', '0', '2', 'apartments']
# ['3', '6', '0', 'All', 'house']
# ['3', '6', '1', '1', 'laboratory']
# ['3', '6', '1', '1', 'restaurant']
# ['3', '6', '1', 'All', 'house']
# ['3', '6', '2', '3', 'laboratory']
# ['3', '6', '2', 'All', 'apartments']
# ['3', '6', '3', '1', 'hospital']
# ['3', '6', '3', 'All', 'laboratory']
# ['3', '6', '4', '1', 'hospital']
# ['3', '6', '4', '2', 'laboratory']
# ['3', '6', '4', 'All', 'residential']
# ['3', '6', '5', '1', 'barbershop']
# ['3', '6', '5', '1', 'school']
# ['3', '6', '5', '4', 'retail']
# ['3', '6', '5', '6', 'restaurant']
# ['3', '6', '5', 'All', 'apartments']
# ['3', '6', '6', '1', 'karaoke_box']
# ['3', '6', '6', '1', 'retail']
# ['3', '6', '6', 'All', 'apartments']
# ['3', '6', '7', 'All', 'apartments']
# ['2', '7', '1', 'All', 'apartments']
# ['2', '7', '2', '1', 'laboratory']
# ['2', '7', '2', '2', 'restaurant']
# ['2', '7', '2', '2', 'retail']
# ['2', '7', '2', 'All', 'apartments']
# ['2', '7', '3', '3', 'office']
# ['2', '7', '3', 'All', 'apartments']
# ['2', '7', '4', '1', 'hospital']
# ['2', '7', '4', '1', 'university']
# ['2', '7', '4', 'All', 'apartments']
# ['2', '7', '5', '2', 'hall']
# ['2', '7', '5', '3', 'university']
# ['2', '7', '5', 'All', 'laboratory']
# ['2', '7', '6', '1', 'restaurant']
# ['2', '7', '6', '1', 'retail']
# ['2', '7', '6', 'All', 'apartments']
# ['2', '7', '7', '1', 'clinic']
# ['2', '7', '7', '2', 'hospital']
# ['2', '7', '7', '3', 'restaurant']
# ['2', '7', '7', '3', 'retail']
# ['2', '7', '7', 'All', 'apartments']
# ['2', '7', '8', '1', 'laboratory']
# ['2', '7', '8', '1', 'skill school']
# ['2', '7', '8', 'All', 'apartments']
# ['1', '8', '0', '3', 'retail']
# ['1', '8', '0', 'All', 'house']
# ['1', '8', '1', '1', 'apartments']
# ['1', '8', '1', '1', 'clinic']
# ['1', '8', '1', '1', 'restaurant']
# ['1', '8', '1', '1', 'retail']
# ['1', '8', '1', '1', 'skill school']
# ['1', '8', '1', 'All', 'house']
# ['1', '8', '2', '1', 'restaurant']
# ['1', '8', '2', '1', 'retail']
# ['1', '8', '2', '2', 'office']
# ['1', '8', '2', 'All', 'apartments']
# ['1', '8', '3', '1', 'office']
# ['1', '8', '3', '1', 'restaurant']
# ['1', '8', '3', '1', 'retail']
# ['1', '8', '3', '1', 'skill school']
# ['1', '8', '3', '2', 'barbershop']
# ['1', '8', '3', 'All', 'apartments']
# ['1', '8', '4', '1', 'restaurant']
# ['1', '8', '4', 'All', 'office']
# ['1', '8', '5', '1', 'restaurant']
# ['1', '8', '5', '1', 'university']
# ['1', '8', '5', 'All', 'residential']
# ['1', '8', '6', '4', 'museum']
# ['1', '8', '6', 'All', 'school']
# ['1', '8', '7', '1', 'hotel']
# ['1', '8', '7', '1', 'skill school']
# ['1', '8', '7', 'All', 'apartments']
# ['1', '8', '8', '1', 'school']
# ['1', '8', '8', '3', 'office']
# ['1', '8', '8', 'All', 'apartments']
# ['1', '8', '9', 'All', 'apartments']
# ['0', '9', '1', '1', 'nursery']
# ['0', '9', '1', 'All', 'school']
# ['0', '9', '5', '1', 'hall']
# ['0', '9', '5', '1', 'restaurant']
# ['0', '9', '5', '2', 'hotel']
# ['0', '9', '5', 'All', 'apartments']
# ['0', '9', '6', '1', 'hotel']
# ['0', '9', '6', '1', 'mall']
# ['0', '9', '6', 'All', 'office']
# ['0', '9', '7', '1', 'apartments']
# ['0', '9', '7', '2', 'office']
# ['0', '9', '7', 'All', 'mall']
# ['0', '9', '8', '1', 'hall']
# ['0', '9', '8', '2', 'mall']
# ['0', '9', '8', '3', 'apartments']
# ['0', '9', '8', 'All', 'office']
# ['0', '9', '9', '1', 'mall']
# ['0', '9', '9', '1', 'office']
# ['0', '9', '9', 'All', 'apartments']

# %%
print(osmMap)
# Out:
# Epidemicon Map
#  number of nodes = 22469
#  number of ways = 3681
#  number of roads = 8134
#  number of roads node = 10760
#  number of buildings = 1752

# %%
sim = Simulator.Simulator("../config/jobs.csv",osmMap,agentNum = 10000,threadNumber = 8)
# Out:
# ['student', '9', '9', 'school', '4', '18', '5', '8', '9', 'weekday', '5', '5', 'no', '0']
# ['university_student', '4', '9', 'university', '18', '60', '5', '8', '14', 'weekday', '1', '5', 'no', '0']
# ['medical_doctor', '8', '24', 'public', '25', '70', '1', '0', '23', 'everyday', '5', '7', 'no', '0']
# ['teacher', '9', '9', 'school', '23', '70', '1', '8', '9', 'weekday', '5', '5', 'no', '0']
# ['university_professor ', '5', '9', 'school', '28', '70', '1', '8', '9', 'weekday', '3', '5', 'no', '0']
# ['salaryman_tsuchiura', '9', '9', 'train_station', '19', '70', '3', '8', '9', 'weekday', '5', '5', 'yes', '0.001']
# ['salaryman_tokyo', '9', '9', 'train_station', '19', '70', '3', '8', '9', 'weekday', '5', '5', 'yes', '0.001']
# ['convenience_store_employee', '8', '8', 'retail', '19', '70', '1', '0', '23', 'everyday', '3', '5', 'no', '0']
# ['test_job', '4', '5', 'school', '19', '70', '1', '0', '23', 'mon,tue', '2', '2', 'no', '0']
# Processed 0 lines.
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# ...
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays

# %%
len(sim.agents)
# Out:
# 9996

# %%
x = threading.Thread(target=showData, args=(sim,))
x.start()
sim.stepCount = 3600*8

# %%
renderer.render(osmMap,sim)
# Out:
# double click
# Start moving agents
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping
# Start moving agents
# VBox()
#     double click
# Finished moving agents, proceeding to check for infection
# Finished infection checking, proceeding to finalize the infection
# Finished finalizing the infection
# finish stepping

# %%
sim.history
# Out:
# {'Susceptible': [9916, 9846],
#  'Infectious': [80, 80],
#  'Exposed': [0, 70],
#  'Recovered': [0, 0]}

# %% [markdown]
# showData(sim)

# %% [markdown]
# sim.stepCount = 3600*8

# %% [markdown]
# x = threading.Thread(target=renderer.render, args=(osmMap,sim,))
# x.start()

# %% [markdown]
# showData(sim)

# %% [markdown]
# a = [(45,'for', 24), (3,'Geeks', 8), (20,'Geeks', 30)]
# a.sort(key=lambda x:x[1])
# a

# %% [markdown]
# result

# %% [markdown]
# print(osmMap.buildingsMap["b586"])
# print(osmMap.buildingsMap["b586"].node)
# print(osmMap.buildingsMap["b586"].entryPoint)

# %% [markdown]
# for x in sim.agents:
#     print(x.mainJob.isWorking(0,8))

# %% [markdown]
# agent = sim.agents[1]

# %% [markdown]
# agent.step(0,8,steps=15)

# %% [markdown]
# sim.currentHour()

# %% [markdown]
# print(agent.activeSequence)

# %% [markdown]
# osmMap.findPath(agent,agent.mainJob.building)

# %% [markdown]
# x = agent.currentNode.getMovementSequence(agent.mainJob.building.node)
# print (x)

# %% [markdown]
# print(agent.currentNode)
# print(agent.home.node())

# %% [markdown]
# agent.mainJob.isWorking(0,8)

# %% [markdown]
# agent.mainJob.workdays

# %% [markdown]
# b = agent.currentNode.getMovementSequence(agent.mainJob.building.node)
# print(b)

# %% [markdown]
# from lib.Map.PathFinder import searchPath
# distance, sequence = searchPath(osmMap,agent.currentNode,agent.mainJob.building.node)

# %% [markdown]
# sequence

# %% [markdown]
# distance

# %% [markdown]
# agent.setMovementSequence(activeSequence)

# %% [markdown]
# agent.currentNode.addMovementSequence(sequence.clone())
