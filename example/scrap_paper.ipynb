# %% [markdown]
# # Load Library
# load global library

# %%
import sys
import os

# %% [markdown]
# import random
# infectionPercentage = (-23.28 * 0) + 10.0
# print(infectionPercentage)
# test = random.randint(0,int(100*100))
# print(f"{test} vs {int(infectionPercentage*100)}")

# %% [markdown]
# import matplotlib.pyplot

# %% [markdown]
# load local library

# %%
sys.path.append(os.path.join(os.getcwd() , ".."))
import lib.Map.Map as map
import lib.Renderer.Renderer as renderer
from lib.Renderer.GraphViewer import showData
from lib.Renderer.LocationStatistic import showPieChart
import threading
import lib.Simulation.Simulator as Simulator

# %%
print(map.Map.__doc__)
# Out:
#     [Class] Map
#     A class to represent the map
#
#     Properties:
#         - origin        : [Coordinate] map's origin coordinate
#         - end           : [Coordinate] map's end coordinate
#         - num_nodes     : Number of Nodes.
#         - nodesDict     : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - nodes         : List of all nodes.
#
#         - num_ways      : Number of Ways.
#         - waysDict      : Dictionary of all nodes. The key used are the Open Street Map ID.
#         - ways          : List of all ways.
#
#         - num_roads     : Number of Roads.
#         - roadNodesDict :
#         - roadNodes     :
#         - roadsDict     : List of all nodes that marked as road.
#         - roads         : List of all roads.
#
#         - num_buildings : Number of Buildings.
#         - buildings     : List of all buildings.
#         - naturals      : List of all naturals.
#         - leisures      : List of all leisures.
#         - amenities     : List of all amenities.
#
#         - grids         : [(int,int)] Two dimensional array of grids
#
#         - others        : List of other openstreetmap ways that yet to be categorized.
#         - distanceLat   : height of 1 grid in latitude
#         - distanceLon   : width of 1 grid in longitude
#         - gridsize      : tuple of 2 integer that shows how many grids we have

# %%
print(map.readFile.__doc__)
# Out:
#     [Function] readFile
#     Function to generate map fom osm File
#
#     parameter:
#         - filepath : [string] path to the OSM file
#         - grid     : [(int,int)] grid size, default value = (10,10)

# %%
dataDirectory = os.path.join("..","osmData")
filename = "TX-To-TU.osm"
filepath = os.path.join(dataDirectory,filename)

buildingConfigPath = os.path.join("..","config","tsukuba-tu-building-data.csv")

# %%
osmMap = map.readFile(filepath,buildingCSV = buildingConfigPath)
# Out:
# 0.002800000000002001,0.004399999999999693
# error, Heron's formula is not working due to very small angle
# ['9', '0', '0', 'All', 'laboratory']
# ['9', '0', '1', 'All', 'residential']
# ['9', '0', '2', '1', 'barbershop']
# ['9', '0', '2', '1', 'retail']
# ['9', '0', '2', 'All', 'residential']
# ['8', '1', '0', '5', 'office']
# ['8', '1', '0', 'All', 'residential']
# ['8', '1', '1', '2', 'laboratory']
# ['8', '1', '1', 'All', 'laboratory']
# ['8', '1', '2', 'All', 'residential']
# ['8', '1', '3', 'All', 'laboratory']
# ['8', '1', '4', 'All', 'university']
# ['8', '1', '7', '3', 'retail']
# ['8', '1', '7', 'All', 'office']
# ['8', '1', '8', '1', 'clinic']
# ['8', '1', '8', '1', 'residential']
# ['8', '1', '8', '1', 'skill school']
# ['8', '1', '8', 'All', 'retail']
# ['7', '2', '1', 'All', 'laboratory']
# ['7', '2', '2', 'All', 'university']
# ['7', '2', '3', '1', 'retail']
# ['6', '3', '3', '3', 'residential']
# ['7', '2', '3', 'All', 'university']
# ['7', '2', '4', 'All', 'laboratory']
# ['7', '2', '5', '4', 'house']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', 'All', 'apartments']
# ['7', '2', '6', '1', 'house']
# ['7', '2', '6', '1', 'office']
# ['7', '2', '6', '1', 'university']
# ['7', '2', '6', '3', 'retail']
# ['7', '2', '6', '4', 'residential']
# ['7', '2', '6', 'All', 'apartments']
# ['7', '2', '7', '1', 'office']
# ['7', '2', '7', '2', 'retail']
# ['7', '2', '7', 'All', 'apartments']
# ['7', '2', '7', 'All', 'apartments']
# ['7', '2', '8', '1', 'office']
# ['7', '2', '8', 'All', 'retail']
# ['6', '3', '0', '2', 'apartments']
# ['6', '3', '0', 'All', 'house']
# ['6', '3', '1', '1', 'pachinko']
# ['6', '3', '1', 'All', 'house']
# ['6', '3', '2', '13', 'laboratory']
# ['6', '3', '3', '1', 'barbershop']
# ['6', '3', '3', 'All', 'University']
# ['6', '3', '4', '1', 'church']
# ['6', '3', '4', '1', 'office']
# ['6', '3', '4', '1', 'residential']
# ['6', '3', '4', '1', 'retail']
# ['6', '3', '4', 'All', 'apartments']
# ['6', '3', '5', '1', 'retail']
# ['6', '3', '5', '3', 'residential']
# ['6', '3', '5', 'All', 'apartments']
# ['6', '3', '6', '4', 'retail']
# ['6', '3', '6', '15', 'residential']
# ['6', '3', '6', 'All', 'apartments']
# ['6', '3', '7', '1', 'clinic']
# ['6', '3', '7', '1', 'office']
# ['6', '3', '7', '3', 'barbershop']
# ['6', '3', '7', '4', 'retail']
# ['6', '3', '7', 'All', 'apartments']
# ['6', '3', '8', '2', 'residential']
# ['6', '3', '8', 'All', 'apartments']
# ['5', '4', '0', '1', 'house']
# ['5', '4', '0', 'All', 'apartments']
# ['5', '4', '1', 'All', 'house']
# ['5', '4', '2', '2', 'barbershop']
# ['5', '4', '2', '4', 'house']
# ['5', '4', '2', '4', 'residential']
# ['5', '4', '2', 'All', 'apartments']
# ['5', '4', '3', '2', 'residential']
# ['5', '4', '3', '4', 'hall']
# ['5', '4', '3', '8', 'apartments']
# ['5', '4', '3', 'All', 'university']
# ['5', '4', '4', 'All', 'university']
# ['5', '4', '5', 'All', 'university']
# ['5', '4', '6', 'All', 'museum']
# ['5', '4', '7', 'All', 'museum']
# ['4', '5', '0', '1', 'nursery']
# ['4', '5', '0', 'All', 'miscellaneous']
# ['4', '5', '1', '1', 'clinic']
# ['4', '5', '1', '1', 'karaoke_box']
# ['4', '5', '1', '1', 'skill school']
# ['4', '5', '1', '2', 'residential']
# ['4', '5', '1', '2', 'retail']
# ['4', '5', '1', 'All', 'apartments']
# ['4', '5', '2', '1', 'barbershop']
# ['4', '5', '2', '1', 'university']
# ['4', '5', '2', '2', 'retail']
# ['4', '5', '2', '3', 'restaurant']
# ['4', '5', '2', 'All', 'apartments']
# ['4', '5', '3', '1', 'retail']
# ['4', '5', '3', '3', 'restaurant']
# ['4', '5', '3', '3', 'university']
# ['4', '5', '3', '4', 'residential']
# ['4', '5', '3', 'All', 'apartments']
# ['4', '5', '4', '1', 'office']
# ['4', '5', '4', '1', 'retail']
# ['4', '5', '4', '2', 'restaurant']
# ['4', '5', '4', 'All', 'residential']
# ['4', '5', '5', '4', 'restaurant']
# ['4', '5', '5', 'All', 'apartments']
# ['4', '5', '6', 'All', 'museum']
# ['4', '5', '8', 'All', 'hall']
# ['3', '6', '0', '1', 'office']
# ['3', '6', '0', '2', 'apartments']
# ['3', '6', '0', 'All', 'house']
# ['3', '6', '1', '1', 'laboratory']
# ['3', '6', '1', '1', 'restaurant']
# ['3', '6', '1', 'All', 'house']
# ['3', '6', '2', '3', 'laboratory']
# ['3', '6', '2', 'All', 'apartments']
# ['3', '6', '3', '1', 'hospital']
# ['3', '6', '3', 'All', 'laboratory']
# ['3', '6', '4', '1', 'hospital']
# ['3', '6', '4', '2', 'laboratory']
# ['3', '6', '4', 'All', 'residential']
# ['3', '6', '5', '1', 'barbershop']
# ['3', '6', '5', '1', 'school']
# ['3', '6', '5', '4', 'retail']
# ['3', '6', '5', '6', 'restaurant']
# ['3', '6', '5', 'All', 'apartments']
# ['3', '6', '6', '1', 'karaoke_box']
# ['3', '6', '6', '1', 'retail']
# ['3', '6', '6', 'All', 'apartments']
# ['3', '6', '7', 'All', 'apartments']
# ['2', '7', '1', 'All', 'apartments']
# ['2', '7', '2', '1', 'laboratory']
# ['2', '7', '2', '2', 'restaurant']
# ['2', '7', '2', '2', 'retail']
# ['2', '7', '2', 'All', 'apartments']
# ['2', '7', '3', '3', 'office']
# ['2', '7', '3', 'All', 'apartments']
# ['2', '7', '4', '1', 'hospital']
# ['2', '7', '4', '1', 'university']
# ['2', '7', '4', 'All', 'apartments']
# ['2', '7', '5', '2', 'hall']
# ['2', '7', '5', '3', 'university']
# ['2', '7', '5', 'All', 'laboratory']
# ['2', '7', '6', '1', 'restaurant']
# ['2', '7', '6', '1', 'retail']
# ['2', '7', '6', 'All', 'apartments']
# ['2', '7', '7', '1', 'clinic']
# ['2', '7', '7', '2', 'hospital']
# ['2', '7', '7', '3', 'restaurant']
# ['2', '7', '7', '3', 'retail']
# ['2', '7', '7', 'All', 'apartments']
# ['2', '7', '8', '1', 'laboratory']
# ['2', '7', '8', '1', 'skill school']
# ['2', '7', '8', 'All', 'apartments']
# ['1', '8', '0', '3', 'retail']
# ['1', '8', '0', 'All', 'house']
# ['1', '8', '1', '1', 'apartments']
# ['1', '8', '1', '1', 'clinic']
# ['1', '8', '1', '1', 'restaurant']
# ['1', '8', '1', '1', 'retail']
# ['1', '8', '1', '1', 'skill school']
# ['1', '8', '1', 'All', 'house']
# ['1', '8', '2', '1', 'restaurant']
# ['1', '8', '2', '1', 'retail']
# ['1', '8', '2', '2', 'office']
# ['1', '8', '2', 'All', 'apartments']
# ['1', '8', '3', '1', 'office']
# ['1', '8', '3', '1', 'restaurant']
# ['1', '8', '3', '1', 'retail']
# ['1', '8', '3', '1', 'skill school']
# ['1', '8', '3', '2', 'barbershop']
# ['1', '8', '3', 'All', 'apartments']
# ['1', '8', '4', '1', 'restaurant']
# ['1', '8', '4', 'All', 'office']
# ['1', '8', '5', '1', 'restaurant']
# ['1', '8', '5', '1', 'university']
# ['1', '8', '5', 'All', 'residential']
# ['1', '8', '6', '4', 'museum']
# ['1', '8', '6', 'All', 'school']
# ['1', '8', '7', '1', 'hotel']
# ['1', '8', '7', '1', 'bus_terminal']
# ['1', '8', '7', 'All', 'apartments']
# ['1', '8', '8', '1', 'school']
# ['1', '8', '8', '3', 'office']
# ['1', '8', '8', 'All', 'apartments']
# ['1', '8', '9', 'All', 'apartments']
# ['0', '9', '1', '1', 'nursery']
# ['0', '9', '1', 'All', 'school']
# ['0', '9', '5', '1', 'hall']
# ['0', '9', '5', '1', 'restaurant']
# ['0', '9', '5', '2', 'hotel']
# ['0', '9', '5', 'All', 'apartments']
# ['0', '9', '6', '1', 'hotel']
# ['0', '9', '6', '1', 'mall']
# ['0', '9', '6', 'All', 'office']
# ['0', '9', '7', '1', 'apartments']
# ['0', '9', '7', '2', 'office']
# ['0', '9', '7', 'All', 'mall']
# ['0', '9', '8', '1', 'hall']
# ['0', '9', '8', '2', 'mall']
# ['0', '9', '8', '3', 'apartments']
# ['0', '9', '8', 'All', 'office']
# ['0', '9', '9', '1', 'mall']
# ['0', '9', '9', '1', 'office']
# ['0', '9', '9', 'All', 'apartments']

# %%
print(osmMap)
# Out:
# Epidemicon Map
#  number of nodes = 22469
#  number of ways = 3681
#  number of roads = 8134
#  number of roads node = 10760
#  number of buildings = 1752

# %%
sim = Simulator.Simulator("../config/jobs.csv",osmMap,agentNum = 1000,threadNumber = 6, infectedAgent = 0.1)
# Out:
# ['student', '9', '9', 'school', '4', '18', '5', '8', '9', 'weekday', '5', '5', 'no']
# ['university_student', '4', '9', 'university', '18', '60', '5', '8', '14', 'weekday', '1', '5', 'no']
# ['medical_doctor', '8', '24', 'hospital', '25', '70', '1', '0', '23', 'everyday', '5', '7', 'no']
# ['teacher', '9', '9', 'school', '23', '70', '1', '8', '9', 'weekday', '5', '5', 'no']
# ['university_professor ', '5', '9', 'university', '28', '70', '1', '8', '9', 'weekday', '3', '5', 'no']
# ['salaryman_tsuchiura', '9', '9', 'train_station', '19', '70', '3', '8', '9', 'weekday', '5', '5', 'yes']
# ['salaryman_tokyo', '9', '9', 'train_station', '19', '70', '3', '8', '9', 'weekday', '5', '5', 'yes']
# ['convenience_store_employee', '8', '8', 'retail', '19', '70', '1', '0', '23', 'everyday', '3', '5', 'no']
# ['salaryman', '4', '5', 'office', '19', '70', '5', '8', '10', 'weekday', '5', '5', 'no']
# ['barber', '7', '8', 'barbershop', '20', '70', '1', '8', '12', 'everyday', '5', '6', 'no']
# ['clinic_doctor', '8', '24', 'clinic', '25', '70', '1', '0', '23', 'everyday', '5', '7', 'no']
# ['restaurant_worker', '8', '10', 'restaurant', '16', '70', '1', '0', '18', 'everyday', '5', '7', 'no']
# ['scientist', '5', '9', 'laboratory', '21', '70', '2', '8', '9', 'weekday', '3', '5', 'no']
# Processed 0 lines.
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays

# %%
len(sim.agents)
# Out:
# 995

# %%
x = threading.Thread(target=showData, args=(sim,))
x.start()
#sim.stepCount = 3600*8

# %%
#y = threading.Thread(target=showPieChart, args=(sim,))
#y.start()

# %%
renderer.render(osmMap,sim,stepLength = 300)
# Out:
# double click
# Current Time = 0:0.0
#   agent id 527 is eating outside
# VBox()
# VBox()
# agent id 382 is eating outside
# VBox()
# agent id 7 is eating outside
# agent id 198 is eating outside
# agent id 303 is eating outside
# agent id 925 is eating outside
# VBox()
# agent id 595 is eating outside
#  agent id 282 is eating outside
# VBox()
#  agent id 180 is eating outside
# agent id 263 is eating outside
# VBox()
# agent id 768 is eating outside
# agent id 238 is eating outside
# agent id 284 is eating outside
# agent id 612 is eating outside
# agent id 986 is eating outside
# agent id 920 is eating outside
# agent id 85 is eating outside
# agent id 665 is eating outside
# agent id 607 is eating outside
# agent id 681 is eating outside
# agent id 171 is eating outside
# agent id 539 is eating outside
# agent id 839 is eating outside
# agent id 773 is eating outside
# agent id 73 is eating outside
# agent id 264 is eating outside
# agent id 272 is eating outside
# agent id 927 is eating outside
# agent id 716 is eating outside
# agent id 96 is eating outside
# agent id 444 is eating outside
# agent id 933 is eating outside
# agent id 88 is eating outside
# agent id 376 is eating outside
# agent id 311 is eating outside
# agent id 682 is eating outside
# agent id 684 is eating outside
# agent id 831 is eating outside
# agent id 570 is eating outside
# agent id 936 is eating outside
# agent id 173 is eating outside
# agent id 820 is eating outside
# agent id 343 is eating outside
# agent id 643 is eating outside
# agent id 747 is eating outside
# agent id 872 is eating outside
# agent id 55 is eating outside
# agent id 601 is eating outside
# agent id 355 is eating outside
# agent id 868 is eating outside
# agent id 714 is eating outside
# agent id 234 is eating outside
# agent id 613 is eating outside
# agent id 390 is eating outside
# agent id 979 is eating outside
# agent id 434 is eating outside
# agent id 880 is eating outside
# agent id 963 is eating outside
# Finished finalizing the infection
#
# known infection location
# Initial = 99
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 0:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:0.0
#   agent id 140 is eating outside
# VBox()
#    agent id 925 is eating outside
# agent id 629 is eating outside
# agent id 321 is eating outside
# agent id 767 is eating outside
# agent id 706 is eating outside
# agent id 190 is eating outside
# agent id 199 is eating outside
# agent id 946 is eating outside
# agent id 729 is eating outside
# agent id 887 is eating outside
# agent id 198 is eating outside
# agent id 240 is eating outside
# agent id 662 is eating outside
# agent id 435 is eating outside
# agent id 207 is eating outside
# agent id 855 is eating outside
# agent id 247 is eating outside
# agent id 685 is eating outside
# agent id 316 is eating outside
# agent id 135 is eating outside
# agent id 776 is eating outside
# agent id 228 is eating outside
# agent id 854 is eating outside
# agent id 804 is eating outside
# agent id 878 is eating outside
# agent id 669 is eating outside
# agent id 34 is eating outside
# agent id 193 is eating outside
# agent id 848 is eating outside
# agent id 153 is eating outside
# agent id 627 is eating outside
# agent id 422 is eating outside
# agent id 702 is eating outside
# agent id 955 is eating outside
# agent id 172 is eating outside
# agent id 428 is eating outside
# agent id 769 is eating outside
# agent id 89 is eating outside
# agent id 21 is eating outside
# agent id 789 is eating outside
# agent id 994 is eating outside
# agent id 939 is eating outside
# agent id 239 is eating outside
# agent id 661 is eating outside
# agent id 284 is eating outside
# agent id 389 is eating outside
# agent id 98 is eating outside
# agent id 836 is eating outside
# agent id 493 is eating outside
# agent id 112 is eating outside
# agent id 734 is eating outside
# agent id 372 is eating outside
# agent id 449 is eating outside
# agent id 410 is eating outside
# agent id 934 is eating outside
# agent id 532 is eating outside
# agent id 604 is eating outside
# agent id 674 is eating outside
# agent id 397 is eating outside
# agent id 197 is eating outside
# agent id 979 is eating outside
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 1:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:0.0
#  agent id 843 is eating outside
#  agent id 680 is eating outside
# VBox()
#     agent id 174 is eating outside
# agent id 764 is eating outside
# agent id 945 is eating outside
# agent id 543 is eating outside
# agent id 846 is eating outside
# agent id 534 is eating outside
# agent id 967 is eating outside
# agent id 140 is eating outside
# agent id 456 is eating outside
# agent id 625 is eating outside
# agent id 133 is eating outside
# agent id 699 is eating outside
# agent id 707 is eating outside
# agent id 340 is eating outside
# agent id 897 is eating outside
# agent id 722 is eating outside
# agent id 193 is eating outside
# agent id 887 is eating outside
# agent id 373 is eating outside
# agent id 314 is eating outside
# agent id 108 is eating outside
# agent id 438 is eating outside
# agent id 697 is eating outside
# agent id 938 is eating outside
# agent id 196 is eating outside
# agent id 152 is eating outside
# agent id 683 is eating outside
# agent id 917 is eating outside
# agent id 873 is eating outside
# agent id 488 is eating outside
# agent id 371 is eating outside
# agent id 239 is eating outside
# agent id 443 is eating outside
# agent id 592 is eating outside
# agent id 908 is eating outside
# agent id 986 is eating outside
# agent id 659 is eating outside
# agent id 734 is eating outside
# agent id 673 is eating outside
# agent id 992 is eating outside
# agent id 31 is eating outside
# agent id 886 is eating outside
# agent id 777 is eating outside
# agent id 402 is eating outside
# agent id 482 is eating outside
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 2:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:0.0
#    agent id 268 is eating outside
# VBox()
# agent id 623 is eating outside
# agent id 580 is eating outside
#  agent id 14 is eating outside
# agent id 530 is eating outside
#   agent id 758 is eating outside
# agent id 629 is eating outside
# agent id 294 is eating outside
# agent id 37 is eating outside
# agent id 504 is eating outside
# agent id 303 is eating outside
# agent id 710 is eating outside
# agent id 337 is eating outside
# agent id 522 is eating outside
# agent id 517 is eating outside
# agent id 957 is eating outside
# agent id 4 is eating outside
# agent id 890 is eating outside
# agent id 608 is eating outside
# agent id 343 is eating outside
# agent id 481 is eating outside
# agent id 289 is eating outside
# agent id 506 is eating outside
# agent id 359 is eating outside
# agent id 617 is eating outside
# agent id 178 is eating outside
# agent id 755 is eating outside
# agent id 776 is eating outside
# agent id 207 is eating outside
# agent id 773 is eating outside
# agent id 392 is eating outside
# agent id 272 is eating outside
# agent id 379 is eating outside
# agent id 321 is eating outside
# agent id 192 is eating outside
# agent id 592 is eating outside
# agent id 64 is eating outside
# agent id 50 is eating outside
# agent id 145 is eating outside
# agent id 287 is eating outside
# agent id 326 is eating outside
# agent id 681 is eating outside
# agent id 107 is eating outside
# agent id 529 is eating outside
# agent id 725 is eating outside
# agent id 854 is eating outside
# agent id 462 is eating outside
# agent id 61 is eating outside
# agent id 425 is eating outside
# agent id 156 is eating outside
# agent id 989 is eating outside
# agent id 372 is eating outside
# agent id 189 is eating outside
# agent id 690 is eating outside
# agent id 613 is eating outside
# agent id 673 is eating outside
# agent id 157 is eating outside
# agent id 400 is eating outside
# agent id 553 is eating outside
# agent id 813 is eating outside
# agent id 956 is eating outside
# agent id 302 is eating outside
# agent id 927 is eating outside
# agent id 329 is eating outside
# agent id 727 is eating outside
# agent id 447 is eating outside
# agent id 862 is eating outside
# agent id 77 is eating outside
# agent id 151 is eating outside
# agent id 195 is eating outside
# agent id 609 is eating outside
# agent id 912 is eating outside
# agent id 217 is eating outside
# agent id 884 is eating outside
# agent id 213 is eating outside
# agent id 799 is eating outside
# agent id 649 is eating outside
# agent id 54 is eating outside
# agent id 659 is eating outside
# agent id 116 is eating outside
# agent id 903 is eating outside
# agent id 540 is eating outside
# agent id 578 is eating outside
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 1
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 3:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:0.0
#   agent id 680 is eating outside
#  agent id 231 is eating outside
# VBox()
#  agent id 236 is eating outside
# agent id 140 is eating outside
#   agent id 48 is eating outside
# agent id 255 is eating outside
# agent id 82 is eating outside
# agent id 436 is eating outside
# agent id 29 is eating outside
# agent id 28 is eating outside
# agent id 459 is eating outside
# agent id 946 is eating outside
# agent id 736 is eating outside
# agent id 856 is eating outside
# agent id 528 is eating outside
# agent id 401 is eating outside
# agent id 610 is eating outside
# agent id 25 is eating outside
# agent id 212 is eating outside
# agent id 792 is eating outside
# agent id 920 is eating outside
# agent id 435 is eating outside
# agent id 340 is eating outside
# agent id 224 is eating outside
# agent id 615 is eating outside
# agent id 36 is eating outside
# agent id 613 is eating outside
# agent id 472 is eating outside
# agent id 935 is eating outside
# agent id 675 is eating outside
# agent id 781 is eating outside
# agent id 990 is eating outside
# agent id 135 is eating outside
# agent id 86 is eating outside
# agent id 955 is eating outside
# agent id 658 is eating outside
# agent id 769 is eating outside
# agent id 833 is eating outside
# agent id 501 is eating outside
# agent id 142 is eating outside
# agent id 250 is eating outside
# agent id 586 is eating outside
# agent id 778 is eating outside
# agent id 375 is eating outside
# agent id 780 is eating outside
# agent id 593 is eating outside
# agent id 100 is eating outside
# agent id 120 is eating outside
# agent id 318 is eating outside
# agent id 334 is eating outside
# agent id 272 is eating outside
# agent id 908 is eating outside
# agent id 913 is eating outside
# agent id 89 is eating outside
# agent id 416 is eating outside
# agent id 876 is eating outside
# agent id 8 is eating outside
# agent id 839 is eating outside
# agent id 342 is eating outside
# agent id 929 is eating outside
# agent id 49 is eating outside
# agent id 412 is eating outside
# agent id 446 is eating outside
# agent id 670 is eating outside
# agent id 432 is eating outside
# agent id 536 is eating outside
# agent id 982 is eating outside
# agent id 202 is eating outside
# agent id 825 is eating outside
# agent id 113 is eating outside
# agent id 533 is eating outside
# agent id 972 is eating outside
# agent id 596 is eating outside
# agent id 470 is eating outside
# agent id 817 is eating outside
# agent id 963 is eating outside
# agent id 583 is eating outside
# agent id 6 is eating outside
# agent id 155 is eating outside
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 2
#
#
# finish stepping
# moving agents in renderer
# Current Time = 4:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 3
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:0.0
#    agent id 623 is eating outside
# VBox()
# agent id 230 is eating outside
#  agent id 635 is eating outside
#   agent id 764 is eating outside
# agent id 843 is eating outside
# agent id 712 is eating outside
# agent id 689 is eating outside
# agent id 456 is eating outside
# agent id 429 is eating outside
# agent id 749 is eating outside
# agent id 240 is eating outside
# agent id 252 is eating outside
# agent id 715 is eating outside
# agent id 181 is eating outside
# agent id 730 is eating outside
# agent id 449 is eating outside
# agent id 853 is eating outside
# agent id 410 is eating outside
# agent id 432 is eating outside
# agent id 993 is eating outside
# agent id 325 is eating outside
# agent id 800 is eating outside
# agent id 634 is eating outside
# agent id 334 is eating outside
# agent id 461 is eating outside
# agent id 886 is eating outside
# agent id 625 is eating outside
# agent id 262 is eating outside
# agent id 322 is eating outside
# agent id 182 is eating outside
# agent id 510 is eating outside
# agent id 173 is eating outside
# agent id 422 is eating outside
# agent id 665 is eating outside
# agent id 927 is eating outside
# agent id 59 is eating outside
# agent id 96 is eating outside
# agent id 261 is eating outside
# agent id 454 is eating outside
# agent id 713 is eating outside
# agent id 516 is eating outside
# agent id 746 is eating outside
# agent id 736 is eating outside
# agent id 119 is eating outside
# agent id 175 is eating outside
# agent id 587 is eating outside
# agent id 777 is eating outside
# agent id 50 is eating outside
# agent id 402 is eating outside
# agent id 138 is eating outside
# agent id 65 is eating outside
# agent id 675 is eating outside
# agent id 274 is eating outside
# agent id 130 is eating outside
# agent id 489 is eating outside
# agent id 324 is eating outside
# agent id 847 is eating outside
# agent id 63 is eating outside
# agent id 373 is eating outside
# agent id 443 is eating outside
# agent id 985 is eating outside
# agent id 196 is eating outside
# agent id 469 is eating outside
# agent id 377 is eating outside
# agent id 104 is eating outside
# agent id 955 is eating outside
# agent id 594 is eating outside
# agent id 609 is eating outside
# agent id 735 is eating outside
# agent id 223 is eating outside
# agent id 541 is eating outside
# agent id 32 is eating outside
# agent id 194 is eating outside
# agent id 79 is eating outside
# agent id 22 is eating outside
# agent id 420 is eating outside
# agent id 771 is eating outside
# agent id 867 is eating outside
# agent id 177 is eating outside
# agent id 251 is eating outside
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 4
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:5.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 5
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:10.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 5
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:15.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 5
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:20.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 5
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:25.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 6
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:30.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 7
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:35.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 2
# restaurant = 7
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:40.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 3
# restaurant = 7
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:45.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 3
# restaurant = 7
# retail = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:50.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 3
# restaurant = 7
# retail = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 5:55.0
# Finished finalizing the infection
#
# known infection location
# Initial = 99
# Home = 3
# restaurant = 8
# retail = 1
#
#
# finish stepping
# moving agents in renderer
# Current Time = 6:0.0
#  agent id 378 is eating outside
# agent id 437 is eating outside
# VBox()
#   agent id 623 is eating outside
# agent id 331 is eating outside
#   agent id 308 is eating outside
# agent id 441 is eating outside
# agent id 818 is eating outside
# agent id 701 is eating outside
# agent id 556 is eating outside
# agent id 509 is eating outside
# agent id 786 is eating outside
# agent id 19 is eating outside
# agent id 311 is eating outside
# agent id 191 is eating outside
# agent id 937 is eating outside
# agent id 236 is eating outside
# agent id 831 is eating outside
# agent id 150 is eating outside
# agent id 841 is eating outside
# agent id 170 is eating outside
# agent id 57 is eating outside
# agent id 741 is eating outside
# agent id 710 is eating outside
# agent id 335 is eating outside
# agent id 628 is eating outside
# agent id 90 is eating outside
# agent id 662 is eating outside
# agent id 809 is eating outside
# agent id 361 is eating outside
# agent id 744 is eating outside
# agent id 126 is eating outside
# agent id 50 is eating outside
# agent id 42 is eating outside
# agent id 954 is eating outside
# agent id 601 is eating outside
# agent id 615 is eating outside
# agent id 904 is eating outside
# agent id 372 is eating outside
# agent id 224 is eating outside
# agent id 932 is eating outside
# agent id 15 is eating outside
# agent id 798 is eating outside
# agent id 765 is eating outside
# agent id 342 is eating outside
# agent id 542 is eating outside
# agent id 845 is eating outside
# agent id 801 is eating outside
# agent id 238 is eating outside
# agent id 901 is eating outside
# agent id 953 is eating outside
# agent id 102 is eating outside
# agent id 386 is eating outside
# agent id 536 is eating outside
# agent id 373 is eating outside
# agent id 346 is eating outside
# agent id 851 is eating outside
# agent id 490 is eating outside
# agent id 196 is eating outside
# agent id 559 is eating outside
# agent id 671 is eating outside
# agent id 362 is eating outside

# %%
osmMap.summarizeBuilding()

# %%
sim.history

# %%
for agent in sim.agents:
    print(agent.home.groceries)

# %% [markdown]
# showData(sim)

# %% [markdown]
# sim.stepCount = 3600*8

# %% [markdown]
# x = threading.Thread(target=renderer.render, args=(osmMap,sim,))
# x.start()

# %% [markdown]
# showData(sim)

# %% [markdown]
# a = [(45,'for', 24), (3,'Geeks', 8), (20,'Geeks', 30)]
# a.sort(key=lambda x:x[1])
# a

# %% [markdown]
# result

# %% [markdown]
# print(osmMap.buildingsMap["b586"])
# print(osmMap.buildingsMap["b586"].node)
# print(osmMap.buildingsMap["b586"].entryPoint)

# %% [markdown]
# for x in sim.agents:
#     print(x.mainJob.isWorking(0,8))

# %% [markdown]
# agent = sim.agents[1]

# %% [markdown]
# agent.step(0,8,steps=15)

# %% [markdown]
# sim.currentHour()

# %% [markdown]
# print(agent.activeSequence)

# %% [markdown]
# osmMap.findPath(agent,agent.mainJob.building)

# %% [markdown]
# x = agent.currentNode.getMovementSequence(agent.mainJob.building.node)
# print (x)

# %% [markdown]
# print(agent.currentNode)
# print(agent.home.node())

# %% [markdown]
# agent.mainJob.isWorking(0,8)

# %% [markdown]
# agent.mainJob.workdays

# %% [markdown]
# b = agent.currentNode.getMovementSequence(agent.mainJob.building.node)
# print(b)

# %% [markdown]
# from lib.Map.PathFinder import searchPath
# distance, sequence = searchPath(osmMap,agent.currentNode,agent.mainJob.building.node)

# %% [markdown]
# sequence

# %% [markdown]
# distance

# %% [markdown]
# agent.setMovementSequence(activeSequence)

# %% [markdown]
# agent.currentNode.addMovementSequence(sequence.clone())
