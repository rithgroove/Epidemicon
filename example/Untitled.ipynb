# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd() , ".."))
import lib.Map.Map as map
import lib.Renderer.Renderer as renderer
from lib.Renderer.GraphViewer import showData
from lib.Renderer.LocationStatistic import showPieChart
import threading
import lib.Simulation.Simulator as Simulator

# %%
dataDirectory = os.path.join("..","osmData")
filename = "TX-To-TU.osm"
filepath = os.path.join(dataDirectory,filename)

buildingConfigPath = os.path.join("..","config","tsukuba-tu-building-data.csv")
osmMap = map.readFile(filepath,buildingCSV = buildingConfigPath)
sim = Simulator.Simulator("../config/jobs.csv",osmMap,agentNum = 2000,threadNumber = 8, infectedAgent = 10)
# Out:
# 0.002800000000002001,0.004399999999999693
# error, Heron's formula is not working due to very small angle
# ['9', '0', '0', 'All', 'laboratory']
# ['9', '0', '1', 'All', 'residential']
# ['9', '0', '2', '1', 'barbershop']
# ['9', '0', '2', '1', 'retail']
# ['9', '0', '2', 'All', 'residential']
# ['8', '1', '0', '5', 'office']
# ['8', '1', '0', 'All', 'residential']
# ['8', '1', '1', '2', 'laboratory']
# ['8', '1', '1', 'All', 'laboratory']
# ['8', '1', '2', 'All', 'residential']
# ['8', '1', '3', 'All', 'laboratory']
# ['8', '1', '4', 'All', 'university']
# ['8', '1', '7', '3', 'retail']
# ['8', '1', '7', 'All', 'office']
# ['8', '1', '8', '1', 'clinic']
# ['8', '1', '8', '1', 'residential']
# ['8', '1', '8', '1', 'skill school']
# ['8', '1', '8', 'All', 'retail']
# ['7', '2', '1', 'All', 'laboratory']
# ['7', '2', '2', 'All', 'university']
# ['7', '2', '3', '1', 'retail']
# ['6', '3', '3', '3', 'residential']
# ['7', '2', '3', 'All', 'university']
# ['7', '2', '4', 'All', 'laboratory']
# ['7', '2', '5', '4', 'house']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', '4', 'residential']
# ['7', '2', '5', 'All', 'apartments']
# ['7', '2', '6', '1', 'house']
# ['7', '2', '6', '1', 'office']
# ['7', '2', '6', '1', 'university']
# ['7', '2', '6', '3', 'retail']
# ['7', '2', '6', '4', 'residential']
# ['7', '2', '6', 'All', 'apartments']
# ['7', '2', '7', '1', 'office']
# ['7', '2', '7', '2', 'retail']
# ['7', '2', '7', 'All', 'apartments']
# ['7', '2', '7', 'All', 'apartments']
# ['7', '2', '8', '1', 'office']
# ['7', '2', '8', 'All', 'retail']
# ['6', '3', '0', '2', 'apartments']
# ['6', '3', '0', 'All', 'house']
# ['6', '3', '1', '1', 'pachinko']
# ['6', '3', '1', 'All', 'house']
# ['6', '3', '2', '13', 'laboratory']
# ['6', '3', '3', '1', 'barbershop']
# ['6', '3', '3', 'All', 'University']
# ['6', '3', '4', '1', 'church']
# ['6', '3', '4', '1', 'office']
# ['6', '3', '4', '1', 'residential']
# ['6', '3', '4', '1', 'retail']
# ['6', '3', '4', 'All', 'apartments']
# ['6', '3', '5', '1', 'retail']
# ['6', '3', '5', '3', 'residential']
# ['6', '3', '5', 'All', 'apartments']
# ['6', '3', '6', '4', 'retail']
# ['6', '3', '6', '15', 'residential']
# ['6', '3', '6', 'All', 'apartments']
# ['6', '3', '7', '1', 'clinic']
# ['6', '3', '7', '1', 'office']
# ['6', '3', '7', '3', 'barbershop']
# ['6', '3', '7', '4', 'retail']
# ['6', '3', '7', 'All', 'apartments']
# ['6', '3', '8', '2', 'residential']
# ['6', '3', '8', 'All', 'apartments']
# ['5', '4', '0', '1', 'house']
# ['5', '4', '0', 'All', 'apartments']
# ['5', '4', '1', 'All', 'house']
# ['5', '4', '2', '2', 'barbershop']
# ['5', '4', '2', '4', 'house']
# ['5', '4', '2', '4', 'residential']
# ['5', '4', '2', 'All', 'apartments']
# ['5', '4', '3', '2', 'residential']
# ['5', '4', '3', '4', 'hall']
# ['5', '4', '3', '8', 'apartments']
# ['5', '4', '3', 'All', 'university']
# ['5', '4', '4', 'All', 'university']
# ['5', '4', '5', 'All', 'university']
# ['5', '4', '6', 'All', 'museum']
# ['5', '4', '7', 'All', 'museum']
# ['4', '5', '0', '1', 'nursery']
# ['4', '5', '0', 'All', 'miscellaneous']
# ['4', '5', '1', '1', 'clinic']
# ['4', '5', '1', '1', 'karaoke_box']
# ['4', '5', '1', '1', 'skill school']
# ['4', '5', '1', '2', 'residential']
# ['4', '5', '1', '2', 'retail']
# ['4', '5', '1', 'All', 'apartments']
# ['4', '5', '2', '1', 'barbershop']
# ['4', '5', '2', '1', 'university']
# ['4', '5', '2', '2', 'retail']
# ['4', '5', '2', '3', 'restaurant']
# ['4', '5', '2', 'All', 'apartments']
# ['4', '5', '3', '1', 'retail']
# ['4', '5', '3', '3', 'restaurant']
# ['4', '5', '3', '3', 'university']
# ['4', '5', '3', '4', 'residential']
# ['4', '5', '3', 'All', 'apartments']
# ['4', '5', '4', '1', 'office']
# ['4', '5', '4', '1', 'retail']
# ['4', '5', '4', '2', 'restaurant']
# ['4', '5', '4', 'All', 'residential']
# ['4', '5', '5', '4', 'restaurant']
# ['4', '5', '5', 'All', 'apartments']
# ['4', '5', '6', 'All', 'museum']
# ['4', '5', '8', 'All', 'hall']
# ['3', '6', '0', '1', 'office']
# ['3', '6', '0', '2', 'apartments']
# ['3', '6', '0', 'All', 'house']
# ['3', '6', '1', '1', 'laboratory']
# ['3', '6', '1', '1', 'restaurant']
# ['3', '6', '1', 'All', 'house']
# ['3', '6', '2', '3', 'laboratory']
# ['3', '6', '2', 'All', 'apartments']
# ['3', '6', '3', '1', 'hospital']
# ['3', '6', '3', 'All', 'laboratory']
# ['3', '6', '4', '1', 'hospital']
# ['3', '6', '4', '2', 'laboratory']
# ['3', '6', '4', 'All', 'residential']
# ['3', '6', '5', '1', 'barbershop']
# ['3', '6', '5', '1', 'school']
# ['3', '6', '5', '4', 'retail']
# ['3', '6', '5', '6', 'restaurant']
# ['3', '6', '5', 'All', 'apartments']
# ['3', '6', '6', '1', 'karaoke_box']
# ['3', '6', '6', '1', 'retail']
# ['3', '6', '6', 'All', 'apartments']
# ['3', '6', '7', 'All', 'apartments']
# ['2', '7', '1', 'All', 'apartments']
# ['2', '7', '2', '1', 'laboratory']
# ['2', '7', '2', '2', 'restaurant']
# ['2', '7', '2', '2', 'retail']
# ['2', '7', '2', 'All', 'apartments']
# ['2', '7', '3', '3', 'office']
# ['2', '7', '3', 'All', 'apartments']
# ['2', '7', '4', '1', 'hospital']
# ['2', '7', '4', '1', 'university']
# ['2', '7', '4', 'All', 'apartments']
# ['2', '7', '5', '2', 'hall']
# ['2', '7', '5', '3', 'university']
# ['2', '7', '5', 'All', 'laboratory']
# ['2', '7', '6', '1', 'restaurant']
# ['2', '7', '6', '1', 'retail']
# ['2', '7', '6', 'All', 'apartments']
# ['2', '7', '7', '1', 'clinic']
# ['2', '7', '7', '2', 'hospital']
# ['2', '7', '7', '3', 'restaurant']
# ['2', '7', '7', '3', 'retail']
# ['2', '7', '7', 'All', 'apartments']
# ['2', '7', '8', '1', 'laboratory']
# ['2', '7', '8', '1', 'skill school']
# ['2', '7', '8', 'All', 'apartments']
# ['1', '8', '0', '3', 'retail']
# ['1', '8', '0', 'All', 'house']
# ['1', '8', '1', '1', 'apartments']
# ['1', '8', '1', '1', 'clinic']
# ['1', '8', '1', '1', 'restaurant']
# ['1', '8', '1', '1', 'retail']
# ['1', '8', '1', '1', 'skill school']
# ['1', '8', '1', 'All', 'house']
# ['1', '8', '2', '1', 'restaurant']
# ['1', '8', '2', '1', 'retail']
# ['1', '8', '2', '2', 'office']
# ['1', '8', '2', 'All', 'apartments']
# ['1', '8', '3', '1', 'office']
# ['1', '8', '3', '1', 'restaurant']
# ['1', '8', '3', '1', 'retail']
# ['1', '8', '3', '1', 'skill school']
# ['1', '8', '3', '2', 'barbershop']
# ['1', '8', '3', 'All', 'apartments']
# ['1', '8', '4', '1', 'restaurant']
# ['1', '8', '4', 'All', 'office']
# ['1', '8', '5', '1', 'restaurant']
# ['1', '8', '5', '1', 'university']
# ['1', '8', '5', 'All', 'residential']
# ['1', '8', '6', '4', 'museum']
# ['1', '8', '6', 'All', 'school']
# ['1', '8', '7', '1', 'hotel']
# ['1', '8', '7', '1', 'bus_terminal']
# ['1', '8', '7', 'All', 'apartments']
# ['1', '8', '8', '1', 'school']
# ['1', '8', '8', '3', 'office']
# ['1', '8', '8', 'All', 'apartments']
# ['1', '8', '9', 'All', 'apartments']
# ['0', '9', '1', '1', 'nursery']
# ['0', '9', '1', 'All', 'school']
# ['0', '9', '5', '1', 'hall']
# ['0', '9', '5', '1', 'restaurant']
# ['0', '9', '5', '2', 'hotel']
# ['0', '9', '5', 'All', 'apartments']
# ['0', '9', '6', '1', 'hotel']
# ['0', '9', '6', '1', 'mall']
# ['0', '9', '6', 'All', 'office']
# ['0', '9', '7', '1', 'apartments']
# ['0', '9', '7', '2', 'office']
# ['0', '9', '7', 'All', 'mall']
# ['0', '9', '8', '1', 'hall']
# ['0', '9', '8', '2', 'mall']
# ['0', '9', '8', '3', 'apartments']
# ['0', '9', '8', 'All', 'office']
# ['0', '9', '9', '1', 'mall']
# ['0', '9', '9', '1', 'office']
# ['0', '9', '9', 'All', 'apartments']
# ['student', '9', '9', 'school', '4', '18', '5', '8', '9', 'weekday', '5', '5', 'no']
# ['university_student', '4', '9', 'university', '18', '60', '5', '8', '14', 'weekday', '1', '5', 'no']
# ['medical_doctor', '8', '24', 'hospital', '25', '70', '1', '0', '23', 'everyday', '5', '7', 'no']
# ['teacher', '9', '9', 'school', '23', '70', '1', '8', '9', 'weekday', '5', '5', 'no']
# ['university_professor ', '5', '9', 'university', '28', '70', '1', '8', '9', 'weekday', '3', '5', 'no']
# ['salaryman_tsuchiura', '9', '9', 'train_station', '19', '70', '3', '8', '9', 'weekday', '5', '5', 'yes']
# ['salaryman_tokyo', '9', '9', 'train_station', '19', '70', '3', '8', '9', 'weekday', '5', '5', 'yes']
# ['convenience_store_employee', '8', '8', 'retail', '19', '70', '1', '0', '23', 'everyday', '3', '5', 'no']
# ['salaryman', '4', '5', 'office', '19', '70', '5', '8', '10', 'weekday', '5', '5', 'no']
# ['barber', '7', '8', 'barbershop', '20', '70', '1', '8', '12', 'everyday', '5', '6', 'no']
# ['restaurant_worker', '8', '10', 'restaurant', '16', '70', '1', '0', '18', 'everyday', '5', '7', 'no']
# ['scientist', '5', '9', 'laboratory', '21', '70', '2', '8', '9', 'weekday', '3', '5', 'no']
# Processed 0 lines.
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# ...
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays
# warning, activities per week is lower than the optional workdays

# %%
stepLength = 300 #step length in simulation seconds
for i in range(0,1*24*3600,stepLength):
    print(i)
    sim.step(stepLength)
# Out:
# 0
# Day = 0 Current Time = 00:00
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# VBox()
# Finished finalizing the infection
#
# known infection location
# Initial = 10
#
#
# 300
# Day = 0 Current Time = 00:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
#
#
# 600
# Day = 0 Current Time = 00:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
#
#
# 900
# Day = 0 Current Time = 00:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 1200
# Day = 0 Current Time = 00:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 1500
# Day = 0 Current Time = 00:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 1800
# Day = 0 Current Time = 00:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 2100
# Day = 0 Current Time = 00:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 2400
# Day = 0 Current Time = 00:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 2700
# Day = 0 Current Time = 00:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 3000
# Day = 0 Current Time = 00:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 3300
# Day = 0 Current Time = 00:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 3600
# Day = 0 Current Time = 01:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 3900
# Day = 0 Current Time = 01:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 4200
# Day = 0 Current Time = 01:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 4500
# Day = 0 Current Time = 01:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 4800
# Day = 0 Current Time = 01:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 5100
# Day = 0 Current Time = 01:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 5400
# Day = 0 Current Time = 01:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 5700
# Day = 0 Current Time = 01:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 6000
# Day = 0 Current Time = 01:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 6300
# Day = 0 Current Time = 01:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 6600
# Day = 0 Current Time = 01:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 6900
# Day = 0 Current Time = 01:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 7200
# Day = 0 Current Time = 02:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 7500
# Day = 0 Current Time = 02:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 7800
# Day = 0 Current Time = 02:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 8100
# Day = 0 Current Time = 02:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 8400
# Day = 0 Current Time = 02:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 8700
# Day = 0 Current Time = 02:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 9000
# Day = 0 Current Time = 02:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 9300
# Day = 0 Current Time = 02:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 9600
# Day = 0 Current Time = 02:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 9900
# Day = 0 Current Time = 02:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 10200
# Day = 0 Current Time = 02:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 10500
# Day = 0 Current Time = 02:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 10800
# Day = 0 Current Time = 03:00
# VBox()
#        Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 11100
# Day = 0 Current Time = 03:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 11400
# Day = 0 Current Time = 03:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 11700
# Day = 0 Current Time = 03:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 12000
# Day = 0 Current Time = 03:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 12300
# Day = 0 Current Time = 03:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 12600
# Day = 0 Current Time = 03:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 12900
# Day = 0 Current Time = 03:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 13200
# Day = 0 Current Time = 03:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 13500
# Day = 0 Current Time = 03:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 13800
# Day = 0 Current Time = 03:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 14100
# Day = 0 Current Time = 03:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 14400
# Day = 0 Current Time = 04:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 14700
# Day = 0 Current Time = 04:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 15000
# Day = 0 Current Time = 04:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 15300
# Day = 0 Current Time = 04:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 15600
# Day = 0 Current Time = 04:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 15900
# Day = 0 Current Time = 04:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 16200
# Day = 0 Current Time = 04:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 16500
# Day = 0 Current Time = 04:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 16800
# Day = 0 Current Time = 04:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 17100
# Day = 0 Current Time = 04:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 17400
# Day = 0 Current Time = 04:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 17700
# Day = 0 Current Time = 04:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 18000
# Day = 0 Current Time = 05:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 18300
# Day = 0 Current Time = 05:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 18600
# Day = 0 Current Time = 05:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 18900
# Day = 0 Current Time = 05:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 19200
# Day = 0 Current Time = 05:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 19500
# Day = 0 Current Time = 05:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 19800
# Day = 0 Current Time = 05:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 20100
# Day = 0 Current Time = 05:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 20400
# Day = 0 Current Time = 05:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 20700
# Day = 0 Current Time = 05:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 21000
# Day = 0 Current Time = 05:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 21300
# Day = 0 Current Time = 05:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 21600
# Day = 0 Current Time = 06:00
# VBox()
#        Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 21900
# Day = 0 Current Time = 06:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 22200
# Day = 0 Current Time = 06:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 22500
# Day = 0 Current Time = 06:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 22800
# Day = 0 Current Time = 06:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 23100
# Day = 0 Current Time = 06:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 23400
# Day = 0 Current Time = 06:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 23700
# Day = 0 Current Time = 06:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 24000
# Day = 0 Current Time = 06:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 24300
# Day = 0 Current Time = 06:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 24600
# Day = 0 Current Time = 06:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 24900
# Day = 0 Current Time = 06:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 25200
# Day = 0 Current Time = 07:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 25500
# Day = 0 Current Time = 07:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 25800
# Day = 0 Current Time = 07:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 26100
# Day = 0 Current Time = 07:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 26400
# Day = 0 Current Time = 07:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 26700
# Day = 0 Current Time = 07:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 27000
# Day = 0 Current Time = 07:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 27300
# Day = 0 Current Time = 07:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 27600
# Day = 0 Current Time = 07:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 27900
# Day = 0 Current Time = 07:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 28200
# Day = 0 Current Time = 07:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 28500
# Day = 0 Current Time = 07:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 28800
# Day = 0 Current Time = 08:00
# VBox()
#        Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 29100
# Day = 0 Current Time = 08:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 29400
# Day = 0 Current Time = 08:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 29700
# Day = 0 Current Time = 08:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 30000
# Day = 0 Current Time = 08:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 30300
# Day = 0 Current Time = 08:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 30600
# Day = 0 Current Time = 08:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 30900
# Day = 0 Current Time = 08:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 31200
# Day = 0 Current Time = 08:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 31500
# Day = 0 Current Time = 08:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 31800
# Day = 0 Current Time = 08:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 32100
# Day = 0 Current Time = 08:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 32400
# Day = 0 Current Time = 09:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 32700
# Day = 0 Current Time = 09:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 33000
# Day = 0 Current Time = 09:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 33300
# Day = 0 Current Time = 09:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 33600
# Day = 0 Current Time = 09:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 33900
# Day = 0 Current Time = 09:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 34200
# Day = 0 Current Time = 09:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 34500
# Day = 0 Current Time = 09:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 34800
# Day = 0 Current Time = 09:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 35100
# Day = 0 Current Time = 09:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 35400
# Day = 0 Current Time = 09:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 35700
# Day = 0 Current Time = 09:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 36000
# Day = 0 Current Time = 10:00
# VBox()
#        Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 36300
# Day = 0 Current Time = 10:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 36600
# Day = 0 Current Time = 10:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 36900
# Day = 0 Current Time = 10:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 37200
# Day = 0 Current Time = 10:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 37500
# Day = 0 Current Time = 10:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 37800
# Day = 0 Current Time = 10:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 38100
# Day = 0 Current Time = 10:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 38400
# Day = 0 Current Time = 10:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 38700
# Day = 0 Current Time = 10:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 39000
# Day = 0 Current Time = 10:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 39300
# Day = 0 Current Time = 10:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 39600
# Day = 0 Current Time = 11:00
# VBox()
#        Finished finalizing the infection
#
# known infection location
# Initial = 10
# Home = 1
#
#
# 39900
# Day = 0 Current Time = 11:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 40200
# Day = 0 Current Time = 11:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 40500
# Day = 0 Current Time = 11:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 40800
# Day = 0 Current Time = 11:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 41100
# Day = 0 Current Time = 11:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 41400
# Day = 0 Current Time = 11:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 41700
# Day = 0 Current Time = 11:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 42000
# Day = 0 Current Time = 11:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 42300
# Day = 0 Current Time = 11:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 42600
# Day = 0 Current Time = 11:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 42900
# Day = 0 Current Time = 11:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 43200
# Day = 0 Current Time = 12:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 43500
# Day = 0 Current Time = 12:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 43800
# Day = 0 Current Time = 12:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 44100
# Day = 0 Current Time = 12:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 44400
# Day = 0 Current Time = 12:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 44700
# Day = 0 Current Time = 12:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 45000
# Day = 0 Current Time = 12:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 45300
# Day = 0 Current Time = 12:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 45600
# Day = 0 Current Time = 12:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 45900
# Day = 0 Current Time = 12:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 46200
# Day = 0 Current Time = 12:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 1
# Home = 1
#
#
# 46500
# Day = 0 Current Time = 12:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 2
# Home = 1
#
#
# 46800
# Day = 0 Current Time = 13:00
# VBox()
#        Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 2
# Home = 1
#
#
# 47100
# Day = 0 Current Time = 13:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 2
# Home = 1
#
#
# 47400
# Day = 0 Current Time = 13:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 2
# Home = 1
#
#
# 47700
# Day = 0 Current Time = 13:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 48000
# Day = 0 Current Time = 13:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 48300
# Day = 0 Current Time = 13:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 48600
# Day = 0 Current Time = 13:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 48900
# Day = 0 Current Time = 13:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 49200
# Day = 0 Current Time = 13:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 49500
# Day = 0 Current Time = 13:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 49800
# Day = 0 Current Time = 13:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 50100
# Day = 0 Current Time = 13:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 50400
# Day = 0 Current Time = 14:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 50700
# Day = 0 Current Time = 14:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 51000
# Day = 0 Current Time = 14:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 51300
# Day = 0 Current Time = 14:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 51600
# Day = 0 Current Time = 14:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 3
# Home = 1
#
#
# 51900
# Day = 0 Current Time = 14:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 4
# Home = 1
#
#
# 52200
# Day = 0 Current Time = 14:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 4
# Home = 1
#
#
# 52500
# Day = 0 Current Time = 14:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 52800
# Day = 0 Current Time = 14:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 53100
# Day = 0 Current Time = 14:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 53400
# Day = 0 Current Time = 14:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 53700
# Day = 0 Current Time = 14:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 54000
# Day = 0 Current Time = 15:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 54300
# Day = 0 Current Time = 15:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 54600
# Day = 0 Current Time = 15:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 54900
# Day = 0 Current Time = 15:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 55200
# Day = 0 Current Time = 15:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 55500
# Day = 0 Current Time = 15:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 55800
# Day = 0 Current Time = 15:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 56100
# Day = 0 Current Time = 15:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 56400
# Day = 0 Current Time = 15:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 56700
# Day = 0 Current Time = 15:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 57000
# Day = 0 Current Time = 15:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 57300
# Day = 0 Current Time = 15:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 57600
# Day = 0 Current Time = 16:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 57900
# Day = 0 Current Time = 16:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 58200
# Day = 0 Current Time = 16:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 58500
# Day = 0 Current Time = 16:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 58800
# Day = 0 Current Time = 16:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 59100
# Day = 0 Current Time = 16:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 59400
# Day = 0 Current Time = 16:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 59700
# Day = 0 Current Time = 16:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 60000
# Day = 0 Current Time = 16:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 60300
# Day = 0 Current Time = 16:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
#
#
# 60600
# Day = 0 Current Time = 16:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 60900
# Day = 0 Current Time = 16:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 61200
# Day = 0 Current Time = 17:00
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 61500
# Day = 0 Current Time = 17:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 61800
# Day = 0 Current Time = 17:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 62100
# Day = 0 Current Time = 17:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 62400
# Day = 0 Current Time = 17:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 62700
# Day = 0 Current Time = 17:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 63000
# Day = 0 Current Time = 17:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 63300
# Day = 0 Current Time = 17:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 63600
# Day = 0 Current Time = 17:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# hospital = 1
#
#
# 63900
# Day = 0 Current Time = 17:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 64200
# Day = 0 Current Time = 17:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 64500
# Day = 0 Current Time = 17:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 64800
# Day = 0 Current Time = 18:00
# VBox()
#        Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 65100
# Day = 0 Current Time = 18:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 65400
# Day = 0 Current Time = 18:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 65700
# Day = 0 Current Time = 18:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 66000
# Day = 0 Current Time = 18:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 66300
# Day = 0 Current Time = 18:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 66600
# Day = 0 Current Time = 18:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 66900
# Day = 0 Current Time = 18:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 67200
# Day = 0 Current Time = 18:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 67500
# Day = 0 Current Time = 18:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 67800
# Day = 0 Current Time = 18:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 68100
# Day = 0 Current Time = 18:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 68400
# Day = 0 Current Time = 19:00
# VBox()
#       Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 68700
# Day = 0 Current Time = 19:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 69000
# Day = 0 Current Time = 19:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 69300
# Day = 0 Current Time = 19:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
#
#
# 69600
# Day = 0 Current Time = 19:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
# barbershop = 1
#
#
# 69900
# Day = 0 Current Time = 19:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
# barbershop = 1
#
#
# 70200
# Day = 0 Current Time = 19:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
# barbershop = 1
#
#
# 70500
# Day = 0 Current Time = 19:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
# barbershop = 1
#
#
# 70800
# Day = 0 Current Time = 19:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
# barbershop = 1
#
#
# 71100
# Day = 0 Current Time = 19:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
# barbershop = 1
#
#
# 71400
# Day = 0 Current Time = 19:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 1
# barbershop = 1
#
#
# 71700
# Day = 0 Current Time = 19:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 72000
# Day = 0 Current Time = 20:00
# VBox()
#      Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 72300
# Day = 0 Current Time = 20:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 72600
# Day = 0 Current Time = 20:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 72900
# Day = 0 Current Time = 20:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 73200
# Day = 0 Current Time = 20:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 73500
# Day = 0 Current Time = 20:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 73800
# Day = 0 Current Time = 20:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 74100
# Day = 0 Current Time = 20:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 74400
# Day = 0 Current Time = 20:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 74700
# Day = 0 Current Time = 20:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 75000
# Day = 0 Current Time = 20:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 75300
# Day = 0 Current Time = 20:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 75600
# Day = 0 Current Time = 21:00
# VBox()
#        Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 75900
# Day = 0 Current Time = 21:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 76200
# Day = 0 Current Time = 21:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 76500
# Day = 0 Current Time = 21:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 76800
# Day = 0 Current Time = 21:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 77100
# Day = 0 Current Time = 21:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 77400
# Day = 0 Current Time = 21:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 77700
# Day = 0 Current Time = 21:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 78000
# Day = 0 Current Time = 21:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 78300
# Day = 0 Current Time = 21:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 78600
# Day = 0 Current Time = 21:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 78900
# Day = 0 Current Time = 21:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# barbershop = 1
#
#
# 79200
# Day = 0 Current Time = 22:00
# VBox()
#        Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 79500
# Day = 0 Current Time = 22:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 79800
# Day = 0 Current Time = 22:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 80100
# Day = 0 Current Time = 22:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 80400
# Day = 0 Current Time = 22:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 80700
# Day = 0 Current Time = 22:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 81000
# Day = 0 Current Time = 22:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 81300
# Day = 0 Current Time = 22:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 81600
# Day = 0 Current Time = 22:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 81900
# Day = 0 Current Time = 22:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 82200
# Day = 0 Current Time = 22:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 82500
# Day = 0 Current Time = 22:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 82800
# Day = 0 Current Time = 23:00
# VBox()
#        Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 83100
# Day = 0 Current Time = 23:05
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 83400
# Day = 0 Current Time = 23:10
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 83700
# Day = 0 Current Time = 23:15
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 84000
# Day = 0 Current Time = 23:20
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 84300
# Day = 0 Current Time = 23:25
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 84600
# Day = 0 Current Time = 23:30
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 84900
# Day = 0 Current Time = 23:35
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 85200
# Day = 0 Current Time = 23:40
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 85500
# Day = 0 Current Time = 23:45
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 85800
# Day = 0 Current Time = 23:50
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1
#
#
# 86100
# Day = 0 Current Time = 23:55
# Finished finalizing the infection
#
# known infection location
# Initial = 10
# Going out of city = 5
# Home = 1
# office = 1
# hospital = 2
# On The Road = 1
# barbershop = 1

# %%
sim.extract()
print("finished")
# Out:
# finished

# %%
osmMap.summarizeBuilding()
# Out:
# Type of buildings contained in this map
# restaurant = 36
# retail = 68
# apartments = 867
# parking = 4
# hotel = 5
# bus_terminal = 1
# office = 52
# train_station = 1
# public = 1
# police = 1
# hall = 9
# mall = 11
# church = 1
# laboratory = 80
# skill school = 5
# clinic = 4
# hospital = 5
# school = 25
# university = 104
# residential = 166
# museum = 12
# barbershop = 8
# karaoke_box = 3
# roof = 11
# nursery = 2
# house = 188
# commercial = 1
# shed = 8
# University = 27
# post_office = 2
# bicycle_parking = 3
# community_centre = 2
# toilets = 1
# yes = 31
# pachinko = 1
# industrial = 2
# garage = 2
# miscellaneous = 2

# %%
a = sim.agents[0]
a.eatingOutPref
# Out:
# 0.7
