# %%
import sys
import os
import yaml
# adds the root of the git dir to the import path
# FIXME: Directory shenanigans
root_dir = os.getcwd()
sys.path.append(root_dir)
import lib.Map.Map as mmap
from lib.Renderer.Controller import Controller
from lib.Renderer.Controller import View
from lib.Simulation.Simulator import Simulator

configFileName = "config.yml"

# %%
requiredConfigs = [
    "OSMfile",
    "buildConnFile",
    "jobsFile",
    "numberOfAgents",
    "buildingConfigPath",
    "threadNumber",
    "infectedAgent",
    "vaccinationPercentage",
    "windowWidth",
    "windowHeight",
    "reportDir",
    "reportInterval",
]

# %%
def read_validate_config(file_path):
    config = None
    with open(file_path, "r") as f:
        config = yaml.safe_load(f)
    err = False
    errMessage = "Missing required attributes in config file: "
    for c in requiredConfigs:
        if c not in config:
            err = True
            errMessage += c + " "
    if err:
        raise NameError(errMessage)

    return config

# %%
c = read_validate_config(configFileName)


# Load the data
gridSize = (c["gridHeight"], c["gridWidth"])
osmMap = mmap.readFile(c["OSMfile"], c["buildConnFile"], gridSize, c["buildingConfigPath"])
# Start Simulator
sim = Simulator(
    osmMap, 
    c["jobsFile"], 
    c["numberOfAgents"], 
    c["threadNumber"], 
    c["infectedAgent"], 
    c["vaccinationPercentage"],
    c["reportDir"],
    c["reportInterval"])

# Draw    
windowSize = (c["windowWidth"], c["windowHeight"])
view = View(mymap=osmMap, simulation=sim, windowSize=windowSize)
app = Controller(model=sim, view=view)
app.main_loop()
sim.extract()
# Out:
# Processed 0 lines.
# Processing... Week = 0 Day = 0 Current Time = 00:00
#             Thread 4 finished
# Thread 9 finished
# Thread 1 finished
# Thread 3 finished
# Thread 6 finished
# Thread 7 finished
# Thread 10 finished
# Thread 12 finished
# Thread 8 finished
# Thread 2 finished
# Thread 11 finished
# Thread 5 finished
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:01
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:02
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:03
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:04
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:05
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:06
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:07
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:08
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:09
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:10
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:11
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:12
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:13
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:14
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:15
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:16
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:17
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:18
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:19
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:20
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:21
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:22
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:23
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:24
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:25
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:26
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:27
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:28
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:29
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:30
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:31
# Finished finalizing the infection
#
# known infection location
# Initial = 200
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:32
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:33
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:34
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:35
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:36
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:37
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:38
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:39
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:40
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:41
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:42
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:43
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:44
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:45
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:46
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:47
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:48
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:49
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:50
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:51
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:52
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:53
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:54
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:55
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
# residential = 1
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:56
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 1
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:57
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 2
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:58
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 2
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 00:59
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 3
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 01:00
#             Thread 4 finished
# Thread 6 finished
# Thread 12 finished
# Thread 9 finished
# Thread 7 finished
# Thread 11 finished
# Thread 8 finished
# Thread 1 finished
# Thread 3 finished
# Thread 10 finished
# Thread 2 finished
# Thread 5 finished
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 3
# residential = 1
#
#
# Extracting data
# Done!
# Processing... Week = 0 Day = 0 Current Time = 01:01
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 3
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 01:02
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 3
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 01:03
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 3
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 01:04
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 3
# residential = 1
#
#
# Done!
# Processing... Week = 0 Day = 0 Current Time = 01:05
# Finished finalizing the infection
#
# known infection location
# Initial = 200
# restaurant = 3
# residential = 1
#
#
# Extracting data
# Done!
# does it work?
